# %% [markdown]
# <div style="text-align: right">INFO 6105 Data Science Eng Methods and Tools, Lecture 6 Day 2</div>
# <div style="text-align: right">Dino Konstantopoulos, 12 February 2020, with material by Ankur Ankan and Abinash Panda</div>
#
# Some people have this to say about advantages of the **German** language:
#
# <br />
# <center>
# <img src="images2/german-flag.jpg" width=300 />
# </center>
#
# - It is better to keep the most important piece of information at the end, to keep people’s attention. In German, the main verb in conjugation is at the end of a sentence: *Sie (You) haben (have) bestimmt (definitely) noch (still) nicht (not) viele (many) anständige (respectable) Zauberer (wizard) **kennen gelernt** (met)*. In Spanish and English, we say all the important information first and, for this reason, we tend to interrupt each other in the middle of a sentence.
#
#
# - The purpose of words is to transmit **knowledge**, so they should be easily understood. Some people seem to use words no one knows just to look smart. In German, it is almost impossible to do this as names for objects describe those objects. I really love this about German: Glutenunverträglichkeit means gluten-not-compatible (celiac). It helped a lot while reading Harry Potter: Zauberer (wizard), Zauberwort (Magic word), Zaubererschule (School of Magic), Zauberstab (magic wand), Zaubererwelt (wizarding world), etc
#
# # POS tagging with Hidden Markov Models
#
# In this notebook you will witness how you can *cheat* Science by relying on data probabilities instead of trying to figure out the rules or laws of Science. I don't know the internals of [Universal Dependencies](https://universaldependencies.org/), but I suspect they do not worry about analyzing the structure of the German language, figuring out that the verb is at the end of a sentence, and accomodating for this in the German Tree Bank. Instead, their algorithms probably read in a lot of german text, and just by looking at the probabilities of where the verb lands in a sentence they can correctly figure out that it's at the end. Probabilities powers **statistics**, and having lots of data means your probabilities can be very *exact*.
#
# Not too many weeks ago, you called R libraries to do POS tagging for you. Now that you know everything about probabilities, *you* can do the same thing *on your own*!
#
# We'll use the [Brown]() corpus to build a [POS tagger](https://en.wikipedia.org/wiki/Part-of-speech_tagging), first using a simple [Bag of Words](https://en.wikipedia.org/wiki/Bag-of-words_model) model (***most probable POS by count***), then using a **Hidden Markov Model** (HMM) that gets *transition* and *emission* probabilities from [POS bigrams](https://en.wikipedia.org/wiki/Bigram) (given a POS, what's the most probable ***next*** POS in the sentence?).
#
# We'll divide the Brown corpus into training and test sets, and compare accuraces for BOW and HMM models.
#
# We'll use some advanced python structures that are often used in Natural Language Processing (NLP).
#
# # Reading in the Brown corpus efficiently

# %% [markdown]
# # 1

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.core.display import HTML
from itertools import chain
from collections import Counter, defaultdict, namedtuple, OrderedDict
from pomegranate import State, HiddenMarkovModel, DiscreteDistribution
import os
from io import BytesIO
from itertools import chain
import random

# %% [markdown]
# Some advanced python-fu:
#
# Library `itertools` is a library of efficient iterators. `chain` makes an iterator that returns elements from the first iterable until it is exhausted, then proceeds to the next iterable, until all of the iterables are exhausted. It is used for treating consecutive sequences as a single sequence
#
# In python, a single star `*` unpacks the sequence/collection into positional arguments, so you can do this:
# ```(python)
# def sum(a, b):
#     return a + b
#
# values = (1, 2)
#
# s = sum(*values)
# ```
#
# This will unpack the tuple so that it actually executes as:
# ```(python)
# s = sum(1, 2)
# ```
#
# The double star `**` does the same, only using a dictionary and thus named arguments:
# ```(python)
# values = { 'a': 1, 'b': 2 }
# s = sum(**values)
# ```
#
# A python `frozenset` is just an immutable version of a Python set object.
#
# While elements of a set can be modified at any time, elements of frozen set remains the same after creation.
#
# So, frozen sets can be used as keys in a sictionary or as element of another set.
#
# `read_data` below reads files page by page (`\n\n`), then line by line (`\n`), uses the first line of a page as a key to an ordered dictionary, with the values being a zipper made out of words and POS tags. It accomodates the syntax of the [Brown corpus](https://en.wikipedia.org/wiki/Brown_Corpus), pictured here below.
#
# <br />
# <center>
# <img src="images/brown.png" width=300 />
#     Header of Brown corpus
# </center>

# %%
filename = "./test.txt"
tags_file = "./pos-tagging-brown/tags-universal.txt"
# tags_file = "./tags.txt"
txt_file = "./pos-tagging-brown/brown-universal.txt"
# txt_file = "./newfile.txt"

# %%
with open(filename,'r') as test:
    a = list(test.read().split("\n"))
    with open('./newfile.txt','w') as w_f:
        index = 0
        id = 0
        for str_file in a:
            if not str_file.split("\t")[0]==' ':
                if index == 20:
                    w_f.write(str_file+"\n\n")
                    w_f.write(str(id)+'\n')
                    index=0
                else:
                    w_f.write(str_file+"\n")
                index+=1
                id+=1

# %%
def read_data(filename):
    """Read tagged sentence data"""
    with open(filename, 'r', encoding = 'UTF-8') as f:
        sentence_lines = [l.split("\n") for l in f.read().split("\n\n")]
    return OrderedDict(((s[0], Sentence(*zip(*[l.strip().split("\t") for l in s[1:]]))) for s in sentence_lines if s[0]))

def read_tags(filename):
    """Read a list of word tag classes"""
    with open(filename, 'r', encoding = 'UTF-8') as f:
        tags = f.read().split("\n")
    return frozenset(tags)

Sentence = namedtuple("Sentence", "words tags")

# %% [markdown]
# Let's read in the Brown corpus to see if our python code works out:

# %%
tagset = read_tags(tags_file)
sentences = read_data(txt_file)
sentences
# Out:
# OrderedDict([('b100-5507',
#               Sentence(words=('Mr.', 'Podger', 'had', 'thanked', 'him', 'gravely', ',', 'and', 'now', 'he', 'made', 'use', 'of', 'the', 'advice', '.'), tags=('NOUN', 'NOUN', 'VERB', 'VERB', 'PRON', 'ADV', '.', 'CONJ', 'ADV', 'PRON', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', '.'))),
#              ('b100-935',
#               Sentence(words=('But', 'there', 'seemed', 'to', 'be', 'some', 'difference', 'of', 'opinion', 'as', 'to', 'how', 'far', 'the', 'board', 'should', 'go', ',', 'and', 'whose', 'advice', 'it', 'should', 'follow', '.'), tags=('CONJ', 'PRT', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'ADP', 'ADV', 'ADV', 'DET', 'NOUN', 'VERB', 'VERB', '.', 'CONJ', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', '.'))),
#              ('b100-30614',
#               Sentence(words=('Such', 'an', 'instrument', 'is', 'expected', 'to', 'be', 'especially', 'useful', 'if', 'it', 'could', 'be', 'used', 'to', 'measure', 'the', 'elasticity', 'of', 'heavy', 'pastes', 'such', 'as', 'printing', 'inks', ',', 'paints', ',', 'adhesives', ',', 'molten', 'plastics', ',', 'and', 'bread', 'dough', ',', 'for', 'the', 'elasticity', 'is', 'related', 'to', 'those', 'various', 'properties', 'termed', '``', 'length', "''", ',', '``', 'shortness', "''", ',', '``', 'spinnability', "''", ',', 'etc.', ',', 'which', 'are', 'usually', 'judged', 'by', 'subjective', 'methods', 'at', 'present', '.'), tags=('PRT', 'DET', 'NOUN', 'VERB', 'VERB', 'PRT', 'VERB', 'ADV', 'ADJ', 'ADP', 'PRON', 'VERB', 'VERB', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'ADJ', 'ADP', 'VERB', 'NOUN', '.', 'NOUN', '.', 'NOUN', '.', 'ADJ', 'NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', '.', 'NOUN', '.', '.', '.', 'NOUN', '.', '.', '.', 'NOUN', '.', '.', 'ADV', '.', 'DET', 'VERB', 'ADV', 'VERB', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.'))),
#              ('b100-6250',
#               Sentence(words=('My', 'future', 'plans', 'are', 'to', 'become', 'a', 'language', 'teacher', '.'), tags=('DET', 'ADJ', 'NOUN', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'NOUN', '.'))),
#              ('b100-39560',
#               Sentence(words=('We', 'ran', 'east', 'for', 'about', 'half', 'a', 'mile', 'before', 'we', 'turned', 'back', 'to', 'the', 'road', ',', 'panting', 'from', 'the', 'effort', 'and', 'soaked', 'with', 'sweat', '.'), tags=('PRON', 'VERB', 'NOUN', 'ADP', 'ADV', 'PRT', 'DET', 'NOUN', 'ADP', 'PRON', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', 'CONJ', 'VERB', 'ADP', 'NOUN', '.'))),
#              ('b100-3367',
#               Sentence(words=('After', 'television', ',', '``', 'La', 'Dolce', 'Vita', "''", 'seems', 'as', 'harmless', 'as', 'a', 'Gray', 'Line', 'tour', 'of', 'North', 'Beach', 'at', 'night', '.'), tags=('ADP', 'NOUN', '.', '.', 'X', 'X', 'X', '.', 'VERB', 'ADV', 'ADJ', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.'))),
#              ('b100-3565',
#               Sentence(words=('It', 'would', 'give', 'him', 'an', 'opportunity', 'to', 'take', 'the', 'measure', 'of', 'his', 'chief', 'adversary', 'in', 'the', 'cold', 'war', ',', 'to', 'try', 'to', 'probe', 'Mr.', "Khrushchev's", 'intentions', 'and', 'to', 'make', 'clear', 'his', 'own', 'views', '.'), tags=('PRON', 'VERB', 'VERB', 'PRON', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'PRT', 'VERB', 'PRT', 'VERB', 'NOUN', 'NOUN', 'NOUN', 'CONJ', 'PRT', 'VERB', 'ADJ', 'DET', 'ADJ', 'NOUN', '.'))),
#              ('b100-48585',
#               Sentence(words=('She', 'had', 'to', 'move', 'in', 'some', 'direction', '--', 'any', 'direction', 'that', 'would', 'take', 'her', 'away', 'from', 'this', 'evil', 'place', '.'), tags=('PRON', 'VERB', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', '.', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', 'PRON', 'ADV', 'ADP', 'DET', 'ADJ', 'NOUN', '.'))),
#              ('b100-24517',
#               Sentence(words=('English', 'philosopher', 'Samuel', "Alexander's", 'debt', 'to', 'Wordsworth', 'and', 'Meredith', 'is', 'a', 'recent', 'interesting', 'example', ',', 'as', 'also', 'A.', 'N.', "Whitehead's", 'understanding', 'of', 'the', 'English', 'romantics', ',', 'chiefly', 'Shelley', 'and', 'Wordsworth', '.'), tags=('ADJ', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'DET', 'ADJ', 'ADJ', 'NOUN', '.', 'ADP', 'ADV', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADV', 'NOUN', 'CONJ', 'NOUN', '.'))),
#              ('b100-22340',
#               Sentence(words=('So', 'we', 'are', 'faced', 'with', 'a', 'vast', 'network', 'of', 'amorphous', 'entities', 'perpetuating', 'themselves', 'in', 'whatever', 'manner', 'they', 'can', ',', 'without', 'regard', 'to', 'the', 'needs', 'of', 'society', ',', 'controlling', 'society', 'and', 'forcing', 'upon', 'it', 'a', 'regime', 'representing', 'only', 'the', "corporation's", 'needs', 'for', 'survival', '.'), tags=('ADV', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'VERB', 'PRON', 'ADP', 'DET', 'NOUN', 'PRON', 'VERB', '.', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'VERB', 'NOUN', 'CONJ', 'VERB', 'ADP', 'PRON', 'DET', 'NOUN', 'VERB', 'ADV', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.'))),
#              ('b100-27528',
#               Sentence(words=('First', ',', 'we', 'can', 'encourage', 'responsibility', 'by', 'establishing', 'as', 'conditions', 'for', 'assistance', 'on', 'a', 'substantial', 'and', 'sustained', 'scale', 'the', 'definition', 'of', 'objectives', 'and', 'the', 'assessment', 'of', 'costs', '.'), tags=('ADV', '.', 'PRON', 'VERB', 'VERB', 'NOUN', 'ADP', 'VERB', 'ADP', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'ADJ', 'CONJ', 'VERB', 'NOUN', 'DET', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'DET', 'NOUN', 'ADP', 'NOUN', '.'))),
#              ('b100-54920',
#               Sentence(words=('Could', 'it', 'just', 'be', ',', 'Theresa', 'wondered', ',', 'that', 'Anne', 'had', 'understood', 'only', 'too', 'well', ',', 'and', 'that', 'George', 'all', 'along', 'was', 'extraordinary', 'only', 'in', 'the', 'degree', 'to', 'which', 'he', 'was', 'dull', '?', '?'), tags=('VERB', 'PRON', 'ADV', 'VERB', '.', 'NOUN', 'VERB', '.', 'ADP', 'NOUN', 'VERB', 'VERB', 'ADV', 'ADV', 'ADV', '.', 'CONJ', 'ADP', 'NOUN', 'PRT', 'ADV', 'VERB', 'ADJ', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'PRON', 'VERB', 'ADJ', '.', '.'))),
#              ('b100-32087',
#               Sentence(words=('Since', 'Af', 'and', 'P', 'divides', 'Af', 'for', 'Af', ',', 'we', 'have', 'Af', '.'), tags=('ADP', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'NOUN', 'ADP', 'NOUN', '.', 'PRON', 'VERB', 'NOUN', '.'))),
#              ('b100-30402', Sentence(words=('1', '.'), tags=('NUM', '.'))),
#              ('b100-17866',
#               Sentence(words=('In', 'upper', 'teen', 'Jewish', 'life', ',', 'the', 'non-college', 'group', 'tends', 'to', 'have', 'a', 'sense', 'of', 'marginality', '.'), tags=('ADP', 'ADJ', 'NOUN', 'ADJ', 'NOUN', '.', 'DET', 'NOUN', 'NOUN', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', '.'))),
#              ('b100-18282',
#               Sentence(words=('One', 'tempest', 'was', 'stirred', 'up', 'last', 'March', 'when', 'Udall', 'announced', 'that', 'an', 'eight-and-a-half-foot', 'bronze', 'statue', 'of', 'William', 'Jennings', 'Bryan', ',', 'sculpted', 'by', 'the', 'late', 'Gutzon', 'Borglum', ',', 'would', 'be', 'sent', '``', 'on', 'indefinite', 'loan', "''", 'to', 'Salem', ',', 'Illinois', ',', "Bryan's", 'birthplace', '.'), tags=('NUM', 'NOUN', 'VERB', 'VERB', 'PRT', 'ADJ', 'NOUN', 'ADV', 'NOUN', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', '.', 'VERB', 'VERB', 'VERB', '.', 'ADP', 'ADJ', 'NOUN', '.', 'ADP', 'NOUN', '.', 'NOUN', '.', 'NOUN', 'NOUN', '.'))),
#              ('b100-49254',
#               Sentence(words=('You', 'killed', 'him', ',', "didn't", 'you', "''", '?', '?'), tags=('PRON', 'VERB', 'PRON', '.', 'VERB', 'PRON', '.', '.', '.'))),
#              ('b100-32471',
#               Sentence(words=('In', 'the', 'first', 'case', 'the', 'fixed', 'elements', 'within', 'each', 'pencil', 'are', 'the', 'multiple', 'secant', 'and', 'the', 'line', 'joining', 'the', 'vertex', ',', 'P', ',', 'to', 'the', 'intersection', 'of', '**zg', 'and', 'the', 'plane', 'of', 'the', 'pencil', 'which', 'does', 'not', 'lie', 'on', 'the', 'multiple', 'secant', '.'), tags=('ADP', 'DET', 'ADJ', 'NOUN', 'DET', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'DET', 'ADJ', 'NOUN', 'CONJ', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', '.', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'DET', 'VERB', 'ADV', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', '.'))),
#              ('b100-7646',
#               Sentence(words=('Before', 'you', 'let', 'loose', 'a', 'howl', 'saying', 'we', 'announced', 'its', 'coming', ',', 'not', 'once', 'but', 'several', 'times', ',', 'indeed', 'we', 'did', '.'), tags=('ADP', 'PRON', 'VERB', 'ADJ', 'DET', 'NOUN', 'VERB', 'PRON', 'VERB', 'DET', 'NOUN', '.', 'ADV', 'ADV', 'CONJ', 'ADJ', 'NOUN', '.', 'ADV', 'PRON', 'VERB', '.'))),
#              ('b100-54164',
#               Sentence(words=('``', 'Either', 'that', 'or', 'a', 'veterinarian', "''", '.'), tags=('.', 'CONJ', 'DET', 'CONJ', 'DET', 'NOUN', '.', '.'))),
#              ('b100-8161',
#               Sentence(words=('Mr.', 'Kennan', 'takes', 'careful', 'account', 'of', 'every', 'mitigating', 'circumstance', 'in', 'recalling', 'the', 'historical', 'atmosphere', 'in', 'which', 'mistaken', 'decisions', 'were', 'taken', '.'), tags=('NOUN', 'NOUN', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'VERB', 'NOUN', 'ADP', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'VERB', 'NOUN', 'VERB', 'VERB', '.'))),
#              ('b100-26988',
#               Sentence(words=('In', '1957', 'the', 'social-economic', 'approach', 'to', 'European', 'integration', 'was', 'capped', 'by', 'the', 'formation', 'among', '``', 'the', 'Six', "''", 'of', 'a', 'tariff-free', 'European', 'Common', 'Market', ',', 'and', 'Euratom', 'for', 'cooperation', 'in', 'the', 'development', 'of', 'atomic', 'energy', '.'), tags=('ADP', 'NUM', 'DET', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', '.', 'DET', 'NUM', '.', 'ADP', 'DET', 'ADJ', 'ADJ', 'ADJ', 'NOUN', '.', 'CONJ', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.'))),
#              ('b100-14776',
#               Sentence(words=('This', 'leads', 'one', 'to', 'conclude', ',', 'as', 'you', 'have', ',', 'that', 'there', 'is', 'inevitably', 'more', 'prestige', 'in', 'a', 'management', 'position', 'in', 'the', 'minds', 'of', 'our', 'people', "''", '.'), tags=('DET', 'VERB', 'NOUN', 'PRT', 'VERB', '.', 'ADP', 'PRON', 'VERB', '.', 'ADP', 'PRT', 'VERB', 'ADV', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', '.'))),
#              ('b100-40677',
#               Sentence(words=('``', 'I', 'have', 'to', 'believe', 'it', "''", '.'), tags=('.', 'PRON', 'VERB', 'PRT', 'VERB', 'PRON', '.', '.'))),
#              ('b100-56664',
#               Sentence(words=('But', 'then', ',', 'when', 'you', 'stuck', 'things', 'into', 'the', 'holes', ',', 'why', "didn't", 'they', 'come', 'right', 'out', 'again', '?', '?'), tags=('CONJ', 'ADV', '.', 'ADV', 'PRON', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'ADV', 'VERB', 'PRON', 'VERB', 'ADV', 'PRT', 'ADV', '.', '.'))),
#              ('b100-19688',
#               Sentence(words=('But', 'no', 'art', 'at', 'all', 'was', 'born', 'of', 'the', 'art', 'effort', 'in', 'the', 'early', 'movies', '.'), tags=('CONJ', 'DET', 'NOUN', 'ADP', 'PRT', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.'))),
#              ('b100-48598',
#               Sentence(words=('``', 'To', 'me', "you'll", 'always', 'be', 'the', 'girl', "o'", 'my', 'dreams', ',', "an'", 'the', 'sweetest', 'flower', 'that', 'grows', "''", '.'), tags=('.', 'ADP', 'PRON', 'PRT', 'ADV', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'CONJ', 'DET', 'ADJ', 'NOUN', 'DET', 'VERB', '.', '.'))),
#              ('b100-51679',
#               Sentence(words=('He', 'held', 'his', 'elbows', 'away', 'from', 'his', 'body', ',', 'and', 'the', 'little', 'sweet', 'potato', 'trilled', 'neatly', 'and', 'sweetly', 'as', 'he', 'tickled', 'its', 'tune-belly', '.'), tags=('PRON', 'VERB', 'DET', 'NOUN', 'ADV', 'ADP', 'DET', 'NOUN', '.', 'CONJ', 'DET', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'ADV', 'CONJ', 'ADV', 'ADP', 'PRON', 'VERB', 'DET', 'NOUN', '.'))),
#              ('b100-18',
#               Sentence(words=('The', 'jury', 'also', 'commented', 'on', 'the', 'Fulton', "ordinary's", 'court', 'which', 'has', 'been', 'under', 'fire', 'for', 'its', 'practices', 'in', 'the', 'appointment', 'of', 'appraisers', ',', 'guardians', 'and', 'administrators', 'and', 'the', 'awarding', 'of', 'fees', 'and', 'compensation', '.'), tags=('DET', 'NOUN', 'ADV', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', 'DET', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', 'CONJ', 'NOUN', 'CONJ', 'DET', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'NOUN', '.'))),
#              ('b100-53197',
#               Sentence(words=('I', "didn't", 'want', 'to', 'stir', 'things', 'up', '.'), tags=('PRON', 'VERB', 'VERB', 'PRT', 'VERB', 'NOUN', 'PRT', '.'))),
#              ('b100-46654',
#               Sentence(words=('Yet', 'there', 'was', 'some', 'precedent', 'for', 'it', '.'), tags=('ADV', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'PRON', '.'))),
#              ('b100-22827',
#               Sentence(words=('At', 'the', 'time', 'of', 'his', 'capture', 'Helion', 'had', 'on', 'his', 'person', 'a', 'sketchbook', 'he', 'had', 'bought', 'at', "Woolworth's", 'in', 'New', 'York', '.'), tags=('ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.'))),
#              ('b100-12962',
#               Sentence(words=('Nowhere', 'in', 'the', 'boat', 'do', 'the', 'frames', 'come', 'in', 'contact', 'with', 'the', 'plywood', 'planking', '.'), tags=('ADV', 'ADP', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.'))),
#              ('b100-24306',
#               Sentence(words=('Undoubtedly', ',', 'however', ',', 'the', 'significance', 'of', 'the', 'volume', 'is', 'greater', 'than', 'the', 'foregoing', 'paragraphs', 'suggest', '.'), tags=('ADV', '.', 'ADV', '.', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'ADJ', 'ADP', 'DET', 'VERB', 'NOUN', 'VERB', '.'))),
#              ('b100-12087',
#               Sentence(words=('Laguerre', 'Hanover', '(', '(', 'Tar', 'Heel-Lotus', 'Hanover', ')', ',', '2:30.3-:36.1', ';', ';'), tags=('NOUN', 'NOUN', '.', '.', 'NOUN', 'NOUN', 'NOUN', '.', '.', 'NUM', '.', '.'))),
#              ('b100-24832',
#               Sentence(words=('I', 'looked', 'from', 'her', 'to', 'him', '.'), tags=('PRON', 'VERB', 'ADP', 'PRON', 'ADP', 'PRON', '.'))),
#              ('b100-28951',
#               Sentence(words=('The', 'radioactivity', 'of', 'fallout', 'decays', 'rapidly', 'at', 'first', '.'), tags=('DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'ADV', 'ADP', 'ADV', '.'))),
#              ('b100-17491',
#               Sentence(words=('It', 'was', 'the', '7th', 'Cavalry', 'whose', 'troopers', 'were', 'charged', 'with', 'guarding', 'the', 'Imperial', 'Palace', 'of', 'the', 'Emperor', '.'), tags=('PRON', 'VERB', 'DET', 'ADJ', 'NOUN', 'DET', 'NOUN', 'VERB', 'VERB', 'ADP', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', '.'))),
#              ('b100-26657',
#               Sentence(words=('He', 'said', ',', '``', 'We', 'had', 'a', 'good', 'time', 'tonight', ',', "didn't", 'we', ',', 'Earl', "''", '?', '?'), tags=('PRON', 'VERB', '.', '.', 'PRON', 'VERB', 'DET', 'ADJ', 'NOUN', 'NOUN', '.', 'VERB', 'PRON', '.', 'NOUN', '.', '.', '.'))),
#              ('b100-23915',
#               Sentence(words=('As', 'notable', 'examples', 'of', 'this', 'abuse', ',', 'he', 'quotes', 'passages', 'from', 'the', 'Examiner', ',', '``', 'that', 'Destroyer', 'of', 'all', 'things', "''", ',', 'and', 'The', 'Character', 'of', 'Richard', 'Steele', ',', 'which', 'he', 'here', 'attributes', 'to', 'Swift', '.'), tags=('ADP', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'PRON', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', '.', '.', 'DET', 'NOUN', 'ADP', 'PRT', 'NOUN', '.', '.', 'CONJ', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'DET', 'PRON', 'ADV', 'VERB', 'ADP', 'NOUN', '.'))),
#              ('b100-1559',
#               Sentence(words=('The', 'truth', 'is', ',', 'though', ',', 'that', 'men', 'react', 'differently', 'to', 'different', 'treatment', '.'), tags=('DET', 'NOUN', 'VERB', '.', 'ADV', '.', 'ADP', 'NOUN', 'VERB', 'ADV', 'ADP', 'ADJ', 'NOUN', '.'))),
#              ('b100-17192',
#               Sentence(words=('Robert', 'E.', 'Lee', 'represented', 'the', 'dignity', 'needed', 'by', 'a', 'rebelling', 'confederacy', '.'), tags=('NOUN', 'NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'VERB', 'ADP', 'DET', 'VERB', 'NOUN', '.'))),
#              ('b100-30492',
#               Sentence(words=('Heat', 'transfer', 'by', 'molecular', 'conduction', 'as', 'well', 'as', 'by', 'radiation', 'from', 'the', 'arc', 'column', '.'), tags=('NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'ADV', 'ADV', 'ADP', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.'))),
#              ('b100-28020',
#               Sentence(words=('Since', 'accurate', 'base', 'maps', 'are', 'necessary', 'for', 'any', 'planning', 'program', ',', 'the', 'first', 'step', 'taken', 'by', 'the', 'planning', 'division', 'to', 'implement', 'the', 'long-range', 'state', 'plan', 'has', 'been', 'to', 'prepare', 'two', 'series', 'of', 'base', 'maps', '--', 'one', 'at', 'a', 'scale', 'of', '1', 'inch', 'to', 'a', 'mile', ',', 'and', 'the', 'second', 'a', 'series', 'of', '26', 'sheets', 'at', 'a', 'scale', 'of', '1', 'inch', 'to', '2000', 'feet', ',', 'covering', 'the', 'entire', 'state', '.'), tags=('ADP', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'ADJ', 'ADP', 'DET', 'VERB', 'NOUN', '.', 'DET', 'ADJ', 'NOUN', 'VERB', 'ADP', 'DET', 'VERB', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'VERB', 'PRT', 'VERB', 'NUM', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.', 'NUM', 'ADP', 'DET', 'NOUN', 'ADP', 'NUM', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'CONJ', 'DET', 'ADJ', 'DET', 'NOUN', 'ADP', 'NUM', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NUM', 'NOUN', 'ADP', 'NUM', 'NOUN', '.', 'VERB', 'DET', 'ADJ', 'NOUN', '.'))),
#              ('b100-4501',
#               Sentence(words=('Hong', 'Kong', ',', 'India', 'and', 'Pakistan', 'have', 'been', 'limiting', 'exports', 'of', 'certain', 'types', 'of', 'textiles', 'to', 'Britain', 'for', 'several', 'years', 'under', 'the', '``', 'Lancashire', 'Pact', "''", '.'), tags=('NOUN', 'NOUN', '.', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'VERB', 'VERB', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'ADP', 'DET', '.', 'NOUN', 'NOUN', '.', '.'))),
#              ('b100-21383',
#               Sentence(words=('One', 'day', 'the', 'dogs', 'of', 'Ireland', 'will', 'do', 'that', 'too', 'and', 'perhaps', 'also', 'the', 'pigs', "''", '.'), tags=('NUM', 'NOUN', 'DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'DET', 'ADV', 'CONJ', 'ADV', 'ADV', 'DET', 'NOUN', '.', '.'))),
#              ('b100-48246',
#               Sentence(words=('The', 'big', 'fans', 'were', 'going', ',', 'drawing', 'from', 'the', 'large', 'room', 'the', 'remnants', 'of', 'stale', 'smoke', 'which', 'drifted', 'about', 'in', 'pale', 'strata', 'underneath', 'the', 'ceiling', '.'), tags=('DET', 'ADJ', 'NOUN', 'VERB', 'VERB', '.', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'DET', 'VERB', 'ADV', 'ADP', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', '.'))),
#              ('b100-16901',
#               Sentence(words=('He', 'had', 'obtained', 'and', 'provisioned', 'a', 'veteran', 'ship', 'called', 'the', 'Discovery', 'and', 'had', 'recruited', 'a', 'crew', 'of', 'twenty-one', ',', 'the', 'largest', 'he', 'had', 'ever', 'commanded', '.'), tags=('PRON', 'VERB', 'VERB', 'CONJ', 'VERB', 'DET', 'ADJ', 'NOUN', 'VERB', 'DET', 'NOUN', 'CONJ', 'VERB', 'VERB', 'DET', 'NOUN', 'ADP', 'NUM', '.', 'DET', 'ADJ', 'PRON', 'VERB', 'ADV', 'VERB', '.'))),
#              ('b100-31862',
#               Sentence(words=('The', 'nuclei', 'of', 'these', 'fibers', ',', 'as', 'is', 'shown', 'in', 'Figures', '3', 'and', '4', ',', 'showed', 'remarkable', 'proliferation', 'and', 'were', 'closely', 'approximated', ',', 'forming', 'a', 'chainlike', 'structure', 'at', 'either', 'the', 'center', 'or', 'the', 'periphery', 'of', 'the', 'fiber', '.'), tags=('DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'VERB', 'VERB', 'ADP', 'NOUN', 'NUM', 'CONJ', 'NUM', '.', 'VERB', 'ADJ', 'NOUN', 'CONJ', 'VERB', 'ADV', 'VERB', '.', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'CONJ', 'DET', 'NOUN', 'CONJ', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.'))),
#              ('b100-31528',
#               Sentence(words=('The', 'presence', 'of', 'normally', 'occurring', 'bronchial', 'artery-pulmonary', 'artery', 'anastomoses', 'was', 'first', 'noted', 'in', '1721', 'by', 'Ruysch', ',', 'and', 'thereafter', 'by', 'many', 'others', '.'), tags=('DET', 'NOUN', 'ADP', 'ADV', 'VERB', 'ADJ', 'ADJ', 'NOUN', 'NOUN', 'VERB', 'ADV', 'VERB', 'ADP', 'NUM', 'ADP', 'NOUN', '.', 'CONJ', 'ADV', 'ADP', 'ADJ', 'NOUN', '.'))),
#              ('b100-31072',
#               Sentence(words=('Much', 'information', 'has', 'been', 'gathered', 'relative', 'to', 'quantitative', 'sampling', 'and', 'assesment', 'techniques', '.'), tags=('ADJ', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADJ', 'ADP', 'ADJ', 'NOUN', 'CONJ', 'NOUN', 'NOUN', '.'))),
#              ('b100-11067',
#               Sentence(words=('But', 'most', 'disturbing', 'of', 'all', 'were', 'the', 'advisers', 'he', 'called', 'to', 'sit', 'with', 'him', 'in', 'the', 'Palace', ';', ';'), tags=('CONJ', 'ADV', 'ADJ', 'ADP', 'PRT', 'VERB', 'DET', 'NOUN', 'PRON', 'VERB', 'PRT', 'VERB', 'ADP', 'PRON', 'ADP', 'DET', 'NOUN', '.', '.'))),
#              ('b100-3326', Sentence(words=('Precise',), tags=('ADJ',))),
#              ('b100-33638',
#               Sentence(words=('This', 'may', 'both', 'divert', 'the', 'attention', 'of', 'the', 'uninitiate', 'and', 'cause', 'confusion', 'for', 'the', 'more', 'knowledgeable', '.'), tags=('DET', 'VERB', 'DET', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'VERB', 'NOUN', 'ADP', 'DET', 'ADV', 'ADJ', '.'))),
#              ('b100-34816', Sentence(words=('6', '.'), tags=('NUM', '.'))),
#              ('b100-32135',
#               Sentence(words=(')', 'Now', 'Af', 'is', 'a', 'diagonalizable', 'operator', 'which', 'is', 'also', 'nilpotent', '.'), tags=('.', 'ADV', 'NOUN', 'VERB', 'DET', 'ADJ', 'NOUN', 'DET', 'VERB', 'ADV', 'ADJ', '.'))),
#              ('b100-41718',
#               Sentence(words=('He', "don't", 'care', 'about', 'anybody', '.'), tags=('PRON', 'VERB', 'VERB', 'ADP', 'NOUN', '.'))),
#              ('b100-521',
#               Sentence(words=('``', 'We', 'have', 'witnessed', 'in', 'this', 'campaign', 'the', 'effort', 'to', 'project', 'Mr.', 'Mitchell', 'as', 'the', 'image', 'of', 'a', 'unity', 'candidate', 'from', 'Washington', '.'), tags=('.', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'DET', 'NOUN', 'PRT', 'VERB', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.'))),
#              ('b100-25197',
#               Sentence(words=('This', 'was', 'the', 'crassest', 'kind', 'of', 'materialism', 'and', 'they', ',', 'the', 'Artists', ',', 'would', 'have', 'no', 'truck', 'with', 'it', '.'), tags=('DET', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'PRON', '.', 'DET', 'NOUN', '.', 'VERB', 'VERB', 'DET', 'NOUN', 'ADP', 'PRON', '.'))),
#              ('b100-22728',
#               Sentence(words=("It's", 'easy', 'to', 'see', 'why', '.'), tags=('PRT', 'ADJ', 'PRT', 'VERB', 'ADV', '.'))),
#              ('b100-15251',
#               Sentence(words=('If', 'you', 'wish', 'to', 'budget', 'closely', 'on', 'transportation', ',', 'saving', 'your', 'extra', 'dollars', 'to', 'indulge', 'in', 'luxuries', ',', 'one', 'agency', 'lists', 'the', 'small', 'Fiat', '500', 'at', 'only', '$1.26', 'a', 'day', 'plus', '$.03', 'a', 'kilometer', 'and', 'the', 'Fiat', '2100', 'Station', 'Wagon', ',', 'seating', 'six', ',', 'at', 'just', '$1.10', 'a', 'day', 'and', '$.105', 'a', 'kilometer', '.'), tags=('ADP', 'PRON', 'VERB', 'PRT', 'VERB', 'ADV', 'ADP', 'NOUN', '.', 'VERB', 'DET', 'ADJ', 'NOUN', 'PRT', 'VERB', 'ADP', 'NOUN', '.', 'NUM', 'NOUN', 'VERB', 'DET', 'ADJ', 'NOUN', 'NUM', 'ADP', 'ADV', 'NOUN', 'DET', 'NOUN', 'CONJ', 'NOUN', 'DET', 'NOUN', 'CONJ', 'DET', 'NOUN', 'NUM', 'NOUN', 'NOUN', '.', 'VERB', 'NUM', '.', 'ADP', 'ADV', 'NOUN', 'DET', 'NOUN', 'CONJ', 'NOUN', 'DET', 'NOUN', '.'))),
#              ('b100-41630',
#               Sentence(words=('``', 'The', "kid's", 'froze', 'good', '.'), tags=('.', 'DET', 'PRT', 'VERB', 'ADV', '.'))),
#              ('b100-9608',
#               Sentence(words=('But', 'how', 'can', 'one', 'figure', 'symbolize', 'both', '?', '?'), tags=('CONJ', 'ADV', 'VERB', 'NUM', 'VERB', 'VERB', 'DET', '.', '.'))),
#              ('b100-3554',
#               Sentence(words=('Thus', 'when', 'Premier', 'Khrushchev', 'intimated', 'even', 'before', 'inauguration', 'that', 'he', 'hoped', 'for', 'an', 'early', 'meeting', 'with', 'the', 'new', 'President', ',', 'Mr.', 'Kennedy', 'was', 'confronted', 'with', 'a', 'delicate', 'problem', '.'), tags=('ADV', 'ADV', 'NOUN', 'NOUN', 'VERB', 'ADV', 'ADP', 'NOUN', 'ADP', 'PRON', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', '.'))),
#              ('b100-32931',
#               Sentence(words=('These', 'are', 'as', 'follows', ':', '(', '1', ')', 'field', 'work', 'procedures', '.'), tags=('DET', 'VERB', 'ADV', 'VERB', '.', '.', 'NUM', '.', 'NOUN', 'NOUN', 'NOUN', '.'))),
#              ('b100-31368',
#               Sentence(words=('Felix', 'Kopstein', 'states', 'that', '``', 'when', 'the', 'snake', 'reaches', 'its', 'maturity', 'it', 'has', 'already', 'reached', 'about', 'its', 'maximal', 'length', "''", ',', 'but', 'goes', 'on', 'to', 'cite', 'the', 'reticulate', 'python', 'as', 'an', 'exception', ',', 'with', 'maximum', 'length', 'approximately', 'three', 'times', 'that', 'at', 'maturity', '.'), tags=('NOUN', 'NOUN', 'VERB', 'ADP', '.', 'ADV', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', 'PRON', 'VERB', 'ADV', 'VERB', 'ADV', 'DET', 'ADJ', 'NOUN', '.', '.', 'CONJ', 'VERB', 'PRT', 'PRT', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'ADJ', 'NOUN', 'ADV', 'NUM', 'NOUN', 'DET', 'ADP', 'NOUN', '.'))),
#              ('b100-43093',
#               Sentence(words=('He', 'went', 'around', 'the', 'corner', 'and', 'parked', ',', 'turning', 'off', 'his', 'lights', 'and', 'motor', '.'), tags=('PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'CONJ', 'VERB', '.', 'VERB', 'PRT', 'DET', 'NOUN', 'CONJ', 'NOUN', '.'))),
#              ('b100-52936',
#               Sentence(words=('If', 'she', 'could', 'not', 'take', 'the', 'children', 'out', 'of', 'this', 'section', ',', 'at', 'least', 'she', 'could', 'take', 'other', 'children', 'out', 'of', 'their', 'countries', 'and', 'put', 'them', 'on', 'the', 'farms', '.'), tags=('ADP', 'PRON', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'ADP', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'ADJ', 'PRON', 'VERB', 'VERB', 'ADJ', 'NOUN', 'ADP', 'ADP', 'DET', 'NOUN', 'CONJ', 'VERB', 'PRON', 'ADP', 'DET', 'NOUN', '.'))),
#              ('b100-29078',
#               Sentence(words=('Under', 'its', 'plan', 'Du', 'Pont', 'would', 'retain', 'its', 'General', 'Motors', 'shares', 'but', 'be', 'required', 'to', 'pass', 'on', 'to', 'its', 'stockholders', 'the', 'right', 'to', 'vote', 'those', 'shares', '.'), tags=('ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'VERB', 'DET', 'NOUN', 'NOUN', 'NOUN', 'CONJ', 'VERB', 'VERB', 'PRT', 'VERB', 'PRT', 'ADP', 'DET', 'NOUN', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', '.'))),
#              ('b100-48045',
#               Sentence(words=('his', 'eyes', 'were', 'black', 'and', 'deep-set', ',', 'and', 'expressionless', '.'), tags=('DET', 'NOUN', 'VERB', 'ADJ', 'CONJ', 'ADJ', '.', 'CONJ', 'ADJ', '.'))),
#              ('b100-13233',
#               Sentence(words=('It', 'is', 'one', 'of', 'the', 'very', 'few', ',', 'if', 'not', 'the', 'only', 'surviving', 'bridge', 'of', 'its', 'type', 'to', 'serve', 'a', 'main', 'artery', 'of', 'the', 'U.S.', 'highway', 'system', ',', 'thus', 'it', 'is', 'far', 'more', 'than', 'a', 'relic', 'of', 'the', 'horse', 'and', 'buggy', 'days', '.'), tags=('PRON', 'VERB', 'NUM', 'ADP', 'DET', 'ADV', 'ADJ', '.', 'ADP', 'ADV', 'DET', 'ADJ', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', '.', 'ADV', 'PRON', 'VERB', 'ADV', 'ADJ', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'NOUN', 'NOUN', '.'))),
#              ('b100-26874',
#               Sentence(words=('The', 'promise', 'that', 'the', 'lion', 'and', 'the', 'lamb', 'will', 'lie', 'down', 'together', 'was', 'given', 'in', 'the', 'future', 'tense', '.'), tags=('DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'DET', 'NOUN', 'VERB', 'VERB', 'PRT', 'ADV', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', '.'))),
#              ('b100-51004',
#               Sentence(words=('``', 'But', "that's", 'what', 'he', 'told', 'me', '.'), tags=('.', 'CONJ', 'PRT', 'DET', 'PRON', 'VERB', 'PRON', '.'))),
#              ('b100-18813',
#               Sentence(words=('The', 'common', 'spices', ',', 'flavorings', ',', 'and', 'condiments', 'make', 'up', 'this', 'group', '.'), tags=('DET', 'ADJ', 'NOUN', '.', 'NOUN', '.', 'CONJ', 'NOUN', 'VERB', 'PRT', 'DET', 'NOUN', '.'))),
#              ('b100-20637',
#               Sentence(words=('The', 'values', 'and', 'talents', 'which', 'made', 'the', 'tile', 'and', 'the', 'dome', ',', 'the', 'rug', ',', 'the', 'poem', 'and', 'the', 'miniature', ',', 'continue', 'in', 'certain', 'social', 'institutions', 'which', 'rise', 'above', 'the', 'ordinary', 'life', 'of', 'this', 'city', ',', 'as', 'the', 'great', 'buildings', 'rise', 'above', 'blank', 'walls', 'and', 'dirty', 'lanes', '.'), tags=('DET', 'NOUN', 'CONJ', 'NOUN', 'DET', 'VERB', 'DET', 'NOUN', 'CONJ', 'DET', 'NOUN', '.', 'DET', 'NOUN', '.', 'DET', 'NOUN', 'CONJ', 'DET', 'NOUN', '.', 'VERB', 'ADP', 'ADJ', 'ADJ', 'NOUN', 'DET', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', 'ADP', 'ADJ', 'NOUN', 'CONJ', 'ADJ', 'NOUN', '.'))),
#              ('b100-21384',
#               Sentence(words=('But', 'do', 'the', 'plays', 'deal', 'with', 'the', 'same', 'facets', 'of', 'experience', 'religion', 'must', 'also', 'deal', 'with', '?', '?'), tags=('CONJ', 'VERB', 'DET', 'NOUN', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'VERB', 'ADV', 'VERB', 'ADP', '.', '.'))),
#              ('b100-3041',
#               Sentence(words=('Called', 'Perennian', ',', 'to', 'indicate', 'its', 'lasting', ',', 'good', 'today', 'and', 'tomorrow', 'quality', ',', 'the', 'collection', 'truly', 'avoids', 'the', 'monotony', 'of', 'identical', 'pieces', '.'), tags=('VERB', 'ADJ', '.', 'PRT', 'VERB', 'DET', 'VERB', '.', 'ADJ', 'NOUN', 'CONJ', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', 'ADV', 'VERB', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.'))),
#              ('b100-56440',
#               Sentence(words=('It', 'had', 'a', "gourmet's", 'corner', '(', 'instead', 'of', 'a', 'kitchen', ')', ',', 'a', 'breakfast', 'room', ',', 'a', 'luncheon', 'room', ',', 'a', 'dining', 'room', ',', 'a', 'sitting', 'room', ',', 'a', 'room', 'for', 'standing', 'up', ',', 'a', 'party', 'room', ',', 'dressing', 'rooms', 'for', 'everybody', ',', 'even', 'a', 'room', 'for', 'mud', '.'), tags=('PRON', 'VERB', 'DET', 'NOUN', 'NOUN', '.', 'ADV', 'ADP', 'DET', 'NOUN', '.', '.', 'DET', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', 'NOUN', '.', 'DET', 'VERB', 'NOUN', '.', 'DET', 'VERB', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'VERB', 'PRT', '.', 'DET', 'NOUN', 'NOUN', '.', 'VERB', 'NOUN', 'ADP', 'NOUN', '.', 'ADV', 'DET', 'NOUN', 'ADP', 'NOUN', '.'))),
#              ('b100-39943',
#               Sentence(words=('``', 'Few', 'crank', 'calls', "''", ',', 'McFeeley', 'said', '.'), tags=('.', 'ADJ', 'NOUN', 'NOUN', '.', '.', 'NOUN', 'VERB', '.'))),
#              ('b100-42617',
#               Sentence(words=('If', 'he', 'does', ',', "it's", 'still', 'better', 'than', 'an', 'even', 'chance', 'he', "won't", 'notice', 'the', 'transposition', 'of', 'the', 'numbers', ',', 'and', 'if', 'he', 'should', 'notice', 'it', ',', 'the', 'thing', 'can', 'be', 'passed', 'off', 'as', 'an', 'honest', 'mistake', '.'), tags=('ADP', 'PRON', 'VERB', '.', 'PRT', 'ADV', 'ADJ', 'ADP', 'DET', 'ADJ', 'NOUN', 'PRON', 'VERB', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'CONJ', 'ADP', 'PRON', 'VERB', 'VERB', 'PRON', '.', 'DET', 'NOUN', 'VERB', 'VERB', 'VERB', 'PRT', 'ADP', 'DET', 'ADJ', 'NOUN', '.'))),
#              ('b100-17349',
#               Sentence(words=('The', 'most', 'infamous', 'of', 'all', 'was', 'launched', 'by', 'the', 'explosion', 'of', 'the', 'island', 'of', 'Krakatoa', 'in', '1883', ';', ';'), tags=('DET', 'ADV', 'ADJ', 'ADP', 'PRT', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NUM', '.', '.'))),
#              ('b100-10144',
#               Sentence(words=('What', 'about', 'transfers', '?', '?'), tags=('DET', 'ADP', 'NOUN', '.', '.'))),
#              ('b100-5596',
#               Sentence(words=('This', 'angle', 'of', 'just', 'where', 'the', 'Orioles', 'can', 'look', 'for', 'improvement', 'this', 'year', 'is', 'an', 'interesting', 'one', '.'), tags=('DET', 'NOUN', 'ADP', 'ADV', 'ADV', 'DET', 'NOUN', 'VERB', 'VERB', 'ADP', 'NOUN', 'DET', 'NOUN', 'VERB', 'DET', 'ADJ', 'NUM', '.'))),
#              ('b100-19428', Sentence(words=(')',), tags=('.',))),
#              ('b100-21509',
#               Sentence(words=('Under', 'the', 'influence', 'of', 'marijuana', 'the', 'beatnik', 'comes', 'alive', 'within', 'and', 'experiences', 'a', 'wonderfully', 'enhanced', 'sense', 'of', 'self', 'as', 'if', 'he', 'had', 'discovered', 'the', 'open', 'sesame', 'to', 'the', 'universe', 'of', 'being', '.'), tags=('ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'DET', 'NOUN', 'VERB', 'ADJ', 'ADP', 'CONJ', 'VERB', 'DET', 'ADV', 'VERB', 'NOUN', 'ADP', 'NOUN', 'ADP', 'ADP', 'PRON', 'VERB', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'VERB', '.'))),
#              ('b100-55586',
#               Sentence(words=('She', 'asked', 'him', 'and', ',', 'laughing', ',', 'she', 'added', ',', '``', 'I', 'was', 'nervous', 'about', 'buying', 'a', 'book', 'with', 'a', 'title', 'like', 'that', ',', 'but', 'I', 'knew', "you'd", 'like', 'it', "''", '.'), tags=('PRON', 'VERB', 'PRON', 'CONJ', '.', 'VERB', '.', 'PRON', 'VERB', '.', '.', 'PRON', 'VERB', 'ADJ', 'ADP', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', '.', 'CONJ', 'PRON', 'VERB', 'PRT', 'VERB', 'PRON', '.', '.'))),
#              ('b100-47744',
#               Sentence(words=('At', 'the', 'same', 'moment', 'Wheeler', 'Fiske', 'fired', 'the', 'rifle', 'Mike', 'had', 'given', 'him', 'and', 'another', 'guerrilla', 'was', 'hit', '.'), tags=('ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'NOUN', 'VERB', 'VERB', 'PRON', 'CONJ', 'DET', 'NOUN', 'VERB', 'VERB', '.'))),
#              ('b100-51300',
#               Sentence(words=('``', 'And', 'what', 'makes', 'you', 'think', "you're", 'going', 'to', 'get', 'it', ',', 'pretty', 'boy', "''", '?', '?'), tags=('.', 'CONJ', 'DET', 'VERB', 'PRON', 'VERB', 'PRT', 'VERB', 'PRT', 'VERB', 'PRON', '.', 'ADJ', 'NOUN', '.', '.', '.'))),
#              ('b100-45653',
#               Sentence(words=('``', 'Certainly', ',', 'sir', "''", '.'), tags=('.', 'ADV', '.', 'NOUN', '.', '.'))),
#              ('b100-49047',
#               Sentence(words=('Later', ',', 'riding', 'in', 'for', 'some', 'lusty', 'enjoyment', 'of', 'the', 'liquor', 'and', 'professional', 'ladies', 'of', 'Cheyenne', ',', 'he', 'laid', 'claim', 'to', 'the', 'killing', 'with', 'the', 'vague', 'insinuations', 'he', 'made', '.'), tags=('ADV', '.', 'VERB', 'PRT', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', 'PRON', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'PRON', 'VERB', '.'))),
#              ('b100-24085',
#               Sentence(words=('It', 'was', 'said', 'that', 'the', 'Hetman', 'plotted', 'to', 'take', 'over', 'the', 'entire', 'Hearst', 'newspaper', 'empire', 'one', 'day', 'by', 'means', 'of', 'various', 'coups', ':', 'the', 'destruction', 'of', 'editors', 'who', 'tried', 'to', 'halt', 'his', 'course', ',', 'the', 'unfrocking', 'of', 'publishers', 'whose', 'mistakes', 'of', 'judgment', 'might', 'be', 'magnified', 'in', 'secret', 'reports', 'to', 'Mr.', 'Hearst', '.'), tags=('PRON', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'VERB', 'PRT', 'VERB', 'PRT', 'DET', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'NUM', 'NOUN', 'ADP', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', 'PRON', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', 'DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.'))),
#              ('b100-24178',
#               Sentence(words=('Mama', 'always', 'felt', 'that', 'the', 'collection', 'symbolized', 'Mrs.', "Coolidge's", 'wish', 'for', 'a', 'little', 'girl', '.'), tags=('NOUN', 'ADV', 'VERB', 'ADP', 'DET', 'NOUN', 'VERB', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.'))),
#              ('b100-57206',
#               Sentence(words=('We', 'would', 'have', 'preferred', ',', 'however', ',', 'to', 'have', 'had', 'the', 'rest', 'of', 'the', 'orchestra', 'refrain', 'from', 'laughing', 'at', 'this', 'and', 'other', 'spots', 'on', 'the', 'recording', ',', 'since', 'it', 'mars', 'an', 'otherwise', 'sober', ',', 'if', 'not', 'lofty', ',', 'performance', '.'), tags=('PRON', 'VERB', 'VERB', 'VERB', '.', 'ADV', '.', 'PRT', 'VERB', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'ADP', 'VERB', 'ADP', 'DET', 'CONJ', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'PRON', 'VERB', 'DET', 'ADV', 'ADJ', '.', 'ADP', 'ADV', 'ADJ', '.', 'NOUN', '.'))),
#              ('b100-7251',
#               Sentence(words=('Their', 'burgeoning', 'popularity', 'may', 'be', 'a', 'result', 'of', 'the', 'closing', 'of', 'the', '52nd', 'Street', 'burlesque', 'joints', ',', 'but', 'curiously', 'enough', 'their', 'atmosphere', 'is', 'almost', 'always', 'familial', '--', 'neighborhood', 'saloons', 'with', 'a', 'bit', 'of', 'epidermis', '.'), tags=('DET', 'VERB', 'NOUN', 'VERB', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', 'NOUN', '.', 'CONJ', 'ADV', 'ADV', 'DET', 'NOUN', 'VERB', 'ADV', 'ADV', 'ADJ', '.', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.'))),
#              ('b100-56028',
#               Sentence(words=('He', 'swung', 'around', ',', 'eyes', 'toward', 'the', 'bedroom', ',', 'some', 'fifteen', 'feet', 'away', '.'), tags=('PRON', 'VERB', 'ADV', '.', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'DET', 'NUM', 'NOUN', 'ADV', '.'))),
#              ('b100-31139',
#               Sentence(words=('It', 'is', 'possible', 'that', 'certain', 'mutational', 'forms', 'may', 'be', 'produced', 'such', 'as', 'antibiotic', 'resistant', 'strains', '.'), tags=('PRON', 'VERB', 'ADJ', 'ADP', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADJ', 'ADP', 'NOUN', 'ADJ', 'NOUN', '.'))),
#              ('b100-50636',
#               Sentence(words=('Few', 'passed', "''", '.'), tags=('ADJ', 'VERB', '.', '.'))),
#              ('b100-14417',
#               Sentence(words=('An', 'examination', 'of', 'some', 'forty', 'catalogs', 'of', 'schools', 'offering', 'courses', 'in', 'interior', 'design', ',', 'for', 'the', 'most', 'part', 'schools', 'accredited', 'by', 'membership', 'in', 'the', 'National', 'Association', 'of', 'Schools', 'of', 'Art', ',', 'and', 'a', 'further', '``', 'on', 'the', 'spot', "''", 'inspection', 'of', 'a', 'number', 'of', 'schools', ',', 'show', 'their', 'courses', 'adhere', 'pretty', 'closely', 'to', 'the', 'recommendations', '.'), tags=('DET', 'NOUN', 'ADP', 'DET', 'NUM', 'NOUN', 'ADP', 'NOUN', 'VERB', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', 'CONJ', 'DET', 'ADJ', '.', 'ADP', 'DET', 'NOUN', '.', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'VERB', 'DET', 'NOUN', 'VERB', 'ADV', 'ADV', 'ADP', 'DET', 'NOUN', '.'))),
#              ('b100-15122',
#               Sentence(words=('It', 'changes', 'the', 'answers', 'to', '``', 'Who', 'should', 'do', 'what', ',', 'and', 'where', "''", '?', '?'), tags=('PRON', 'VERB', 'DET', 'NOUN', 'ADP', '.', 'PRON', 'VERB', 'VERB', 'DET', '.', 'CONJ', 'ADV', '.', '.', '.'))),
#              ('b100-40251',
#               Sentence(words=('the', 'clay', 'he', 'used', 'plastically', 'to', 'suggest', 'soft', 'moving', 'flesh', ',', 'as', 'in', 'an', 'abdomen', ',', 'in', 'a', 'reclining', 'torso', ';', ';'), tags=('DET', 'NOUN', 'PRON', 'VERB', 'ADV', 'PRT', 'VERB', 'ADJ', 'VERB', 'NOUN', '.', 'ADP', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'DET', 'VERB', 'NOUN', '.', '.'))),
#              ('b100-51274',
#               Sentence(words=('And', 'when', 'this', 'was', 'gone', ',', 'he', "hadn't", 'even', 'a', 'little', 'bitter', 'tablet', 'to', 'purify', 'other', 'water', 'if', 'he', 'were', 'to', 'discover', 'some', 'stagnant', 'jungle', 'pool', '.'), tags=('CONJ', 'ADV', 'DET', 'VERB', 'VERB', '.', 'PRON', 'VERB', 'ADV', 'DET', 'ADV', 'ADJ', 'NOUN', 'PRT', 'VERB', 'ADJ', 'NOUN', 'ADP', 'PRON', 'VERB', 'PRT', 'VERB', 'DET', 'ADJ', 'NOUN', 'NOUN', '.'))),
#              ('b100-24055',
#               Sentence(words=('He', 'seemed', 'timid', '(', 'at', 'first', ',', ')', 'wore', 'nose', 'glasses', 'from', 'which', 'a', 'black', 'ribbon', 'dangled', ',', 'and', 'was', 'no', 'bigger', 'than', 'a', 'jockey', '.'), tags=('PRON', 'VERB', 'ADJ', '.', 'ADP', 'ADV', '.', '.', 'VERB', 'NOUN', 'NOUN', 'ADP', 'DET', 'DET', 'ADJ', 'NOUN', 'VERB', '.', 'CONJ', 'VERB', 'ADV', 'ADJ', 'ADP', 'DET', 'NOUN', '.'))),
#              ('b100-19299',
#               Sentence(words=('In', 'the', 'adult', 'world', ',', 'there', 'are', 'a', 'number', 'of', 'rather', 'general', 'and', 'diffuse', 'sources', 'of', 'ideological', 'diffusion', 'that', 'further', 'compound', 'the', "adolescent's", 'search', 'for', 'meaning', 'during', 'this', 'particular', 'identity', 'crisis', '.'), tags=('ADP', 'DET', 'NOUN', 'NOUN', '.', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'ADV', 'ADJ', 'CONJ', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'PRON', 'ADV', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', '.'))),
#              ('b100-11836',
#               Sentence(words=('We', 'used', 'the', 'latter', 'equipped', 'with', 'a', 'carborundum', 'disk', 'about'), tags=('PRON', 'VERB', 'DET', 'ADJ', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADV'))),
#              ('b100-10533',
#               Sentence(words=('And', 'if', 'you', 'should', 'step', 'inside', 'of', 'such', 'a', 'magnified', 'atom', ',', 'according', 'to', 'the', 'physics', 'of', 'forty', 'years', 'ago', ',', 'you', 'would', 'see', 'circulating', 'over', 'your', 'head', ',', 'down', 'at', 'the', 'sides', ',', 'and', 'under', 'your', 'feet', ',', 'some', 'twenty', 'luminous', 'balls', 'about', 'the', 'size', 'of', 'footballs', '.'), tags=('CONJ', 'ADP', 'PRON', 'VERB', 'VERB', 'ADV', 'ADP', 'PRT', 'DET', 'VERB', 'NOUN', '.', 'ADP', 'ADP', 'DET', 'NOUN', 'ADP', 'NUM', 'NOUN', 'ADV', '.', 'PRON', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', '.', 'PRT', 'ADP', 'DET', 'NOUN', '.', 'CONJ', 'ADP', 'DET', 'NOUN', '.', 'DET', 'NUM', 'ADJ', 'NOUN', 'ADV', 'DET', 'NOUN', 'ADP', 'NOUN', '.'))),
#              ('b100-26960',
#               Sentence(words=('In', 'a', 'pessimistic', 'assessment', 'of', 'the', 'cold', 'war', ',', 'Eden', 'declared', ':', '``', 'There', 'must', 'be', 'much', 'closer', 'unity', 'within', 'the', 'West', 'before', 'there', 'can', 'be', 'effective', 'negotiation', 'with', 'the', 'East', "''", '.'), tags=('ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'NOUN', 'VERB', '.', '.', 'PRT', 'VERB', 'VERB', 'ADV', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'PRT', 'VERB', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', '.', '.'))),
#              ('b100-39955',
#               Sentence(words=('McFeeley', 'told', 'the', 'parents', 'he', 'would', 'escort', 'them', 'to', 'police', 'headquarters', 'in', 'a', 'half', 'hour', '.'), tags=('NOUN', 'VERB', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', 'PRON', 'ADP', 'NOUN', 'NOUN', 'ADP', 'DET', 'PRT', 'NOUN', '.'))),
#              ('b100-6994',
#               Sentence(words=('This', 'third', 'choice', 'was', 'in', 'fact', 'made', '.'), tags=('DET', 'ADJ', 'NOUN', 'VERB', 'ADP', 'NOUN', 'VERB', '.'))),
#              ('b100-35283',
#               Sentence(words=('There', 'are', 'signs', 'that', 'it', 'has', 'struggled', 'for', 'days', 'to', 'escape', 'and', 'that', 'in', 'a', 'frenzy', 'of', 'hunger', ',', 'pain', ',', 'and', 'fear', ',', 'it', 'has', 'all', 'but', 'eaten', 'off', 'its', 'own', 'leg', '.'), tags=('PRT', 'VERB', 'NOUN', 'ADP', 'PRON', 'VERB', 'VERB', 'ADP', 'NOUN', 'PRT', 'VERB', 'CONJ', 'ADP', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', '.', 'CONJ', 'NOUN', '.', 'PRON', 'VERB', 'PRT', 'ADP', 'VERB', 'PRT', 'DET', 'ADJ', 'NOUN', '.'))),
#              ('b100-37552',
#               Sentence(words=('The', 'importance', 'of', 'a', 'hard', ',', 'abrasion-resistant', 'knife', 'material', 'like', 'the', 'Carboloy', 'employed', 'in', 'the', 'Hesiometer', 'immediately', 'becomes', 'apparent', '.'), tags=('DET', 'NOUN', 'ADP', 'DET', 'ADJ', '.', 'ADJ', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'ADV', 'VERB', 'ADJ', '.'))),
#              ('b100-3822',
#               Sentence(words=('They', 'had', 'the', 'unspoken', 'support', 'of', 'President-elect', 'Kennedy', ',', 'whose', 'own', 'legislative', 'program', 'was', 'menaced', 'by', 'the', 'Rules', 'Committee', 'bottleneck', '.'), tags=('PRON', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'DET', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', '.'))),
#              ('b100-56688',
#               Sentence(words=('If', 'he', 'was', 'sober', ',', 'which', 'was', 'doubtful', ',', "he'd", 'have', 'him', 'get', 'in', 'touch', 'with', 'Mr.', 'Crombie', '.'), tags=('ADP', 'PRON', 'VERB', 'ADJ', '.', 'DET', 'VERB', 'ADJ', '.', 'PRT', 'VERB', 'PRON', 'VERB', 'ADP', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.'))),
#              ('b100-27389',
#               Sentence(words=('Product', 'research', 'and', 'development'), tags=('NOUN', 'NOUN', 'CONJ', 'NOUN'))),
#              ('b100-4261',
#               Sentence(words=('Twenty-four', 'hours', 'after', 'independence', 'the', 'wild', 'tribesmen', 'commenced', 'fighting', 'each', 'other', '.'), tags=('NUM', 'NOUN', 'ADP', 'NOUN', 'DET', 'ADJ', 'NOUN', 'VERB', 'VERB', 'DET', 'ADJ', '.'))),
#              ('b100-19895',
#               Sentence(words=('The', "congressman's", 'patriotism', 'is', 'always', 'involved', 'when', 'he', 'turns', 'upon', 'the', 'Defense', 'Department', '.'), tags=('DET', 'NOUN', 'NOUN', 'VERB', 'ADV', 'VERB', 'ADV', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', '.'))),
#              ('b100-22738',
#               Sentence(words=("Ortega's", 'hope', 'that', 'modern', 'psychology', 'might', 'yet', 'bring', 'forth', 'a', 'last', 'flowering', 'of', 'the', 'novel', 'has', 'only', 'been', 'partially', 'fulfilled', '.'), tags=('NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'VERB', 'ADV', 'VERB', 'ADV', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'ADV', 'VERB', 'ADV', 'VERB', '.'))),
#              ('b100-40142',
#               Sentence(words=('So', 'something', 'like', 'this', 'matters', 'more', 'than', 'it', 'would', 'at', 'home', '.'), tags=('ADV', 'NOUN', 'ADP', 'DET', 'VERB', 'ADV', 'ADP', 'PRON', 'VERB', 'ADP', 'NOUN', '.'))),
#              ('b100-33084',
# ...
#              ('b100-27457',
#               Sentence(words=('The', 'credit', 'requirements', 'stipulate', 'that', 'the', 'applicant', 'must', 'have', 'the', 'ability', 'to', 'operate', 'the', 'business', 'successfully', 'and', 'have', 'enough', 'capital', 'in', 'the', 'business', 'so', 'that', ',', 'with', 'loan', 'assistance', 'from', 'the', 'SBA', ',', 'it', 'will', 'be', 'able', 'to', 'operate', 'on', 'a', 'sound', 'financial', 'basis', '.'), tags=('DET', 'NOUN', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'VERB', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'ADV', 'CONJ', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'ADP', '.', 'ADP', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'PRON', 'VERB', 'VERB', 'ADJ', 'PRT', 'VERB', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', '.'))),
#              ('b100-55531',
#               Sentence(words=('``', 'I', "don't", 'get', 'it', "''", '.'), tags=('.', 'PRON', 'VERB', 'VERB', 'PRON', '.', '.'))),
#              ('b100-29540',
#               Sentence(words=('Another', 'example', 'is', 'the', 'recent', 'cancellation', 'of', 'the', 'F-108', ',', 'a', 'long-range', 'interceptor', 'with', 'a', 'speed', 'three', 'times', 'as', 'great', 'as', 'the', 'speed', 'of', 'sound', ',', 'which', 'was', 'designed', 'for', 'use', 'against', 'manned', 'bombers', 'in', 'the', 'period', 'of', 'the', "mid-1960's", '.'), tags=('DET', 'NOUN', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'NUM', 'NOUN', 'ADV', 'ADJ', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'DET', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADP', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.'))),
#              ('b100-10418',
#               Sentence(words=('This', 'narrow', '``', 'professionalism', "''", 'does', 'not', 'even', 'fit', 'the', 'present', 'realities', 'of', 'their', 'situation', ',', 'as', 'the', 'pressure', 'of', 'minorities', 'and', 'the', 'power', 'and', 'respectability', 'of', 'the', 'realtors', 'increase', '.'), tags=('DET', 'ADJ', '.', 'NOUN', '.', 'VERB', 'ADV', 'ADV', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'DET', 'NOUN', 'CONJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', '.'))),
#              ('b100-17743',
#               Sentence(words=('``', 'We', "''", 'were', 'Bill', 'Garrett', 'of', 'the', 'National', 'Geographic', 'Illustrations', 'Staff', ',', 'whose', 'three', 'cameras', 'and', 'eight', 'lenses', 'made', 'him', 'look', 'as', 'formidable', 'as', 'any', 'fighting', 'man', 'we', 'met', ';', ';'), tags=('.', 'PRON', '.', 'VERB', 'NOUN', 'NOUN', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', 'NOUN', '.', 'DET', 'NUM', 'NOUN', 'CONJ', 'NUM', 'NOUN', 'VERB', 'PRON', 'VERB', 'ADV', 'ADJ', 'ADP', 'DET', 'VERB', 'NOUN', 'PRON', 'VERB', '.', '.'))),
#              ('b100-20510',
#               Sentence(words=('Such', 'stretches', 'have', 'an', 'inhuman', 'moonlike', 'quality', '.'), tags=('ADJ', 'NOUN', 'VERB', 'DET', 'ADJ', 'ADJ', 'NOUN', '.'))),
#              ('b100-45335',
#               Sentence(words=('But', 'Graham', "hadn't", 'stumbled', 'on', 'it', '.'), tags=('CONJ', 'NOUN', 'VERB', 'VERB', 'ADP', 'PRON', '.'))),
#              ('b100-9706',
#               Sentence(words=('We', 'today', 'are', 'not', 'entitled', 'to', 'excoriate', 'honest', 'men', 'who', 'believed', 'Parker', 'to', 'be', 'downright', 'pernicious', 'and', 'who', 'barred', 'their', 'pulpits', 'against', 'his', 'demand', 'to', 'poison', 'the', 'minds', 'of', 'their', 'congregations', '.'), tags=('PRON', 'NOUN', 'VERB', 'ADV', 'VERB', 'PRT', 'VERB', 'ADJ', 'NOUN', 'PRON', 'VERB', 'NOUN', 'PRT', 'VERB', 'ADV', 'ADJ', 'CONJ', 'PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.'))),
#              ('b100-8272',
#               Sentence(words=('Snow', 'or', 'no', ',', 'the', 'fans', 'were', 'present', 'in', 'force', 'at', 'the', 'Metropolitan', 'Opera', 'last', 'night', 'for', 'a', 'performance', 'of', 'the', 'Ponchielli', 'work', '.'), tags=('NOUN', 'CONJ', 'DET', '.', 'DET', 'NOUN', 'VERB', 'ADV', 'ADP', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.'))),
#              ('b100-53846',
#               Sentence(words=('``', 'Darling', "''", '--', 'she', 'said', ',', 'and', 'the', 'single', 'word', 'mingled', 'love', 'and', 'exasperation', 'in', 'an', 'equal', 'blend', '.'), tags=('.', 'NOUN', '.', '.', 'PRON', 'VERB', '.', 'CONJ', 'DET', 'ADJ', 'NOUN', 'VERB', 'NOUN', 'CONJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.'))),
#              ('b100-33809',
#               Sentence(words=('There', 'is', 'no', 'apparent', 'reason', 'why', 'we', 'should', 'feel', 'bound', 'by', "Swadesh's", 'rules', 'and', 'procedure', 'since', 'his', 'predilections', 'and', 'aims', 'have', 'grown', 'so', 'vast', '.'), tags=('PRT', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADV', 'PRON', 'VERB', 'VERB', 'VERB', 'ADP', 'NOUN', 'NOUN', 'CONJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'VERB', 'ADV', 'ADJ', '.'))),
#              ('b100-56979',
#               Sentence(words=('``', 'There', 'was', 'also', 'Gott', 'strafe', 'Angleterre', "''", ',', 'Moreland', 'reminded', 'me', ',', '``', 'and', 'Carthago', 'delenda', 'est', ',', 'or', 'if', 'you', 'will', ',', 'Deus', 'strafe', 'Carthage', '.'), tags=('.', 'PRT', 'VERB', 'ADV', 'X', 'X', 'X', '.', '.', 'NOUN', 'VERB', 'PRON', '.', '.', 'CONJ', 'X', 'X', 'X', '.', 'CONJ', 'ADP', 'PRON', 'VERB', '.', 'X', 'X', 'NOUN', '.'))),
#              ('b100-47487',
#               Sentence(words=('The', 'two', 'horses', 'broke', 'from', 'the', 'yard', ',', 'from', 'the', 'circle', 'of', 'light', 'cast', 'by', 'the', 'lamp', 'still', 'burning', 'in', 'the', 'house', ',', 'into', 'the', 'darkness', '.'), tags=('DET', 'NUM', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'ADV', 'VERB', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'DET', 'NOUN', '.'))),
#              ('b100-47712',
#               Sentence(words=('An', 'ammunition', 'case', 'stood', 'open', ',', 'containing', 'canisters', 'which', 'contained', 'powder', 'cartridges', '.'), tags=('DET', 'NOUN', 'NOUN', 'VERB', 'ADJ', '.', 'VERB', 'NOUN', 'DET', 'VERB', 'NOUN', 'NOUN', '.'))),
#              ('b100-38721',
#               Sentence(words=('The', 'idea', 'had', 'come', 'from', 'Herold', ',', 'who', 'had', 'once', 'been', 'a', "chemist's", 'clerk', '.'), tags=('DET', 'NOUN', 'VERB', 'VERB', 'ADP', 'NOUN', '.', 'PRON', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'NOUN', '.'))),
#              ('b100-33053',
#               Sentence(words=('The', 'writer', 'sensed', 'a', 'much', 'freer', 'and', 'more', 'frank', 'discussion', ',', 'especially', 'of', 'this', 'one', 'area', ',', 'than', 'ever', 'before', '.'), tags=('DET', 'NOUN', 'VERB', 'DET', 'ADV', 'ADJ', 'CONJ', 'ADV', 'ADJ', 'NOUN', '.', 'ADV', 'ADP', 'DET', 'NUM', 'NOUN', '.', 'ADP', 'ADV', 'ADV', '.'))),
#              ('b100-53185',
#               Sentence(words=('I', 'had', 'come', 'prepared', 'to', 'worship', 'at', 'the', 'feet', 'of', 'this', 'classic', ',', 'and', 'he', 'turned', 'out', 'to', 'be', 'a', 'rather', 'bitter', 'old', 'man', 'who', 'smelled', 'of', 'dead', 'cigars', '.'), tags=('PRON', 'VERB', 'VERB', 'VERB', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'CONJ', 'PRON', 'VERB', 'PRT', 'PRT', 'VERB', 'DET', 'ADV', 'ADJ', 'ADJ', 'NOUN', 'PRON', 'VERB', 'ADP', 'ADJ', 'NOUN', '.'))),
#              ('b100-9734',
#               Sentence(words=('Parker', ',', 'along', 'with', 'Garrison', 'and', 'Charles', 'Sumner', ',', 'showed', 'a', 'magnificent', 'moral', 'bravery', 'when', 'facing', 'mobs', 'mobilized', 'in', 'defense', 'of', 'the', 'Mexican', 'War', 'and', 'slavery', '.'), tags=('NOUN', '.', 'ADV', 'ADP', 'NOUN', 'CONJ', 'NOUN', 'NOUN', '.', 'VERB', 'DET', 'ADJ', 'ADJ', 'NOUN', 'ADV', 'VERB', 'NOUN', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'CONJ', 'NOUN', '.'))),
#              ('b100-21649',
#               Sentence(words=('that', 'is', ',', 'he', 'is', 'suspect', ',', 'guilty', ',', 'punishable', ',', 'as', 'is', 'anyone', 'in', "Mann's", 'stories', 'who', 'produces', 'illusion', ',', 'and', 'this', 'is', 'true', 'even', 'though', 'the', 'constant', 'elements', 'of', 'the', 'artist-nature', ',', 'technique', ',', 'magic', ',', 'guilt', 'and', 'suffering', ',', 'are', 'divided', 'in', 'this', 'story', 'between', 'Jacoby', 'and', 'Lautner', '.'), tags=('DET', 'VERB', '.', 'PRON', 'VERB', 'ADJ', '.', 'ADJ', '.', 'ADJ', '.', 'ADP', 'VERB', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'PRON', 'VERB', 'NOUN', '.', 'CONJ', 'DET', 'VERB', 'ADJ', 'ADV', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'NOUN', '.', 'NOUN', '.', 'NOUN', 'CONJ', 'VERB', '.', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'NOUN', '.'))),
#              ('b100-8374',
#               Sentence(words=('At', 'the', 'start', 'of', 'her', 'program', 'there', 'were', 'evidences', 'of', 'pique', '.'), tags=('ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'PRT', 'VERB', 'NOUN', 'ADP', 'NOUN', '.'))),
#              ('b100-46781',
#               Sentence(words=('``', 'Ekstrohm', ',', 'you', 'and', 'I', 'will', 'have', 'a', 'look', "''", ',', 'Ryan', 'said', '.'), tags=('.', 'NOUN', '.', 'PRON', 'CONJ', 'PRON', 'VERB', 'VERB', 'DET', 'NOUN', '.', '.', 'NOUN', 'VERB', '.'))),
#              ('b100-53958',
#               Sentence(words=('``', "I've", 'been', 'fixing', 'up', 'the', 'guest', 'room', 'for', 'Cathy', "''", '.'), tags=('.', 'PRT', 'VERB', 'VERB', 'PRT', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.', '.'))),
#              ('b100-52787',
#               Sentence(words=('You', 'were', 'careful', 'about', 'that', "''", '.'), tags=('PRON', 'VERB', 'ADJ', 'ADP', 'DET', '.', '.'))),
#              ('b100-35966',
#               Sentence(words=('Downtown', 'Los', 'Angeles', 'is', 'already', 'two-thirds', 'freeway', ',', 'interchange', ',', 'street', ',', 'parking', 'lot', 'and', 'garage', '--', 'one', 'of', 'those', 'preposterous', '``', 'if', "''", 'statistics', 'has', 'already', 'come', 'to', 'pass', '.'), tags=('NOUN', 'NOUN', 'NOUN', 'VERB', 'ADV', 'NOUN', 'NOUN', '.', 'NOUN', '.', 'NOUN', '.', 'VERB', 'NOUN', 'CONJ', 'NOUN', '.', 'NUM', 'ADP', 'DET', 'ADJ', '.', 'X', '.', 'NOUN', 'VERB', 'ADV', 'VERB', 'PRT', 'VERB', '.'))),
#              ('b100-37732',
#               Sentence(words=('Extractor', '--', 'centrifugal', 'extractor', 'of', 'the', 'laundry-type', 'with', 'a', 'perforated', 'basket', ',', 'approximately', '11', 'inches', 'deep', 'by', '17', 'inches', 'in', 'diameter', ',', 'with', 'an', 'operating', 'speed', 'of', 'approximately', '1,500', 'r.p.m.', '.'), tags=('NOUN', '.', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'VERB', 'NOUN', '.', 'ADV', 'NUM', 'NOUN', 'ADJ', 'ADP', 'NUM', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'DET', 'VERB', 'NOUN', 'ADP', 'ADV', 'NUM', 'NOUN', '.'))),
#              ('b100-54144',
#               Sentence(words=('Quint', 'smothered', 'a', 'yawn', '.'), tags=('NOUN', 'VERB', 'DET', 'NOUN', '.'))),
#              ('b100-18655',
#               Sentence(words=('If', 'the', 'student', 'drops', 'out', 'of', 'high', 'school', ',', 'the', 'break', 'with', 'the', 'school', 'is', 'even', 'more', 'complete', '.'), tags=('ADP', 'DET', 'NOUN', 'VERB', 'ADP', 'ADP', 'ADJ', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'ADV', 'ADV', 'ADJ', '.'))),
#              ('b100-34037',
#               Sentence(words=('All', 'the', 'manuals', 'for', 'setting', 'up', 'vocational', 'courses', 'stress', 'the', 'importance', 'of', 'first', 'making', 'a', 'local', 'survey', 'of', 'skill', 'needs', ',', 'of', 'estimating', 'the', 'growth', 'of', 'local', 'jobs', ',', 'and', 'of', 'consulting', 'with', 'local', 'employers', 'on', 'the', 'types', 'of', 'courses', 'and', 'their', 'content', '.'), tags=('PRT', 'DET', 'NOUN', 'ADP', 'VERB', 'PRT', 'ADJ', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'ADV', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'ADP', 'VERB', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.', 'CONJ', 'ADP', 'VERB', 'ADP', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'DET', 'NOUN', '.'))),
#              ('b100-38496',
#               Sentence(words=('Two', 'of', 'our', 'men', 'were', 'killed', ',', 'a', 'third', 'was', 'wounded', '.'), tags=('NUM', 'ADP', 'DET', 'NOUN', 'VERB', 'VERB', '.', 'DET', 'ADJ', 'VERB', 'VERB', '.'))),
#              ('b100-16760',
#               Sentence(words=('Heydrich', ',', 'in', 'opening', 'the', 'Conference', ',', 'followed', 'the', 'reasoning', 'and', 'even', 'the', 'phraseology', 'of', 'the', 'order', 'issued', 'earlier', 'by', 'Goering', 'which', 'authorized', 'the', 'Final', 'Solution', 'as', '``', 'a', 'complement', 'to', "''", 'previous', '``', 'solutions', "''", 'for', 'eliminating', 'the', 'Jews', 'from', 'German', 'living', 'space', 'through', 'violence', ',', 'economic', 'strangulation', ',', 'forced', 'emigration', ',', 'and', 'evacuation', '.'), tags=('NOUN', '.', 'ADP', 'VERB', 'DET', 'NOUN', '.', 'VERB', 'DET', 'NOUN', 'CONJ', 'ADV', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'ADV', 'ADP', 'NOUN', 'DET', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', '.', 'DET', 'NOUN', 'ADP', '.', 'ADJ', '.', 'NOUN', '.', 'ADP', 'VERB', 'DET', 'NOUN', 'ADP', 'ADJ', 'VERB', 'NOUN', 'ADP', 'NOUN', '.', 'ADJ', 'NOUN', '.', 'VERB', 'NOUN', '.', 'CONJ', 'NOUN', '.'))),
#              ('b100-24743',
#               Sentence(words=('``', 'Is', 'this', 'then', 'the', 'frontier', "''", '?', '?'), tags=('.', 'VERB', 'DET', 'ADV', 'DET', 'NOUN', '.', '.', '.'))),
#              ('b100-48817',
#               Sentence(words=('``', "Let's", 'hear', 'it', ',', 'anyway', "''", '.'), tags=('.', 'VERB', 'VERB', 'PRON', '.', 'ADV', '.', '.'))),
#              ('b100-44864',
#               Sentence(words=('``', 'It', "doesn't", 'matter', '.'), tags=('.', 'PRON', 'VERB', 'VERB', '.'))),
#              ('b100-18860',
#               Sentence(words=('Drifts', 'usually', 'occurred', 'in', 'winter', 'in', 'an', 'effort', 'to', 'escape', 'the', 'severe', 'cold', 'winds', ',', 'but', 'it', 'could', 'also', 'occur', 'in', 'summer', 'as', 'the', 'result', 'of', 'lack', 'of', 'water', 'or', 'grass', 'because', 'of', 'a', 'drought', ',', 'or', 'as', 'an', 'aftermath', 'of', 'a', 'stampede', '.'), tags=('NOUN', 'ADV', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'ADJ', 'ADJ', 'NOUN', '.', 'CONJ', 'PRON', 'VERB', 'ADV', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'NOUN', 'ADV', 'ADP', 'DET', 'NOUN', '.', 'CONJ', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.'))),
#              ('b100-16300',
#               Sentence(words=('The', 'sentence', ':', '360', "days'", 'confinement', 'in', 'the', 'county', 'jail', '.'), tags=('DET', 'NOUN', '.', 'NUM', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.'))),
#              ('b100-46785',
#               Sentence(words=('``', 'I', 'heard', 'a', 'story', 'once', 'about', 'a', 'rookie', 'who', 'got', 'excited', 'when', 'the', 'captain', 'stepped', 'outside', 'and', 'he', "couldn't", 'get', 'an', 'encephalographic', 'reading', 'on', 'him', '.'), tags=('.', 'PRON', 'VERB', 'DET', 'NOUN', 'ADV', 'ADP', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADV', 'DET', 'NOUN', 'VERB', 'ADV', 'CONJ', 'PRON', 'VERB', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'PRON', '.'))),
#              ...])

# %% [markdown]
# The class `Dataset` below incorporates our function above, reads in the Brown corpus and creates a collection of `keys`, a set of (unique) words, a sequence of words and a mirror sequence of tags as tuples, with `N` being the number of words in the Brown corpus.
#
# Then it splits all this nice data into a training and test decomposition by using the `Subset` class defined further below, which mirrors the `Dataset` class.

# %%
class Dataset(namedtuple("_Dataset", "sentences keys vocab X tagset Y training_set testing_set N stream")):
    def __new__(cls, tagfile, datafile, train_test_split=0.8, seed=112890):
        tagset = read_tags(tagfile)
        sentences = read_data(datafile)
        keys = tuple(sentences.keys())
        wordset = frozenset(chain(*[s.words for s in sentences.values()]))
        word_sequences = tuple([sentences[k].words for k in keys])
        tag_sequences = tuple([sentences[k].tags for k in keys])
        N = sum(1 for _ in chain(*(s.words for s in sentences.values())))
        
        
        # split data into train/test sets
        _keys = list(keys)
        if seed is not None: random.seed(seed)
        random.shuffle(_keys)
        split = int(train_test_split * len(_keys))
        training_data = Subset(sentences, _keys[:split])
        testing_data = Subset(sentences, _keys[split:])
        stream = tuple(zip(chain(*word_sequences), chain(*tag_sequences)))
        return super().__new__(cls, dict(sentences), keys, wordset, word_sequences, tagset,
                               tag_sequences, training_data, testing_data, N, stream.__iter__)

    def __len__(self):
        return len(self.sentences)

    def __iter__(self):
        return iter(self.sentences.items())
    
    
class Subset(namedtuple("BaseSet", "sentences keys vocab X tagset Y N stream")):
    def __new__(cls, sentences, keys):
        word_sequences = tuple([sentences[k].words for k in keys])
        tag_sequences = tuple([sentences[k].tags for k in keys])
        wordset = frozenset(chain(*word_sequences))
        tagset = frozenset(chain(*tag_sequences))
        N = sum(1 for _ in chain(*(sentences[k].words for k in keys)))
        stream = tuple(zip(chain(*word_sequences), chain(*tag_sequences)))
        return super().__new__(cls, {k: sentences[k] for k in keys}, keys, wordset, word_sequences,
                               tagset, tag_sequences, N, stream.__iter__)

    def __len__(self):
        return len(self.sentences)

    def __iter__(self):
        return iter(self.sentences.items())

# %% [markdown]
# Let's read in the Brown corpus *again*, leveraging our classes above now, which order the corpus into efficiently navigable structures:

# %%
data = Dataset(tags_file, txt_file, train_test_split=0.8)

print("There are {} sentences in the corpus.".format(len(data)))
print("There are {} sentences in the training set.".format(len(data.training_set)))
print("There are {} sentences in the testing set.".format(len(data.testing_set)))

assert len(data) == len(data.training_set) + len(data.testing_set), \
       "The number of sentences in the training set + testing set should sum to the number of sentences in the corpus"
# Out:
# There are 57340 sentences in the corpus.
# There are 45872 sentences in the training set.
# There are 11468 sentences in the testing set.

# %%
print("There are a total of {} samples of {} unique words in the corpus."
      .format(data.N, len(data.vocab)))
print("There are {} samples of {} unique words in the training set."
      .format(data.training_set.N, len(data.training_set.vocab)))
print("There are {} samples of {} unique words in the testing set."
      .format(data.testing_set.N, len(data.testing_set.vocab)))
print("There are {} words in the test set that are missing in the training set."
      .format(len(data.testing_set.vocab - data.training_set.vocab)))

assert data.N == data.training_set.N + data.testing_set.N, \
       "The number of training + test samples should sum to the total number of samples"
# Out:
# There are a total of 1161192 samples of 56057 unique words in the corpus.
# There are 928458 samples of 50536 unique words in the training set.
# There are 232734 samples of 25112 unique words in the testing set.
# There are 5521 words in the test set that are missing in the training set.

# %% [markdown]
# Let's look at an example POS tagging:

# %%
key = '10'
print("Sentence: {}".format(key))
print("words:\n\t{!s}".format(data.sentences[key].words))
print("tags:\n\t{!s}".format(data.sentences[key].tags))
# Out:
# Sentence: 10
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-b4ed9a91005a> in <module>
#       1 key = '10'
#       2 print("Sentence: {}".format(key))
# ----> 3 print("words:\n\t{!s}".format(data.sentences[key].words))
#       4 print("tags:\n\t{!s}".format(data.sentences[key].tags))
#
# KeyError: '10'

# %% [markdown]
# This is how easy it is, now, to access words and associated tags, using the vocabulary of Machine Learning: `X` is the independent variable, and `Y` the dependent variable!

# %%
# accessing words with Dataset.X and tags with Dataset.Y 
for i in range(2):    
    print("Sentence {}:".format(i + 1), data.X[i])
    print()
    print("Labels {}:".format(i + 1), data.Y[i])
    print()
# Out:
# Sentence 1: ('Mr.', 'Podger', 'had', 'thanked', 'him', 'gravely', ',', 'and', 'now', 'he', 'made', 'use', 'of', 'the', 'advice', '.')
#
# Labels 1: ('NOUN', 'NOUN', 'VERB', 'VERB', 'PRON', 'ADV', '.', 'CONJ', 'ADV', 'PRON', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', '.')
#
# Sentence 2: ('But', 'there', 'seemed', 'to', 'be', 'some', 'difference', 'of', 'opinion', 'as', 'to', 'how', 'far', 'the', 'board', 'should', 'go', ',', 'and', 'whose', 'advice', 'it', 'should', 'follow', '.')
#
# Labels 2: ('CONJ', 'PRT', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'ADP', 'ADV', 'ADV', 'DET', 'NOUN', 'VERB', 'VERB', '.', 'CONJ', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', '.')

# %% [markdown]
# Use `Dataset.stream()` to enumerate (word, tag) samples for the entire corpus. Let's enumerate the first 4:

# %%
print("\nStream (word, tag) pairs:\n")
for i, pair in enumerate(data.stream()):
    print("\t", pair)
    if i > 10: break
# Out:
# Stream (word, tag) pairs:
#
# 	 ('Mr.', 'NOUN')
# 	 ('Podger', 'NOUN')
# 	 ('had', 'VERB')
# 	 ('thanked', 'VERB')
# 	 ('him', 'PRON')
# 	 ('gravely', 'ADV')
# 	 (',', '.')
# 	 ('and', 'CONJ')
# 	 ('now', 'ADV')
# 	 ('he', 'PRON')
# 	 ('made', 'VERB')
# 	 ('use', 'NOUN')

# %% [markdown]
# These are all words and tags in our **training set**. Let's uncover the first 4:

# %%
words = [word for i, (word, tag) in enumerate(data.training_set.stream())]
tags = [tag for i, (word, tag) in enumerate(data.training_set.stream())]
words[0:10], tags[0:10]
# Out:
# (['Whenever',
#   'artists',
#   ',',
#   'indeed',
#   ',',
#   'turned',
#   'to',
#   'actual',
#   'representations',
#   'or'],
#  ['ADV', 'NOUN', '.', 'ADV', '.', 'VERB', 'ADP', 'ADJ', 'NOUN', 'CONJ'])

# %% [markdown]
# # POS Tagger using BOW Model
#
# Let's create a dictionary of word + tag pairs where the values are just counts. Note that some words may be associated with different POS tags, in which case they will produce *distinct* pairs:

# %%
def pair_counts(tags, words):
    d = defaultdict(lambda: defaultdict(int))
    for tag, word in zip(tags, words):
        d[tag][word] += 1
    return d
        
word_counts = pair_counts(words, tags)
word_counts
# Out:
# defaultdict(<function __main__.pair_counts.<locals>.<lambda>()>,
#             {'Whenever': defaultdict(int, {'ADV': 12}),
#              'artists': defaultdict(int, {'NOUN': 34}),
#              ',': defaultdict(int, {'.': 46499, 'X': 1}),
#              'indeed': defaultdict(int, {'ADV': 92}),
#              'turned': defaultdict(int, {'VERB': 264}),
#              'to': defaultdict(int,
#                          {'ADP': 8809,
#                           'PRT': 11784,
#                           'ADV': 1,
#                           'NOUN': 1,
#                           'X': 2}),
#              'actual': defaultdict(int, {'ADJ': 77}),
#              'representations': defaultdict(int, {'NOUN': 7}),
#              'or': defaultdict(int, {'CONJ': 3218, 'X': 1}),
#              'molded': defaultdict(int, {'VERB': 12}),
#              'three-dimensional': defaultdict(int, {'ADJ': 8}),
#              'figures': defaultdict(int, {'NOUN': 69, 'VERB': 2}),
#              'which': defaultdict(int, {'DET': 2844, 'X': 1}),
#              'were': defaultdict(int, {'VERB': 2596}),
#              'rare': defaultdict(int, {'ADJ': 33}),
#              'down': defaultdict(int,
#                          {'PRT': 543,
#                           'ADP': 151,
#                           'ADJ': 1,
#                           'VERB': 1,
#                           'NOUN': 1}),
#              '800': defaultdict(int, {'NUM': 10}),
#              'B.C.': defaultdict(int, {'NOUN': 13}),
#              'they': defaultdict(int, {'PRON': 2235}),
#              'tended': defaultdict(int, {'VERB': 18}),
#              'reflect': defaultdict(int, {'VERB': 21}),
#              'reality': defaultdict(int, {'NOUN': 67}),
#              '(': defaultdict(int, {'.': 1923, 'X': 9}),
#              'see': defaultdict(int, {'VERB': 572, 'PRT': 1}),
#              'Plate': defaultdict(int, {'NOUN': 2}),
#              '6a': defaultdict(int, {'NUM': 1}),
#              '9b': defaultdict(int, {'NUM': 1}),
#              ')': defaultdict(int, {'.': 1949, 'X': 9}),
#              ';': defaultdict(int, {'.': 4418}),
#              'For': defaultdict(int, {'ADP': 522}),
#              'almost': defaultdict(int, {'ADV': 302}),
#              'two': defaultdict(int, {'NUM': 1051}),
#              'months': defaultdict(int, {'NOUN': 142}),
#              'the': defaultdict(int, {'DET': 50287, 'X': 3}),
#              'defendant': defaultdict(int, {'NOUN': 6}),
#              'and': defaultdict(int, {'CONJ': 22369, 'X': 2}),
#              'world': defaultdict(int, {'NOUN': 548}),
#              'heard': defaultdict(int, {'VERB': 189}),
#              'from': defaultdict(int, {'ADP': 3393}),
#              'individuals': defaultdict(int, {'NOUN': 56}),
#              'escaped': defaultdict(int, {'VERB': 15}),
#              'grave': defaultdict(int, {'NOUN': 11, 'ADJ': 16}),
#              'about': defaultdict(int,
#                          {'ADP': 972, 'ADV': 422, 'PRT': 16, 'X': 1}),
#              'fathers': defaultdict(int, {'NOUN': 9}),
#              'mothers': defaultdict(int, {'NOUN': 23}),
#              'graybeards': defaultdict(int, {'NOUN': 1}),
#              'adolescents': defaultdict(int, {'NOUN': 5}),
#              'babies': defaultdict(int, {'NOUN': 7}),
#              'starved': defaultdict(int, {'VERB': 3}),
#              'beaten': defaultdict(int, {'VERB': 9}),
#              'death': defaultdict(int, {'NOUN': 208}),
#              'strangled': defaultdict(int, {'VERB': 5}),
#              'machine-gunned': defaultdict(int, {'VERB': 1}),
#              'gassed': defaultdict(int, {'VERB': 1}),
#              'burned': defaultdict(int, {'VERB': 31}),
#              '.': defaultdict(int, {'.': 39500}),
#              'Clearer': defaultdict(int, {'ADJ': 1}),
#              'meaning': defaultdict(int, {'NOUN': 95, 'VERB': 9}),
#              'Yes': defaultdict(int, {'ADV': 69}),
#              'gentlemen': defaultdict(int, {'NOUN': 18}),
#              'I': defaultdict(int, {'PRON': 4140, 'NOUN': 2}),
#              'am': defaultdict(int, {'VERB': 176}),
#              'getting': defaultdict(int, {'VERB': 135, 'NOUN': 2}),
#              'point': defaultdict(int, {'NOUN': 287, 'VERB': 17}),
#              'my': defaultdict(int, {'DET': 951, 'PRT': 1}),
#              'About': defaultdict(int, {'ADV': 34, 'ADP': 4}),
#              'same': defaultdict(int, {'ADJ': 542}),
#              'time': defaultdict(int, {'NOUN': 1275, 'VERB': 1}),
#              'Alleghenies': defaultdict(int, {'NOUN': 1}),
#              'Poconos': defaultdict(int, {'NOUN': 1}),
#              'in': defaultdict(int, {'ADP': 15278, 'PRT': 362, 'X': 3}),
#              'Pennsylvania': defaultdict(int, {'NOUN': 36}),
#              'are': defaultdict(int, {'VERB': 3470}),
#              'magnificent': defaultdict(int, {'ADJ': 19}),
#              '--': defaultdict(int, {'.': 2739, 'X': 1}),
#              'Renovo': defaultdict(int, {'NOUN': 1}),
#              'holds': defaultdict(int, {'VERB': 32, 'NOUN': 1}),
#              'its': defaultdict(int, {'DET': 1431}),
#              'annual': defaultdict(int, {'ADJ': 72, 'NOUN': 1}),
#              'Flaming': defaultdict(int, {'VERB': 1}),
#              'Foliage': defaultdict(int, {'NOUN': 4}),
#              'Festival': defaultdict(int, {'NOUN': 13}),
#              'on': defaultdict(int, {'ADP': 4742, 'PRT': 421, 'X': 2}),
#              'Oct.': defaultdict(int, {'NOUN': 20}),
#              '14': defaultdict(int, {'NUM': 47}),
#              '15': defaultdict(int, {'NUM': 82}),
#              "There's": defaultdict(int, {'PRT': 45}),
#              'no': defaultdict(int, {'DET': 1250, 'ADV': 163}),
#              'doubt': defaultdict(int, {'NOUN': 76, 'VERB': 13}),
#              'this': defaultdict(int, {'DET': 3203}),
#              'Tim': defaultdict(int, {'NOUN': 21}),
#              'sneaked': defaultdict(int, {'VERB': 3}),
#              'back': defaultdict(int,
#                          {'ADV': 575, 'NOUN': 134, 'VERB': 23, 'ADJ': 22}),
#              'killed': defaultdict(int, {'VERB': 56}),
#              'Mrs.': defaultdict(int, {'NOUN': 434}),
#              'Buck': defaultdict(int, {'NOUN': 11}),
#              'The': defaultdict(int, {'DET': 5807}),
#              "cowboy's": defaultdict(int, {'NOUN': 1}),
#              'humorous': defaultdict(int, {'ADJ': 13}),
#              'name': defaultdict(int, {'NOUN': 219, 'VERB': 19}),
#              'for': defaultdict(int, {'ADP': 6979, 'ADV': 5, 'NOUN': 3}),
#              'a': defaultdict(int, {'DET': 17377, 'X': 5, 'NOUN': 1}),
#              'cow': defaultdict(int, {'NOUN': 20}),
#              "givin'": defaultdict(int, {'VERB': 3}),
#              'milk': defaultdict(int, {'NOUN': 35}),
#              'was': defaultdict(int, {'VERB': 7839}),
#              '``': defaultdict(int, {'.': 7033}),
#              'pitcher': defaultdict(int, {'NOUN': 13}),
#              "''": defaultdict(int, {'.': 7004}),
#              'It': defaultdict(int, {'PRON': 1627}),
#              'is': defaultdict(int, {'VERB': 8006, 'X': 1}),
#              'therefore': defaultdict(int, {'ADV': 125}),
#              'not': defaultdict(int, {'ADV': 3562}),
#              'surprising': defaultdict(int, {'ADJ': 12, 'VERB': 12}),
#              'that': defaultdict(int,
#                          {'ADP': 5194,
#                           'PRON': 1431,
#                           'DET': 1607,
#                           'ADV': 43,
#                           'X': 1}),
#              'resist': defaultdict(int, {'VERB': 19}),
#              'lure': defaultdict(int, {'NOUN': 4, 'VERB': 3}),
#              'of': defaultdict(int, {'ADP': 28772, 'X': 2}),
#              'marriage': defaultdict(int, {'NOUN': 74}),
#              'trap': defaultdict(int, {'NOUN': 12}),
#              'domesticity': defaultdict(int, {'NOUN': 1}),
#              'like': defaultdict(int, {'ADP': 795, 'VERB': 179, 'ADJ': 28}),
#              'cats': defaultdict(int, {'NOUN': 12}),
#              'determined': defaultdict(int, {'VERB': 106}),
#              'tame': defaultdict(int, {'VERB': 1, 'ADJ': 3}),
#              'their': defaultdict(int, {'DET': 2057}),
#              'sexual': defaultdict(int, {'ADJ': 52}),
#              'energy': defaultdict(int, {'NOUN': 71}),
#              'A': defaultdict(int, {'DET': 953, 'NOUN': 92, 'X': 1}),
#              'shielded': defaultdict(int, {'VERB': 4}),
#              'thermocouple': defaultdict(int, {'NOUN': 2}),
#              'used': defaultdict(int, {'VERB': 486}),
#              'measure': defaultdict(int, {'VERB': 25, 'NOUN': 52}),
#              'upstream': defaultdict(int, {'ADJ': 1, 'ADV': 3}),
#              'temperature': defaultdict(int, {'NOUN': 105}),
#              'transpiring': defaultdict(int, {'VERB': 3}),
#              'gas': defaultdict(int, {'NOUN': 73, 'VERB': 1}),
#              'ideals': defaultdict(int, {'NOUN': 13}),
#              'country': defaultdict(int, {'NOUN': 263}),
#              'deeply': defaultdict(int, {'ADV': 29}),
#              'indebted': defaultdict(int, {'ADJ': 8}),
#              'Protestantism': defaultdict(int, {'NOUN': 9}),
#              'older': defaultdict(int, {'ADJ': 75}),
#              'stock': defaultdict(int, {'NOUN': 104, 'VERB': 2}),
#              'Matsuo': defaultdict(int, {'NOUN': 24}),
#              'laughed': defaultdict(int, {'VERB': 38}),
#              'slung': defaultdict(int, {'VERB': 2}),
#              'rifle': defaultdict(int, {'NOUN': 50}),
#              'Rousseau': defaultdict(int, {'NOUN': 16}),
#              'asked': defaultdict(int, {'VERB': 296}),
#              'Dave': defaultdict(int, {'NOUN': 28}),
#              'Trager': defaultdict(int, {'NOUN': 2}),
#              'who': defaultdict(int, {'PRON': 1769}),
#              'quite': defaultdict(int, {'PRT': 34, 'ADV': 181}),
#              'showman': defaultdict(int, {'NOUN': 3}),
#              'boss': defaultdict(int, {'NOUN': 12}),
#              "Chicago's": defaultdict(int, {'NOUN': 7}),
#              'new': defaultdict(int, {'ADJ': 851}),
#              'pro': defaultdict(int, {'ADJ': 3, 'ADP': 5, 'NOUN': 3}),
#              'basketball': defaultdict(int, {'NOUN': 7}),
#              'Packers': defaultdict(int, {'NOUN': 1}),
#              'debuting': defaultdict(int, {'VERB': 2}),
#              'International': defaultdict(int, {'ADJ': 29}),
#              'club': defaultdict(int, {'NOUN': 56}),
#              'exclusive': defaultdict(int, {'ADJ': 19, 'NOUN': 1}),
#              'use': defaultdict(int, {'NOUN': 287, 'VERB': 170}),
#              'season': defaultdict(int, {'NOUN': 76}),
#              'ticket': defaultdict(int, {'NOUN': 8}),
#              'holders': defaultdict(int, {'NOUN': 2}),
#              'Stock': defaultdict(int, {'NOUN': 8}),
#              'Yards': defaultdict(int, {'NOUN': 1}),
#              'Inn': defaultdict(int, {'NOUN': 3}),
#              'While': defaultdict(int, {'ADP': 96}),
#              'he': defaultdict(int, {'PRON': 5239, 'X': 2}),
#              'waited': defaultdict(int, {'VERB': 53}),
#              'living': defaultdict(int, {'NOUN': 18, 'VERB': 127}),
#              'room': defaultdict(int, {'NOUN': 284, 'VERB': 1}),
#              'Frank': defaultdict(int, {'NOUN': 33}),
#              'Graham': defaultdict(int, {'NOUN': 12}),
#              'Journal-American': defaultdict(int, {'NOUN': 1}),
#              'sports': defaultdict(int, {'NOUN': 36, 'VERB': 1}),
#              'columnist': defaultdict(int, {'NOUN': 4}),
#              'Health': defaultdict(int, {'NOUN': 14}),
#              'excellent': defaultdict(int, {'ADJ': 55}),
#              'Serenity': defaultdict(int, {'NOUN': 1}),
#              'if': defaultdict(int, {'ADP': 1157, 'X': 1}),
#              'one': defaultdict(int, {'NOUN': 368, 'NUM': 1923, 'DET': 2}),
#              'fortunate': defaultdict(int, {'ADJ': 16}),
#              'enough': defaultdict(int, {'ADV': 189, 'ADJ': 143}),
#              'achieve': defaultdict(int, {'VERB': 41}),
#              'it': defaultdict(int, {'PRON': 5361, 'PRT': 1}),
#              'so': defaultdict(int, {'ADV': 1084, 'ADP': 336}),
#              'good': defaultdict(int, {'ADJ': 572, 'NOUN': 40, 'ADV': 8}),
#              'as': defaultdict(int, {'ADP': 4542, 'ADV': 836, 'X': 1}),
#              'joy': defaultdict(int, {'NOUN': 36}),
#              'but': defaultdict(int, {'CONJ': 2301, 'ADP': 99, 'ADV': 20}),
#              'something': defaultdict(int, {'NOUN': 324}),
#              'should': defaultdict(int, {'VERB': 694}),
#              'have': defaultdict(int, {'VERB': 3095}),
#              'dramatic': defaultdict(int, {'ADJ': 52}),
#              'form': defaultdict(int, {'NOUN': 250, 'VERB': 34}),
#              'with': defaultdict(int, {'ADP': 5610, 'ADV': 3}),
#              'pleasing': defaultdict(int, {'ADJ': 7}),
#              'language': defaultdict(int, {'NOUN': 87}),
#              'portray': defaultdict(int, {'VERB': 5}),
#              'incidents': defaultdict(int, {'NOUN': 9}),
#              'arouse': defaultdict(int, {'VERB': 5}),
#              'pity': defaultdict(int, {'NOUN': 7, 'VERB': 1}),
#              'fear': defaultdict(int, {'NOUN': 74, 'VERB': 25}),
#              'purges': defaultdict(int, {'VERB': 1, 'NOUN': 2}),
#              'these': defaultdict(int, {'DET': 984}),
#              'emotions': defaultdict(int, {'NOUN': 37}),
#              'audience': defaultdict(int, {'NOUN': 98}),
#              'She': defaultdict(int, {'PRON': 732}),
#              'worked': defaultdict(int, {'VERB': 100}),
#              'domestic': defaultdict(int, {'NOUN': 1, 'ADJ': 52}),
#              'first': defaultdict(int, {'ADV': 230, 'ADJ': 731}),
#              'Newport': defaultdict(int, {'NOUN': 22}),
#              'year': defaultdict(int, {'NOUN': 532, 'X': 2}),
#              'then': defaultdict(int, {'ADV': 798, 'ADJ': 9, 'ADP': 1}),
#              'South': defaultdict(int, {'ADJ': 60, 'NOUN': 84, 'ADV': 1}),
#              'Bethlehem': defaultdict(int, {'NOUN': 1}),
#              'another': defaultdict(int, {'DET': 445}),
#              'These': defaultdict(int, {'DET': 259}),
#              'tests': defaultdict(int, {'NOUN': 42, 'VERB': 1}),
#              'accelerated': defaultdict(int, {'VERB': 10}),
#              'must': defaultdict(int, {'VERB': 790, 'NOUN': 4, 'X': 1}),
#              'be': defaultdict(int, {'VERB': 5081, 'X': 2}),
#              'repeated': defaultdict(int, {'VERB': 43}),
#              'evaluate': defaultdict(int, {'VERB': 8}),
#              'dimensional': defaultdict(int, {'ADJ': 9}),
#              'changes': defaultdict(int, {'NOUN': 90, 'VERB': 9}),
#              'after': defaultdict(int, {'ADP': 643, 'ADV': 10, 'PRT': 1}),
#              'launderings': defaultdict(int, {'NOUN': 1}),
#              'Mr.': defaultdict(int, {'NOUN': 696}),
#              'Hammarskjold': defaultdict(int, {'NOUN': 15}),
#              'removes': defaultdict(int, {'VERB': 5}),
#              'United': defaultdict(int, {'VERB': 352}),
#              "Nations'": defaultdict(int, {'NOUN': 3}),
#              'most': defaultdict(int, {'ADV': 542, 'ADJ': 298}),
#              'controversial': defaultdict(int, {'ADJ': 12}),
#              'leader': defaultdict(int, {'NOUN': 52}),
#              'Meanwhile': defaultdict(int, {'ADV': 17}),
#              'experts': defaultdict(int, {'NOUN': 28}),
#              'speak': defaultdict(int, {'VERB': 94}),
#              'wars': defaultdict(int, {'NOUN': 20}),
#              'triggered': defaultdict(int, {'VERB': 7}),
#              'by': defaultdict(int, {'ADP': 4051, 'ADV': 38, 'X': 1}),
#              'false': defaultdict(int, {'ADJ': 18, 'ADV': 1}),
#              'pre-emption': defaultdict(int, {'NOUN': 1}),
#              'escalation': defaultdict(int, {'NOUN': 3}),
#              'unauthorized': defaultdict(int, {'ADJ': 2}),
#              'behavior': defaultdict(int, {'NOUN': 78}),
#              'other': defaultdict(int, {'ADJ': 1272}),
#              'terms': defaultdict(int, {'NOUN': 127, 'VERB': 1}),
#              'will': defaultdict(int, {'VERB': 1706, 'NOUN': 82}),
#              'discussed': defaultdict(int, {'VERB': 56}),
#              'report': defaultdict(int, {'NOUN': 97, 'VERB': 27}),
#              'King': defaultdict(int, {'NOUN': 45}),
#              'Arthur': defaultdict(int, {'NOUN': 39}),
#              'had': defaultdict(int, {'VERB': 4106}),
#              'fifty-four': defaultdict(int, {'NUM': 1}),
#              'overnighters': defaultdict(int, {'NOUN': 3}),
#              'again': defaultdict(int, {'ADV': 416}),
#              'counting': defaultdict(int, {'VERB': 10}),
#              'rooms': defaultdict(int, {'NOUN': 48}),
#              'rather': defaultdict(int, {'ADP': 92, 'ADV': 194, 'PRT': 5}),
#              'than': defaultdict(int, {'ADP': 1434}),
#              'people': defaultdict(int, {'NOUN': 648, 'VERB': 1}),
#              'Inside': defaultdict(int, {'NOUN': 1, 'ADV': 7, 'ADP': 3}),
#              'pieces': defaultdict(int, {'NOUN': 70}),
#              'glazed': defaultdict(int, {'VERB': 4}),
#              'three': defaultdict(int, {'NUM': 421}),
#              'coats': defaultdict(int, {'NOUN': 9}),
#              'Creek-Turn': defaultdict(int, {'NOUN': 5}),
#              'bottle': defaultdict(int, {'NOUN': 60}),
#              'green': defaultdict(int, {'ADJ': 56, 'NOUN': 16}),
#              'antique': defaultdict(int, {'NOUN': 7, 'ADJ': 1}),
#              'glaze': defaultdict(int, {'NOUN': 8}),
#              'But': defaultdict(int, {'CONJ': 1105, 'ADP': 3}),
#              'our': defaultdict(int, {'DET': 885}),
#              'health': defaultdict(int, {'NOUN': 77}),
#              'more': defaultdict(int, {'ADV': 968, 'ADJ': 748, 'X': 1}),
#              'precious': defaultdict(int, {'ADJ': 17}),
#              'all': defaultdict(int, {'PRT': 2069, 'ADV': 144}),
#              'money': defaultdict(int, {'NOUN': 213}),
#              'modern': defaultdict(int, {'ADJ': 142}),
#              'witch': defaultdict(int, {'NOUN': 5}),
#              'doctors': defaultdict(int, {'NOUN': 20}),
#              'fake': defaultdict(int, {'ADJ': 6}),
#              'therapeutic': defaultdict(int, {'ADJ': 9}),
#              'gadgets': defaultdict(int, {'NOUN': 5}),
#              'gambling': defaultdict(int, {'VERB': 13, 'NOUN': 1}),
#              'away': defaultdict(int, {'ADV': 360}),
#              'Over': defaultdict(int, {'PRT': 8, 'ADP': 13}),
#              '4': defaultdict(int, {'NUM': 164}),
#              'million': defaultdict(int, {'NUM': 171}),
#              'shares': defaultdict(int, {'NOUN': 35, 'VERB': 3}),
#              'sold': defaultdict(int, {'VERB': 36}),
#              'highest': defaultdict(int, {'ADJ': 47, 'ADV': 4}),
#              'since': defaultdict(int, {'ADP': 342, 'ADV': 27}),
#              'early': defaultdict(int, {'ADJ': 190, 'ADV': 79}),
#              'June': defaultdict(int, {'NOUN': 77}),
#              'He': defaultdict(int, {'PRON': 2345}),
#              'did': defaultdict(int, {'VERB': 816}),
#              'say': defaultdict(int,
#                          {'VERB': 384, 'PRT': 10, 'NOUN': 4, 'X': 1}),
#              'she': defaultdict(int, {'PRON': 1515}),
#              'could': defaultdict(int, {'VERB': 1251}),
#              'get': defaultdict(int, {'VERB': 557}),
#              'her': defaultdict(int, {'DET': 1459, 'PRON': 879}),
#              'beef': defaultdict(int, {'NOUN': 28}),
#              'vegetables': defaultdict(int, {'NOUN': 13}),
#              'cans': defaultdict(int, {'NOUN': 3}),
#              'summer': defaultdict(int, {'NOUN': 103}),
#              'Washington': defaultdict(int, {'NOUN': 168}),
#              'Feb.': defaultdict(int, {'NOUN': 18}),
#              '9': defaultdict(int, {'NUM': 46}),
#              'supplier': defaultdict(int, {'NOUN': 5}),
#              'delivers': defaultdict(int, {'VERB': 5}),
#              'at': defaultdict(int, {'ADP': 3997}),
#              'his': defaultdict(int, {'DET': 5146, 'PRON': 28, 'X': 2}),
#              'convenience': defaultdict(int, {'NOUN': 16}),
#              'transport': defaultdict(int, {'NOUN': 10, 'VERB': 3}),
#              'loads': defaultdict(int, {'NOUN': 9}),
#              'maintain': defaultdict(int, {'VERB': 52}),
#              'two-to-three': defaultdict(int, {'NUM': 1}),
#              'weeks': defaultdict(int, {'NOUN': 111}),
#              'reserve': defaultdict(int, {'NOUN': 16, 'VERB': 7}),
#              'supply': defaultdict(int, {'NOUN': 44, 'VERB': 35}),
#              'against': defaultdict(int, {'ADP': 491, 'ADV': 2}),
#              'weather': defaultdict(int, {'NOUN': 53}),
#              'contingencies': defaultdict(int, {'NOUN': 5}),
#              'On': defaultdict(int, {'ADP': 279, 'PRT': 1}),
#              'way': defaultdict(int, {'NOUN': 694, 'ADV': 7}),
#              'airport': defaultdict(int, {'NOUN': 9}),
#              'Paris': defaultdict(int, {'NOUN': 55}),
#              'you': defaultdict(int, {'PRON': 2220}),
#              'bet': defaultdict(int, {'VERB': 13, 'NOUN': 4}),
#              'Lucy': defaultdict(int, {'NOUN': 35}),
#              'said': defaultdict(int, {'VERB': 1528}),
#              'herself': defaultdict(int, {'PRON': 96}),
#              'when': defaultdict(int, {'ADV': 1410}),
#              'Gloriana': defaultdict(int, {'NOUN': 3}),
#              'rides': defaultdict(int, {'VERB': 4, 'NOUN': 5}),
#              'them': defaultdict(int, {'PRON': 1411, 'DET': 6}),
#              'also': defaultdict(int, {'ADV': 793}),
#              'take': defaultdict(int, {'VERB': 463, 'NOUN': 4}),
#              'girls': defaultdict(int, {'NOUN': 118}),
#              'usually': defaultdict(int, {'ADV': 151}),
#              'ride': defaultdict(int, {'VERB': 26, 'NOUN': 9}),
#              'little': defaultdict(int, {'ADJ': 527, 'ADV': 91}),
#              'car': defaultdict(int, {'NOUN': 218}),
#              "isn't": defaultdict(int, {'VERB': 69}),
#              'big': defaultdict(int, {'ADJ': 265}),
#              'carrots': defaultdict(int, {'NOUN': 3}),
#              'sometimes': defaultdict(int, {'ADV': 132}),
#              "don't": defaultdict(int, {'VERB': 290}),
#              'make': defaultdict(int, {'VERB': 592, 'NOUN': 2}),
#              'through': defaultdict(int, {'ADP': 713, 'PRT': 48}),
#              'winter': defaultdict(int, {'NOUN': 60}),
#              'Fearful': defaultdict(int, {'ADJ': 1}),
#              'inviting': defaultdict(int, {'VERB': 6, 'ADJ': 2}),
#              'military': defaultdict(int, {'ADJ': 144, 'NOUN': 7}),
#              'showdown': defaultdict(int, {'NOUN': 2}),
#              'West': defaultdict(int, {'NOUN': 77, 'ADJ': 72}),
#              'win': defaultdict(int, {'VERB': 47, 'NOUN': 1}),
#              'Communists': defaultdict(int, {'NOUN': 30}),
#              'seek': defaultdict(int, {'VERB': 60}),
#              'undermine': defaultdict(int, {'VERB': 6}),
#              'Western': defaultdict(int, {'ADJ': 81}),
#              'power': defaultdict(int, {'NOUN': 250, 'VERB': 2}),
#              'where': defaultdict(int, {'ADV': 677}),
#              'nuclear': defaultdict(int, {'ADJ': 88}),
#              'might': defaultdict(int, {'NOUN': 11, 'VERB': 530}),
#              'irrelevant': defaultdict(int, {'ADJ': 13}),
#              'backwoods': defaultdict(int, {'ADJ': 1, 'NOUN': 3}),
#              'guerrilla': defaultdict(int, {'NOUN': 12}),
#              'skirmishes': defaultdict(int, {'NOUN': 1}),
#              'mob': defaultdict(int, {'NOUN': 8}),
#              'uprisings': defaultdict(int, {'NOUN': 2}),
#              'streets': defaultdict(int, {'NOUN': 49}),
#              'parliaments': defaultdict(int, {'NOUN': 1}),
#              'clandestine': defaultdict(int, {'ADJ': 1}),
#              'meetings': defaultdict(int, {'NOUN': 22}),
#              'undercover': defaultdict(int, {'ADJ': 1}),
#              'conspirators': defaultdict(int, {'NOUN': 3}),
#              'Nations': defaultdict(int, {'NOUN': 39}),
#              'propaganda': defaultdict(int, {'NOUN': 25}),
#              'front': defaultdict(int, {'NOUN': 116, 'ADJ': 63}),
#              'diplomatic': defaultdict(int, {'ADJ': 23}),
#              'conferences': defaultdict(int, {'NOUN': 15}),
#              'preferably': defaultdict(int, {'ADV': 8}),
#              'level': defaultdict(int, {'NOUN': 158, 'ADJ': 11, 'VERB': 2}),
#              'Today': defaultdict(int, {'NOUN': 34}),
#              'thousand': defaultdict(int, {'NUM': 77}),
#              'industries': defaultdict(int, {'NOUN': 23}),
#              'distribute': defaultdict(int, {'VERB': 5}),
#              'me': defaultdict(int, {'PRON': 928, 'X': 1}),
#              'employees': defaultdict(int, {'NOUN': 54}),
#              'loss': defaultdict(int, {'NOUN': 66}),
#              'growth': defaultdict(int, {'NOUN': 125}),
#              'sawtimber': defaultdict(int, {'NOUN': 3}),
#              'because': defaultdict(int, {'ADV': 116, 'ADP': 527}),
#              'damage': defaultdict(int, {'NOUN': 25, 'VERB': 3}),
#              'destructive': defaultdict(int, {'ADJ': 22}),
#              'agencies': defaultdict(int, {'NOUN': 52}),
#              'States': defaultdict(int, {'NOUN': 340}),
#              '1952': defaultdict(int, {'NUM': 23}),
#              'estimated': defaultdict(int, {'VERB': 49}),
#              '44': defaultdict(int, {'NUM': 3}),
#              'billion': defaultdict(int, {'NUM': 45}),
#              'board': defaultdict(int, {'NOUN': 139, 'VERB': 5}),
#              'feet': defaultdict(int, {'NOUN': 243}),
#              'Pretty': defaultdict(int, {'ADJ': 2, 'ADV': 3, 'NOUN': 3}),
#              'among': defaultdict(int, {'ADP': 258}),
#              'blonde': defaultdict(int, {'ADJ': 12, 'NOUN': 5}),
#              'hair': defaultdict(int, {'NOUN': 118}),
#              'pert': defaultdict(int, {'ADJ': 2}),
#              'faces': defaultdict(int, {'NOUN': 45, 'VERB': 12}),
#              'Their': defaultdict(int, {'DET': 97}),
#              'study': defaultdict(int, {'NOUN': 158, 'VERB': 27}),
#              'showed': defaultdict(int, {'VERB': 113}),
#              'possible': defaultdict(int, {'ADJ': 314}),
#              'transfer': defaultdict(int, {'VERB': 6, 'NOUN': 24}),
#              '3': defaultdict(int, {'NUM': 233, 'ADJ': 2}),
#              'lb': defaultdict(int, {'NOUN': 8}),
#              'oxygen': defaultdict(int, {'NOUN': 35}),
#              '/': defaultdict(int, {'ADP': 17}),
#              'hr.': defaultdict(int, {'NOUN': 3}),
#              'hp.': defaultdict(int, {'NOUN': 2}),
#              'Haney': defaultdict(int, {'NOUN': 16}),
#              'scowled': defaultdict(int, {'VERB': 4}),
#              'As': defaultdict(int, {'ADP': 376, 'ADV': 43}),
#              'seen': defaultdict(int, {'VERB': 236}),
#              'B.': defaultdict(int, {'NOUN': 66}),
#              'family': defaultdict(int, {'NOUN': 248}),
#              'there': defaultdict(int, {'PRT': 1101, 'ADV': 425}),
#              'an': defaultdict(int, {'DET': 2848, 'X': 1, 'CONJ': 10}),
#              'attempt': defaultdict(int, {'NOUN': 56, 'VERB': 20}),
#              'help': defaultdict(int, {'VERB': 167, 'NOUN': 73, 'PRT': 1}),
#              'client': defaultdict(int, {'NOUN': 14}),
#              'develop': defaultdict(int, {'VERB': 62}),
#              'conscious': defaultdict(int, {'ADJ': 37}),
#              'awareness': defaultdict(int, {'NOUN': 25}),
#              'problem': defaultdict(int, {'NOUN': 247}),
#              'especially': defaultdict(int, {'ADV': 116}),
#              'absence': defaultdict(int, {'NOUN': 43}),
#              'formal': defaultdict(int, {'ADJ': 38}),
#              'request': defaultdict(int, {'NOUN': 36, 'VERB': 4}),
#              'assistance': defaultdict(int, {'NOUN': 65}),
#              'crawled': defaultdict(int, {'VERB': 17}),
#              'into': defaultdict(int, {'ADP': 1420, 'X': 2}),
#              'bed': defaultdict(int, {'NOUN': 98}),
#              'switched': defaultdict(int, {'VERB': 11}),
#              'off': defaultdict(int, {'PRT': 365, 'ADP': 124}),
#              'light': defaultdict(int, {'NOUN': 203, 'ADJ': 44, 'VERB': 6}),
#              'Buckley': defaultdict(int, {'NOUN': 5}),
#              'seems': defaultdict(int, {'VERB': 196}),
#              'assumed': defaultdict(int, {'VERB': 58}),
#              'would': defaultdict(int, {'VERB': 2170}),
#              'given': defaultdict(int, {'VERB': 298, 'X': 1}),
#              'right': defaultdict(int, {'NOUN': 142, 'ADV': 156, 'ADJ': 190}),
#              'pick': defaultdict(int, {'VERB': 38, 'NOUN': 2}),
#              "Gerosa's": defaultdict(int, {'NOUN': 1}),
#              'successor': defaultdict(int, {'NOUN': 14}),
#              'This': defaultdict(int, {'DET': 924}),
#              'manifestly': defaultdict(int, {'ADV': 5}),
#              'provide': defaultdict(int, {'VERB': 168}),
#              '$5000': defaultdict(int, {'NOUN': 5}),
#              'each': defaultdict(int, {'DET': 603}),
#              'surviving': defaultdict(int, {'VERB': 11}),
#              'five': defaultdict(int, {'NUM': 190}),
#              'children': defaultdict(int, {'NOUN': 278}),
#              'What': defaultdict(int, {'DET': 369, 'PRON': 10}),
#              'seem': defaultdict(int, {'VERB': 186}),
#              'realize': defaultdict(int, {'VERB': 59}),
#              "aren't": defaultdict(int, {'VERB': 27}),
#              'tied': defaultdict(int, {'VERB': 32}),
#              'up': defaultdict(int, {'PRT': 1373, 'ADP': 146}),
#              'thing': defaultdict(int, {'NOUN': 274}),
#              '90%': defaultdict(int, {'NOUN': 4}),
#              'transportation': defaultdict(int, {'NOUN': 31}),
#              'know': defaultdict(int, {'VERB': 516, 'NOUN': 3}),
#              'now': defaultdict(int, {'ADV': 823}),
#              'why': defaultdict(int, {'ADV': 194}),
#              'Japanese': defaultdict(int, {'ADJ': 33, 'NOUN': 12}),
#              'friends': defaultdict(int, {'NOUN': 115}),
#              'surprised': defaultdict(int, {'VERB': 49}),
#              'walked': defaultdict(int, {'VERB': 126}),
#              'bathroom': defaultdict(int, {'NOUN': 14}),
#              'let': defaultdict(int, {'VERB': 223, 'NOUN': 6}),
#              'eyelids': defaultdict(int, {'NOUN': 6}),
#              'droop': defaultdict(int, {'VERB': 1}),
#              'breathed': defaultdict(int, {'VERB': 5}),
#              'heavily': defaultdict(int, {'ADV': 47}),
#              'feigning': defaultdict(int, {'VERB': 1}),
#              'sleep': defaultdict(int, {'NOUN': 23, 'VERB': 23}),
#              'meantime': defaultdict(int, {'NOUN': 6, 'ADV': 1}),
#              'beer-runner': defaultdict(int, {'NOUN': 1}),
#              'unhappy': defaultdict(int, {'ADJ': 23}),
#              'solution': defaultdict(int, {'NOUN': 45}),
#              'telephoned': defaultdict(int, {'VERB': 11}),
#              'Torrio': defaultdict(int, {'NOUN': 8}),
#              'returned': defaultdict(int, {'VERB': 100}),
#              "O'Banion": defaultdict(int, {'NOUN': 17}),
#              'message': defaultdict(int, {'NOUN': 52}),
#              ':': defaultdict(int, {'.': 1410, 'ADP': 19, 'NOUN': 1}),
#              'Say': defaultdict(int, {'PRT': 1, 'VERB': 5}),
#              'Dionie': defaultdict(int, {'NOUN': 1}),
#              'just': defaultdict(int, {'ADV': 584, 'ADJ': 12}),
#              'been': defaultdict(int, {'VERB': 2003}),
#              'talking': defaultdict(int, {'VERB': 66, 'NOUN': 1}),
#              'Johnny': defaultdict(int, {'NOUN': 22}),
#              'cops': defaultdict(int, {'NOUN': 15}),
#              'hundred': defaultdict(int, {'NUM': 140}),
#              'hit': defaultdict(int, {'VERB': 84, 'NOUN': 9}),
#              'him': defaultdict(int, {'PRON': 2062}),
#              'ass': defaultdict(int, {'NOUN': 4}),
#              'once': defaultdict(int, {'ADV': 281, 'ADP': 47}),
#              'obligation': defaultdict(int, {'NOUN': 14}),
#              'pertains': defaultdict(int, {'VERB': 4}),
#              'only': defaultdict(int, {'ADV': 1032, 'ADJ': 291}),
#              'countries': defaultdict(int, {'NOUN': 115}),
#              'honestly': defaultdict(int, {'ADV': 11}),
#              'seeking': defaultdict(int, {'VERB': 34}),
#              'become': defaultdict(int, {'VERB': 293}),
#              'responsible': defaultdict(int, {'ADJ': 56}),
#              'members': defaultdict(int, {'NOUN': 251}),
#              'stable': defaultdict(int, {'ADJ': 16, 'NOUN': 9}),
#              'forward-moving': defaultdict(int, {'ADJ': 1}),
#              'community': defaultdict(int, {'NOUN': 163}),
#              "I've": defaultdict(int, {'PRT': 100}),
#              'got': defaultdict(int, {'VERB': 378}),
#              'cold': defaultdict(int, {'NOUN': 16, 'ADJ': 112, 'ADV': 2}),
#              'advantage': defaultdict(int, {'NOUN': 60}),
#              'having': defaultdict(int, {'VERB': 203}),
#              'firm': defaultdict(int, {'NOUN': 45, 'ADJ': 36}),
#              'Tri-State': defaultdict(int, {'ADJ': 10}),
#              'headed': defaultdict(int, {'VERB': 49}),
#              'lawyer': defaultdict(int, {'NOUN': 35}),
#              'Day': defaultdict(int, {'NOUN': 52}),
#              'day': defaultdict(int, {'NOUN': 489}),
#              'week': defaultdict(int, {'NOUN': 205}),
#              'month': defaultdict(int, {'NOUN': 100}),
#              'betrayal': defaultdict(int, {'NOUN': 5}),
#              'gnawed': defaultdict(int, {'VERB': 1}),
#              "Andrei's": defaultdict(int, {'NOUN': 2}),
#              'heart': defaultdict(int, {'NOUN': 142}),
#              'B': defaultdict(int, {'NOUN': 81}),
#              'need': defaultdict(int, {'NOUN': 130, 'VERB': 158}),
#              'plan': defaultdict(int, {'VERB': 24, 'NOUN': 137}),
#              'investment': defaultdict(int, {'NOUN': 35}),
#              'programs': defaultdict(int, {'NOUN': 110}),
#              'His': defaultdict(int, {'DET': 423, 'PRON': 1}),
#              'small': defaultdict(int, {'ADJ': 414}),
#              'mean': defaultdict(int, {'ADJ': 29, 'VERB': 140, 'NOUN': 9}),
#              'eyes': defaultdict(int, {'NOUN': 310}),
#              'regarded': defaultdict(int, {'VERB': 49}),
#              'Marty': defaultdict(int, {'NOUN': 10}),
#              'steadily': defaultdict(int, {'ADV': 16}),
#              'unblinkingly': defaultdict(int, {'ADV': 2}),
#              'Just': defaultdict(int, {'ADV': 91, 'ADJ': 1}),
#              'evocations': defaultdict(int, {'NOUN': 2}),
#              'place': defaultdict(int, {'NOUN': 378, 'VERB': 44}),
#              'passionate': defaultdict(int, {'ADJ': 11}),
#              'encounter': defaultdict(int, {'NOUN': 14, 'VERB': 9}),
#              'between': defaultdict(int, {'ADP': 574, 'ADV': 1}),
#              'man': defaultdict(int, {'NOUN': 902, 'VERB': 1}),
#              'natural': defaultdict(int, {'ADJ': 117}),
#              'today': defaultdict(int, {'NOUN': 199}),
#              'lost': defaultdict(int, {'VERB': 149}),
#              'Both': defaultdict(int, {'DET': 75}),
#              'those': defaultdict(int, {'DET': 623}),
#              'dynamic': defaultdict(int, {'ADJ': 17, 'NOUN': 1}),
#              'run-ups': defaultdict(int, {'NOUN': 1}),
#              'price': defaultdict(int, {'NOUN': 81, 'VERB': 1}),
#              'market': defaultdict(int, {'NOUN': 106}),
#              'recent': defaultdict(int, {'ADJ': 136}),
#              'both': defaultdict(int, {'DET': 536}),
#              'selling': defaultdict(int, {'VERB': 19, 'NOUN': 2, 'ADJ': 1}),
#              'higher': defaultdict(int, {'ADJ': 107, 'ADV': 13}),
#              'price-earnings': defaultdict(int, {'NOUN': 3}),
#              'yield': defaultdict(int, {'NOUN': 13, 'VERB': 11}),
#              'bases': defaultdict(int, {'NOUN': 13, 'VERB': 3}),
#              'Morton': defaultdict(int, {'NOUN': 15}),
#              'coming': defaultdict(int, {'VERB': 118, 'NOUN': 10}),
#              'everyone': defaultdict(int, {'NOUN': 60}),
#              'knew': defaultdict(int, {'VERB': 298}),
#              'anything': defaultdict(int, {'NOUN': 215}),
#              'expected': defaultdict(int, {'VERB': 152}),
#              'fast': defaultdict(int, {'ADJ': 20, 'ADV': 38, 'NOUN': 1}),
#              'run-up': defaultdict(int, {'NOUN': 1, 'ADJ': 1}),
#              'Dr.': defaultdict(int, {'NOUN': 150}),
#              'Karlis': defaultdict(int, {'NOUN': 1}),
#              'Osis': defaultdict(int, {'NOUN': 1}),
#              'Director': defaultdict(int, {'NOUN': 21}),
#              'Research': defaultdict(int, {'NOUN': 28}),
#              'Parapsychology': defaultdict(int, {'NOUN': 1}),
#              'Foundation': defaultdict(int, {'NOUN': 15}),
#              'described': defaultdict(int, {'VERB': 94}),
#              'basis': defaultdict(int, {'NOUN': 140}),
#              'experiment': defaultdict(int, {'NOUN': 45, 'VERB': 6}),
#              'tomorrow': defaultdict(int, {'NOUN': 46}),
#              'article': defaultdict(int, {'NOUN': 39}),
#              'New': defaultdict(int, {'ADJ': 457}),
#              'Survival': defaultdict(int, {'NOUN': 2}),
#              'After': defaultdict(int, {'ADP': 191}),
#              'Death': defaultdict(int, {'NOUN': 11}),
#              'Spring': defaultdict(int, {'NOUN': 17}),
#              '1958': defaultdict(int, {'NUM': 69}),
#              'else': defaultdict(int, {'ADV': 130}),
#              'rattle': defaultdict(int, {'NOUN': 4}),
#              'gunfire': defaultdict(int, {'NOUN': 6}),
#              'sides': defaultdict(int, {'NOUN': 81}),
#              'discussion': defaultdict(int, {'NOUN': 70}),
#              'optimal': defaultdict(int, {'ADJ': 25}),
#              'policy': defaultdict(int, {'NOUN': 168}),
#              'outcome': defaultdict(int, {'NOUN': 21}),
#              'stage': defaultdict(int, {'NOUN': 135, 'VERB': 1}),
#              'known': defaultdict(int, {'VERB': 192}),
#              'before': defaultdict(int, {'ADP': 634, 'ADV': 122, 'X': 1}),
#              'passing': defaultdict(int, {'VERB': 46, 'NOUN': 5}),
#              'next': defaultdict(int, {'ADJ': 233, 'ADP': 30, 'ADV': 24}),
#              'very': defaultdict(int, {'ADV': 543, 'ADJ': 75}),
#              'much': defaultdict(int, {'ADV': 350, 'ADJ': 360}),
#              'difficult': defaultdict(int, {'ADJ': 127}),
#              'matter': defaultdict(int, {'NOUN': 225, 'VERB': 20}),
#              'At': defaultdict(int, {'ADP': 331}),
#              'beginning': defaultdict(int, {'NOUN': 66, 'VERB': 59}),
#              'school': defaultdict(int, {'NOUN': 302, 'VERB': 4}),
#              'students': defaultdict(int, {'NOUN': 167}),
#              'eat': defaultdict(int, {'VERB': 52}),
#              'cereal': defaultdict(int, {'NOUN': 9}),
#              'within': defaultdict(int, {'ADP': 245, 'ADV': 8}),
#              'short': defaultdict(int, {'ADJ': 162, 'ADV': 11}),
#              'eating': defaultdict(int, {'VERB': 24, 'NOUN': 2}),
#              'voraciously': defaultdict(int, {'ADV': 1}),
#              'picnic': defaultdict(int, {'NOUN': 12}),
#              'bag': defaultdict(int, {'NOUN': 36, 'VERB': 1}),
#              'grill': defaultdict(int, {'NOUN': 8, 'VERB': 1}),
#              'cooler': defaultdict(int, {'NOUN': 4, 'ADJ': 6}),
#              'soft': defaultdict(int, {'ADJ': 47, 'ADV': 1}),
#              'drinks': defaultdict(int, {'NOUN': 17, 'VERB': 3}),
#              'beer': defaultdict(int, {'NOUN': 30}),
#              'frozen': defaultdict(int, {'VERB': 19}),
#              'foods': defaultdict(int, {'NOUN': 32}),
#              'Sunday': defaultdict(int, {'NOUN': 79}),
#              'evening': defaultdict(int, {'NOUN': 103}),
#              'program': defaultdict(int, {'NOUN': 286, 'VERB': 4, 'X': 1}),
#              'provides': defaultdict(int, {'VERB': 69}),
#              'theological': defaultdict(int, {'ADJ': 20}),
#              'lectures': defaultdict(int, {'NOUN': 11}),
#              'music': defaultdict(int, {'NOUN': 156}),
#              'drama': defaultdict(int, {'NOUN': 35}),
#              'films': defaultdict(int, {'NOUN': 24}),
#              'related': defaultdict(int, {'VERB': 74}),
#              'issues': defaultdict(int, {'NOUN': 49, 'VERB': 1}),
#              'Judeo-Christian': defaultdict(int, {'ADJ': 1}),
#              'tradition': defaultdict(int, {'NOUN': 75}),
#              "Williams's": defaultdict(int, {'NOUN': 2}),
#              'well': defaultdict(int,
#                          {'ADV': 551,
#                           'PRT': 20,
#                           'ADJ': 9,
#                           'NOUN': 15,
#                           'VERB': 3}),
#              'included': defaultdict(int, {'VERB': 76}),
#              'felt': defaultdict(int, {'VERB': 298, 'NOUN': 1}),
#              'They': defaultdict(int, {'PRON': 696}),
#              'unspoken': defaultdict(int, {'ADJ': 3}),
#              'support': defaultdict(int, {'NOUN': 99, 'VERB': 45}),
#              'President-elect': defaultdict(int, {'NOUN': 1}),
#              'Kennedy': defaultdict(int, {'NOUN': 121}),
#              'whose': defaultdict(int, {'DET': 200}),
#              'own': defaultdict(int, {'ADJ': 579, 'VERB': 16}),
#              'legislative': defaultdict(int, {'ADJ': 27}),
#              'menaced': defaultdict(int, {'VERB': 2}),
#              'Rules': defaultdict(int, {'NOUN': 6}),
#              'Committee': defaultdict(int, {'NOUN': 68}),
#              'bottleneck': defaultdict(int, {'NOUN': 2}),
#              'scope': defaultdict(int, {'NOUN': 23}),
#              'elaborate': defaultdict(int, {'VERB': 5, 'ADJ': 19}),
#              'any': defaultdict(int, {'DET': 1025, 'ADV': 12}),
#              'great': defaultdict(int, {'ADJ': 474, 'ADV': 11}),
#              'detail': defaultdict(int, {'NOUN': 58, 'VERB': 1}),
#              'upon': defaultdict(int, {'ADP': 338, 'ADV': 28}),
#              'special': defaultdict(int, {'ADJ': 186, 'NOUN': 2}),
#              'districts': defaultdict(int, {'NOUN': 29}),
#              'Rhode': defaultdict(int, {'NOUN': 78}),
#              'Island': defaultdict(int, {'NOUN': 105}),
#              'To': defaultdict(int, {'PRT': 207, 'ADP': 140}),
#              'prepare': defaultdict(int, {'VERB': 28}),
#              'latter': defaultdict(int, {'ADJ': 89}),
#              'silver': defaultdict(int, {'NOUN': 19, 'ADJ': 5}),
#              'chloride': defaultdict(int, {'NOUN': 4}),
#              'precipitated': defaultdict(int, {'VERB': 9}),
#              'containing': defaultdict(int, {'VERB': 38}),
#              'Af': defaultdict(int, {'NOUN': 773, 'X': 1}),
#              'obtained': defaultdict(int, {'VERB': 92}),
#              'Oak': defaultdict(int, {'NOUN': 7}),
#              'Ridge': defaultdict(int, {'NOUN': 6}),
#              'National': defaultdict(int, {'ADJ': 132, 'X': 1}),
#              'Laboratory': defaultdict(int, {'NOUN': 11}),
#              'Church': defaultdict(int, {'NOUN': 107}),
#              'loses': defaultdict(int, {'VERB': 13}),
#              'pace': defaultdict(int, {'NOUN': 31, 'VERB': 4}),
#              'purpose': defaultdict(int, {'NOUN': 107}),
#              'conference': defaultdict(int, {'NOUN': 52}),
#              'certain': defaultdict(int, {'ADJ': 234, 'X': 1}),
#              'low-wage': defaultdict(int, {'NOUN': 3}),
#              'control': defaultdict(int, {'VERB': 22, 'NOUN': 142}),
#              'textile': defaultdict(int, {'NOUN': 18, 'ADJ': 2}),
#              'exports': defaultdict(int, {'NOUN': 7}),
#              'dumping': defaultdict(int, {'NOUN': 2, 'VERB': 2}),
#              'specific': defaultdict(int, {'ADJ': 94}),
#              'products': defaultdict(int, {'NOUN': 72}),
#              'high-wage': defaultdict(int, {'NOUN': 1}),
#              'textile-producing': defaultdict(int, {'ADJ': 2}),
#              'Because': defaultdict(int, {'ADV': 21, 'ADP': 32}),
#              'wealth': defaultdict(int, {'NOUN': 16}),
#              'experience': defaultdict(int, {'NOUN': 208, 'VERB': 16}),
#              'Organization': defaultdict(int, {'NOUN': 18}),
#              'European': defaultdict(int, {'ADJ': 44, 'NOUN': 2}),
#              'Economic': defaultdict(int, {'ADJ': 19}),
#              'Cooperation': defaultdict(int, {'NOUN': 3}),
#              'initial': defaultdict(int, {'ADJ': 59}),
#              'studies': defaultdict(int, {'NOUN': 75, 'VERB': 1}),
#              'needed': defaultdict(int, {'VERB': 148}),
#              'face': defaultdict(int, {'NOUN': 270, 'VERB': 40}),
#              'employs': defaultdict(int, {'VERB': 6}),
#              'deductive': defaultdict(int, {'ADJ': 2}),
#              'techniques': defaultdict(int, {'NOUN': 82}),
#              'alien': defaultdict(int, {'ADJ': 10, 'NOUN': 2}),
#              'official': defaultdict(int, {'ADJ': 45, 'NOUN': 15}),
#              'police': defaultdict(int, {'NOUN': 103}),
#              'routine': defaultdict(int, {'NOUN': 16, 'ADJ': 12}),
#              'fullest': defaultdict(int, {'ADJ': 5}),
#              'cooperation': defaultdict(int, {'NOUN': 29}),
#              'Atomic': defaultdict(int, {'ADJ': 7}),
#              'Energy': defaultdict(int, {'NOUN': 3}),
#              'Commission': defaultdict(int, {'NOUN': 55}),
#              'Department': defaultdict(int, {'NOUN': 130}),
#              'Education': defaultdict(int, {'NOUN': 24}),
#              'Welfare': defaultdict(int, {'NOUN': 5}),
#              'State': defaultdict(int, {'NOUN': 214}),
#              'concerned': defaultdict(int, {'VERB': 101}),
#              'shall': defaultdict(int, {'VERB': 203}),
#              'carried': defaultdict(int, {'VERB': 103}),
#              'out': defaultdict(int,
#                          {'PRT': 1304, 'ADP': 340, 'DET': 1, 'ADV': 1}),
#              'interest': defaultdict(int, {'NOUN': 252, 'VERB': 3}),
#              'achieving': defaultdict(int, {'VERB': 13}),
#              'objectives': defaultdict(int, {'NOUN': 32}),
#              'Act': defaultdict(int, {'NOUN': 91}),
#              'East': defaultdict(int, {'NOUN': 40, 'ADJ': 86}),
#              'creating': defaultdict(int, {'VERB': 23}),
#              'government': defaultdict(int, {'NOUN': 223}),
#              'doubtless': defaultdict(int, {'ADV': 9}),
#              'pay': defaultdict(int, {'VERB': 102, 'NOUN': 34}),
#              'Four': defaultdict(int, {'NUM': 23}),
#              'waitresses': defaultdict(int, {'NOUN': 1}),
#              'murdering': defaultdict(int, {'VERB': 2}),
#              'English': defaultdict(int, {'NOUN': 70, 'ADJ': 87}),
#              'counter': defaultdict(int, {'NOUN': 18, 'ADV': 3, 'VERB': 2}),
#              'Yuki': defaultdict(int, {'NOUN': 1}),
#              'Kobayashi': defaultdict(int, {'NOUN': 1}),
#              'happened': defaultdict(int, {'VERB': 110}),
#              'thought': defaultdict(int, {'VERB': 311, 'NOUN': 81}),
#              'wondered': defaultdict(int, {'VERB': 44}),
#              'what': defaultdict(int, {'DET': 1132}),
#              'kind': defaultdict(int, {'NOUN': 231, 'ADJ': 11}),
#              'homesteads': defaultdict(int, {'NOUN': 1}),
#              'such': defaultdict(int, {'ADJ': 732, 'PRT': 223, 'ADV': 13}),
#              'odd': defaultdict(int, {'ADJ': 33}),
#              'pioneers': defaultdict(int, {'NOUN': 1}),
#              'establish': defaultdict(int, {'VERB': 49}),
#              'suburban': defaultdict(int, {'ADJ': 26}),
#              'frontier': defaultdict(int, {'NOUN': 21}),
#              'Swadesh': defaultdict(int, {'NOUN': 7}),
#              'trying': defaultdict(int, {'VERB': 124, 'ADJ': 7}),
#              'basic': defaultdict(int, {'ADJ': 136}),
#              'list': defaultdict(int, {'NOUN': 102, 'VERB': 5}),
#              'universal': defaultdict(int, {'ADJ': 32}),
#              'knowledge': defaultdict(int, {'NOUN': 114}),
#              'modifies': defaultdict(int, {'VERB': 2}),
#              'dictates': defaultdict(int, {'VERB': 4, 'NOUN': 3}),
#              'diagnosis': defaultdict(int, {'NOUN': 9}),
#              'treatment': defaultdict(int, {'NOUN': 105}),
#              'Forty': defaultdict(int, {'NUM': 3}),
#              'miles': defaultdict(int, {'NOUN': 137}),
#              'farther': defaultdict(int, {'ADV': 26}),
#              'north': defaultdict(int, {'NOUN': 50, 'ADJ': 1}),
#              'Mount': defaultdict(int, {'NOUN': 13}),
#              'Moosilauke': defaultdict(int, {'NOUN': 1}),
#              "Dartmouth's": defaultdict(int, {'NOUN': 3}),
#              'mountain': defaultdict(int, {'NOUN': 21}),
#              'refine': defaultdict(int, {'VERB': 3}),
#              'extend': defaultdict(int, {'VERB': 23}),
#              'studying': defaultdict(int, {'VERB': 32}),
#              'individual': defaultdict(int, {'ADJ': 115, 'NOUN': 61}),
#              'Artie': defaultdict(int, {'NOUN': 7}),
#              'picked': defaultdict(int, {'VERB': 62}),
#              'snorkle': defaultdict(int, {'NOUN': 2}),
#              'twirling': defaultdict(int, {'VERB': 5}),
#              'forefinger': defaultdict(int, {'NOUN': 5}),
#              'atomic': defaultdict(int, {'ADJ': 26}),
#              'nucleus': defaultdict(int, {'NOUN': 10}),
#              'contains': defaultdict(int, {'VERB': 26}),
#              'positive': defaultdict(int, {'ADJ': 62, 'NOUN': 1}),
#              'charge': defaultdict(int, {'NOUN': 84, 'VERB': 12}),
#              'electricity': defaultdict(int, {'NOUN': 21}),
#              'holding': defaultdict(int, {'VERB': 41, 'NOUN': 4}),
#              'negatively': defaultdict(int, {'ADV': 2}),
#              'charged': defaultdict(int, {'VERB': 48}),
#              'electrons': defaultdict(int, {'NOUN': 7}),
#              'orbits': defaultdict(int, {'NOUN': 9}),
#              'motorist': defaultdict(int, {'NOUN': 1}),
#              'later': defaultdict(int, {'ADV': 248, 'ADJ': 46}),
#              'identified': defaultdict(int, {'VERB': 38}),
#              'Richard': defaultdict(int, {'NOUN': 56}),
#              'Sarkees': defaultdict(int, {'NOUN': 2}),
#              '17': defaultdict(int, {'NUM': 32}),
#              '2433': defaultdict(int, {'NUM': 1}),
#              'McClellan': defaultdict(int, {'NOUN': 11}),
#              'currently': defaultdict(int, {'ADV': 26}),
#              'probation': defaultdict(int, {'NOUN': 5}),
#              'under': defaultdict(int, {'ADP': 492, 'ADV': 9, 'ADJ': 1}),
#              'court': defaultdict(int, {'NOUN': 90, 'VERB': 1}),
#              'order': defaultdict(int, {'NOUN': 271, 'VERB': 12}),
#              'drive': defaultdict(int, {'VERB': 35, 'NOUN': 34}),
#              'Our': defaultdict(int, {'DET': 86}),
#              'necks': defaultdict(int, {'NOUN': 2}),
#              'stiff': defaultdict(int, {'ADJ': 16, 'NOUN': 1}),
#              'gazing': defaultdict(int, {'VERB': 5}),
#              'wonders': defaultdict(int, {'NOUN': 6, 'VERB': 1}),
#              'outer': defaultdict(int, {'ADJ': 22}),
#              'space': defaultdict(int, {'NOUN': 145}),
#              'captured': defaultdict(int, {'VERB': 16}),
#              'imagination': defaultdict(int, {'NOUN': 55}),
#              'American': defaultdict(int, {'ADJ': 421, 'NOUN': 28}),
#              'public': defaultdict(int, {'NOUN': 109, 'ADJ': 209}),
#              'My': defaultdict(int, {'DET': 122, 'NOUN': 2}),
#              "name's": defaultdict(int, {'PRT': 4}),
#              'Carla': defaultdict(int, {'NOUN': 12}),
#              'Caneli': defaultdict(int, {'NOUN': 1}),
#              'Beyond': defaultdict(int, {'ADP': 11, 'ADV': 2}),
#              'stockade': defaultdict(int, {'NOUN': 9}),
#              'rifles': defaultdict(int, {'NOUN': 18}),
#              'began': defaultdict(int, {'VERB': 248}),
#              'explode': defaultdict(int, {'VERB': 5}),
#              'some': defaultdict(int, {'DET': 1135, 'ADV': 15}),
#              'guerrillas': defaultdict(int, {'NOUN': 12}),
#              'fired': defaultdict(int, {'VERB': 35}),
#              'shadows': defaultdict(int, {'NOUN': 15}),
#              'imagined': defaultdict(int, {'VERB': 22}),
#              'Apaches': defaultdict(int, {'NOUN': 4}),
#              'deadlock': defaultdict(int, {'NOUN': 7}),
#              'has': defaultdict(int, {'VERB': 1925, 'X': 1}),
#              'caused': defaultdict(int, {'VERB': 72}),
#              "Russians'": defaultdict(int, {'NOUN': 1}),
#              'demand': defaultdict(int, {'NOUN': 59, 'VERB': 18}),
#              'three-man': defaultdict(int, {'ADJ': 2}),
#              'neutral': defaultdict(int, {'ADJ': 26}),
#              'directorate': defaultdict(int, {'NOUN': 4}),
#              'thus': defaultdict(int, {'ADV': 126}),
#              'veto': defaultdict(int, {'NOUN': 8, 'VERB': 1}),
#              'over': defaultdict(int, {'ADP': 676, 'PRT': 309, 'ADJ': 2}),
#              'machinery': defaultdict(int, {'NOUN': 46}),
#              "It's": defaultdict(int, {'PRT': 130}),
#              'added': defaultdict(int, {'VERB': 133}),
#              'There': defaultdict(int, {'PRT': 660, 'ADV': 33}),
#              'Hetty': defaultdict(int, {'NOUN': 2}),
#              'inevitably': defaultdict(int, {'ADV': 27}),
#              'unfavorable': defaultdict(int, {'ADJ': 5}),
#              'marked': defaultdict(int, {'VERB': 66}),
#              'contrast': defaultdict(int, {'NOUN': 57, 'VERB': 3}),
#              'amount': defaultdict(int, {'NOUN': 111, 'VERB': 24}),
#              'information': defaultdict(int, {'NOUN': 201}),
#              'bride': defaultdict(int, {'NOUN': 25}),
#              'groom': defaultdict(int, {'NOUN': 4}),
#              'suggests': defaultdict(int, {'VERB': 24}),
#              'Gore': defaultdict(int, {'NOUN': 6}),
#              'Court': defaultdict(int, {'NOUN': 87}),
#              'embodies': defaultdict(int, {'VERB': 3}),
#              'glories': defaultdict(int, {'NOUN': 3, 'VERB': 1}),
#              'Tudor': defaultdict(int, {'NOUN': 4}),
#              'splendor': defaultdict(int, {'NOUN': 6}),
#              'proposals': defaultdict(int, {'NOUN': 23}),
#              'go': defaultdict(int, {'VERB': 477}),
#              'far': defaultdict(int, {'ADV': 298, 'ADJ': 29}),
#              'toward': defaultdict(int, {'ADP': 312}),
#              'economic': defaultdict(int, {'ADJ': 174}),
#              'atmosphere': defaultdict(int, {'NOUN': 66}),
#              'favoring': defaultdict(int, {'VERB': 2}),
#              'turn': defaultdict(int, {'NOUN': 66, 'VERB': 111}),
#              'us': defaultdict(int, {'PRON': 527}),
#              'cope': defaultdict(int, {'VERB': 17}),
#              'runaway': defaultdict(int, {'ADJ': 4, 'VERB': 1, 'NOUN': 1}),
#              'technology': defaultdict(int, {'NOUN': 29}),
#              'No': defaultdict(int, {'ADV': 95, 'DET': 187}),
#              'One': defaultdict(int, {'NUM': 265, 'NOUN': 65}),
#              'Nikita': defaultdict(int, {'NOUN': 7}),
#              "Khrushchev's": defaultdict(int, {'NOUN': 11}),
#              'enthusiastic': defaultdict(int, {'ADJ': 17}),
#              'eulogizers': defaultdict(int, {'NOUN': 1}),
#              "U.S.S.R.'s": defaultdict(int, {'NOUN': 1}),
#              'daily': defaultdict(int, {'ADJ': 36, 'ADV': 40}),
#              'Izvestia': defaultdict(int, {'NOUN': 1}),
#              'enterprisingly': defaultdict(int, {'ADV': 1}),
#              'interviewed': defaultdict(int, {'VERB': 10}),
#              'Red-prone': defaultdict(int, {'ADJ': 1}),
#              'Comedian': defaultdict(int, {'NOUN': 1}),
#              'Charlie': defaultdict(int, {'NOUN': 41}),
#              'Chaplin': defaultdict(int, {'NOUN': 3}),
#              'Swiss': defaultdict(int, {'ADJ': 8, 'NOUN': 5}),
#              'villa': defaultdict(int, {'NOUN': 2}),
#              'self-exile': defaultdict(int, {'NOUN': 1}),
#              'Even': defaultdict(int, {'ADV': 150}),
#              'wanting': defaultdict(int, {'VERB': 11}),
#              'afraid': defaultdict(int, {'ADJ': 47}),
#              'knowing': defaultdict(int, {'VERB': 37, 'ADJ': 1}),
#              'how': defaultdict(int, {'ADV': 482}),
#              'press': defaultdict(int, {'VERB': 19, 'NOUN': 71}),
#              'suit': defaultdict(int, {'NOUN': 28, 'VERB': 8}),
#              'feared': defaultdict(int, {'VERB': 14}),
#              'evil': defaultdict(int, {'ADJ': 29, 'NOUN': 24}),
#              'presences': defaultdict(int, {'NOUN': 2}),
#              'metabolism': defaultdict(int, {'NOUN': 1}),
#              'Pasadena': defaultdict(int, {'NOUN': 5}),
#              'listings': defaultdict(int, {'NOUN': 1}),
#              'recently': defaultdict(int, {'ADV': 88}),
#              'unveiled': defaultdict(int, {'VERB': 2}),
#              'moves': defaultdict(int, {'NOUN': 8, 'VERB': 20}),
#              'international': defaultdict(int, {'ADJ': 88, 'NOUN': 1}),
#              'can': defaultdict(int, {'VERB': 1389, 'NOUN': 7, 'X': 1}),
#              'significant': defaultdict(int, {'ADJ': 70}),
#              'businessmen': defaultdict(int, {'NOUN': 11}),
#              'many': defaultdict(int, {'ADJ': 702, 'ADV': 7, 'PRT': 14}),
#              'lines': defaultdict(int, {'NOUN': 145, 'VERB': 1}),
#              'We': defaultdict(int, {'PRON': 551}),
#              'aim': defaultdict(int, {'VERB': 7, 'NOUN': 19}),
#              "t'": defaultdict(int, {'PRT': 1}),
#              'see-lective': defaultdict(int, {'ADJ': 1}),
#              "y'know": defaultdict(int, {'PRT': 1}),
#              '?': defaultdict(int, {'.': 3732, 'X': 1}),
#              'muttered': defaultdict(int, {'VERB': 12}),
#              'terrible': defaultdict(int, {'ADJ': 34, 'X': 1}),
#              'deliberate': defaultdict(int, {'ADJ': 12}),
#              'slowness': defaultdict(int, {'NOUN': 3}),
#              'elevator': defaultdict(int, {'NOUN': 11}),
#              'flew': defaultdict(int, {'VERB': 24}),
#              'making': defaultdict(int, {'VERB': 181, 'NOUN': 19}),
#              'adjustments': defaultdict(int, {'NOUN': 16}),
#              'obvious': defaultdict(int, {'ADJ': 73}),
#              'doing': defaultdict(int, {'VERB': 123, 'NOUN': 4}),
#              'fruit': defaultdict(int, {'NOUN': 24}),
#              'long': defaultdict(int, {'ADJ': 413, 'ADV': 161, 'VERB': 2}),
#              'Never': defaultdict(int, {'ADV': 27}),
#              "he'd": defaultdict(int, {'PRT': 62}),
#              'told': defaultdict(int, {'VERB': 320}),
#              'Joyce': defaultdict(int, {'NOUN': 18}),
#              'encountered': defaultdict(int, {'VERB': 27}),
#              'situation': defaultdict(int, {'NOUN': 163}),
#              'called': defaultdict(int, {'VERB': 305}),
#              'gun': defaultdict(int, {'NOUN': 72, 'VERB': 1}),
#              'Then': defaultdict(int, {'ADV': 274, 'X': 1, 'ADJ': 9}),
#              'replied': defaultdict(int, {'VERB': 48}),
#              'coldly': defaultdict(int, {'ADV': 6}),
#              'If': defaultdict(int, {'ADP': 586}),
#              'despise': defaultdict(int, {'VERB': 7}),
#              'directly': defaultdict(int, {'ADV': 109}),
#              'When': defaultdict(int, {'ADV': 460}),
#              'Negroes': defaultdict(int, {'NOUN': 47}),
#              'landed': defaultdict(int, {'VERB': 13}),
#              'Boston': defaultdict(int, {'NOUN': 53}),
#              'course': defaultdict(int, {'NOUN': 385}),
#              'longer': defaultdict(int, {'ADV': 105, 'ADJ': 55}),
#              'slaves': defaultdict(int, {'NOUN': 33}),
#              'All': defaultdict(int, {'PRT': 168, 'ADV': 47}),
#              'outside': defaultdict(int,
#                          {'ADP': 65, 'ADV': 39, 'NOUN': 15, 'ADJ': 30}),
#              'bubbles': defaultdict(int, {'NOUN': 11, 'VERB': 1}),
#              'last': defaultdict(int,
#                          {'VERB': 19, 'ADJ': 462, 'ADV': 24, 'NOUN': 8}),
#              'night': defaultdict(int, {'NOUN': 324}),
#              'sentient': defaultdict(int, {'ADJ': 2}),
#              'being': defaultdict(int, {'NOUN': 22, 'VERB': 522, 'X': 1}),
#              'came': defaultdict(int, {'VERB': 516}),
#              'alarm': defaultdict(int, {'NOUN': 14, 'VERB': 2}),
#              'web': defaultdict(int, {'NOUN': 5}),
#              'planners': defaultdict(int, {'NOUN': 10}),
#              'Taiwan': defaultdict(int, {'NOUN': 5}),
#              'struck': defaultdict(int, {'VERB': 46}),
#              'realistic': defaultdict(int, {'ADJ': 32}),
#              'men': defaultdict(int, {'NOUN': 583}),
#              'Most': defaultdict(int, {'ADJ': 72, 'ADV': 7}),
#              'U.S.': defaultdict(int, {'NOUN': 125}),
#              'Senate': defaultdict(int, {'NOUN': 47}),
#              'human': defaultdict(int, {'ADJ': 208, 'NOUN': 29}),
#              'high': defaultdict(int, {'ADV': 27, 'ADJ': 336, 'NOUN': 7}),
#              'hog': defaultdict(int, {'NOUN': 2}),
#              'Jackson': defaultdict(int, {'NOUN': 31}),
#              'political': defaultdict(int, {'ADJ': 199}),
#              'Rusk': defaultdict(int, {'NOUN': 8}),
#              'rid': defaultdict(int, {'ADJ': 12, 'VERB': 4}),
#              'department': defaultdict(int, {'NOUN': 45}),
#              'personnel': defaultdict(int, {'NOUN': 59, 'X': 1}),
#              'engaged': defaultdict(int, {'VERB': 35}),
#              ...})

# %% [markdown]
# Let's produce a dictionary where words (keys) are associated with their ***most frequent*** POS tag:

# %%
mfc_table = dict((word, max(tags.keys(), key=lambda key: tags[key])) for word, tags in word_counts.items())
mfc_table
# Out:
# {'Whenever': 'ADV',
#  'artists': 'NOUN',
#  ',': '.',
#  'indeed': 'ADV',
#  'turned': 'VERB',
#  'to': 'PRT',
#  'actual': 'ADJ',
#  'representations': 'NOUN',
#  'or': 'CONJ',
#  'molded': 'VERB',
#  'three-dimensional': 'ADJ',
#  'figures': 'NOUN',
#  'which': 'DET',
#  'were': 'VERB',
#  'rare': 'ADJ',
#  'down': 'PRT',
#  '800': 'NUM',
#  'B.C.': 'NOUN',
#  'they': 'PRON',
#  'tended': 'VERB',
#  'reflect': 'VERB',
#  'reality': 'NOUN',
#  '(': '.',
#  'see': 'VERB',
#  'Plate': 'NOUN',
#  '6a': 'NUM',
#  '9b': 'NUM',
#  ')': '.',
#  ';': '.',
#  'For': 'ADP',
#  'almost': 'ADV',
#  'two': 'NUM',
#  'months': 'NOUN',
#  'the': 'DET',
#  'defendant': 'NOUN',
#  'and': 'CONJ',
#  'world': 'NOUN',
#  'heard': 'VERB',
#  'from': 'ADP',
#  'individuals': 'NOUN',
#  'escaped': 'VERB',
#  'grave': 'ADJ',
#  'about': 'ADP',
#  'fathers': 'NOUN',
#  'mothers': 'NOUN',
#  'graybeards': 'NOUN',
#  'adolescents': 'NOUN',
#  'babies': 'NOUN',
#  'starved': 'VERB',
#  'beaten': 'VERB',
#  'death': 'NOUN',
#  'strangled': 'VERB',
#  'machine-gunned': 'VERB',
#  'gassed': 'VERB',
#  'burned': 'VERB',
#  '.': '.',
#  'Clearer': 'ADJ',
#  'meaning': 'NOUN',
#  'Yes': 'ADV',
#  'gentlemen': 'NOUN',
#  'I': 'PRON',
#  'am': 'VERB',
#  'getting': 'VERB',
#  'point': 'NOUN',
#  'my': 'DET',
#  'About': 'ADV',
#  'same': 'ADJ',
#  'time': 'NOUN',
#  'Alleghenies': 'NOUN',
#  'Poconos': 'NOUN',
#  'in': 'ADP',
#  'Pennsylvania': 'NOUN',
#  'are': 'VERB',
#  'magnificent': 'ADJ',
#  '--': '.',
#  'Renovo': 'NOUN',
#  'holds': 'VERB',
#  'its': 'DET',
#  'annual': 'ADJ',
#  'Flaming': 'VERB',
#  'Foliage': 'NOUN',
#  'Festival': 'NOUN',
#  'on': 'ADP',
#  'Oct.': 'NOUN',
#  '14': 'NUM',
#  '15': 'NUM',
#  "There's": 'PRT',
#  'no': 'DET',
#  'doubt': 'NOUN',
#  'this': 'DET',
#  'Tim': 'NOUN',
#  'sneaked': 'VERB',
#  'back': 'ADV',
#  'killed': 'VERB',
#  'Mrs.': 'NOUN',
#  'Buck': 'NOUN',
#  'The': 'DET',
#  "cowboy's": 'NOUN',
#  'humorous': 'ADJ',
#  'name': 'NOUN',
#  'for': 'ADP',
#  'a': 'DET',
#  'cow': 'NOUN',
#  "givin'": 'VERB',
#  'milk': 'NOUN',
#  'was': 'VERB',
#  '``': '.',
#  'pitcher': 'NOUN',
#  "''": '.',
#  'It': 'PRON',
#  'is': 'VERB',
#  'therefore': 'ADV',
#  'not': 'ADV',
#  'surprising': 'ADJ',
#  'that': 'ADP',
#  'resist': 'VERB',
#  'lure': 'NOUN',
#  'of': 'ADP',
#  'marriage': 'NOUN',
#  'trap': 'NOUN',
#  'domesticity': 'NOUN',
#  'like': 'ADP',
#  'cats': 'NOUN',
#  'determined': 'VERB',
#  'tame': 'ADJ',
#  'their': 'DET',
#  'sexual': 'ADJ',
#  'energy': 'NOUN',
#  'A': 'DET',
#  'shielded': 'VERB',
#  'thermocouple': 'NOUN',
#  'used': 'VERB',
#  'measure': 'NOUN',
#  'upstream': 'ADV',
#  'temperature': 'NOUN',
#  'transpiring': 'VERB',
#  'gas': 'NOUN',
#  'ideals': 'NOUN',
#  'country': 'NOUN',
#  'deeply': 'ADV',
#  'indebted': 'ADJ',
#  'Protestantism': 'NOUN',
#  'older': 'ADJ',
#  'stock': 'NOUN',
#  'Matsuo': 'NOUN',
#  'laughed': 'VERB',
#  'slung': 'VERB',
#  'rifle': 'NOUN',
#  'Rousseau': 'NOUN',
#  'asked': 'VERB',
#  'Dave': 'NOUN',
#  'Trager': 'NOUN',
#  'who': 'PRON',
#  'quite': 'ADV',
#  'showman': 'NOUN',
#  'boss': 'NOUN',
#  "Chicago's": 'NOUN',
#  'new': 'ADJ',
#  'pro': 'ADP',
#  'basketball': 'NOUN',
#  'Packers': 'NOUN',
#  'debuting': 'VERB',
#  'International': 'ADJ',
#  'club': 'NOUN',
#  'exclusive': 'ADJ',
#  'use': 'NOUN',
#  'season': 'NOUN',
#  'ticket': 'NOUN',
#  'holders': 'NOUN',
#  'Stock': 'NOUN',
#  'Yards': 'NOUN',
#  'Inn': 'NOUN',
#  'While': 'ADP',
#  'he': 'PRON',
#  'waited': 'VERB',
#  'living': 'VERB',
#  'room': 'NOUN',
#  'Frank': 'NOUN',
#  'Graham': 'NOUN',
#  'Journal-American': 'NOUN',
#  'sports': 'NOUN',
#  'columnist': 'NOUN',
#  'Health': 'NOUN',
#  'excellent': 'ADJ',
#  'Serenity': 'NOUN',
#  'if': 'ADP',
#  'one': 'NUM',
#  'fortunate': 'ADJ',
#  'enough': 'ADV',
#  'achieve': 'VERB',
#  'it': 'PRON',
#  'so': 'ADV',
#  'good': 'ADJ',
#  'as': 'ADP',
#  'joy': 'NOUN',
#  'but': 'CONJ',
#  'something': 'NOUN',
#  'should': 'VERB',
#  'have': 'VERB',
#  'dramatic': 'ADJ',
#  'form': 'NOUN',
#  'with': 'ADP',
#  'pleasing': 'ADJ',
#  'language': 'NOUN',
#  'portray': 'VERB',
#  'incidents': 'NOUN',
#  'arouse': 'VERB',
#  'pity': 'NOUN',
#  'fear': 'NOUN',
#  'purges': 'NOUN',
#  'these': 'DET',
#  'emotions': 'NOUN',
#  'audience': 'NOUN',
#  'She': 'PRON',
#  'worked': 'VERB',
#  'domestic': 'ADJ',
#  'first': 'ADJ',
#  'Newport': 'NOUN',
#  'year': 'NOUN',
#  'then': 'ADV',
#  'South': 'NOUN',
#  'Bethlehem': 'NOUN',
#  'another': 'DET',
#  'These': 'DET',
#  'tests': 'NOUN',
#  'accelerated': 'VERB',
#  'must': 'VERB',
#  'be': 'VERB',
#  'repeated': 'VERB',
#  'evaluate': 'VERB',
#  'dimensional': 'ADJ',
#  'changes': 'NOUN',
#  'after': 'ADP',
#  'launderings': 'NOUN',
#  'Mr.': 'NOUN',
#  'Hammarskjold': 'NOUN',
#  'removes': 'VERB',
#  'United': 'VERB',
#  "Nations'": 'NOUN',
#  'most': 'ADV',
#  'controversial': 'ADJ',
#  'leader': 'NOUN',
#  'Meanwhile': 'ADV',
#  'experts': 'NOUN',
#  'speak': 'VERB',
#  'wars': 'NOUN',
#  'triggered': 'VERB',
#  'by': 'ADP',
#  'false': 'ADJ',
#  'pre-emption': 'NOUN',
#  'escalation': 'NOUN',
#  'unauthorized': 'ADJ',
#  'behavior': 'NOUN',
#  'other': 'ADJ',
#  'terms': 'NOUN',
#  'will': 'VERB',
#  'discussed': 'VERB',
#  'report': 'NOUN',
#  'King': 'NOUN',
#  'Arthur': 'NOUN',
#  'had': 'VERB',
#  'fifty-four': 'NUM',
#  'overnighters': 'NOUN',
#  'again': 'ADV',
#  'counting': 'VERB',
#  'rooms': 'NOUN',
#  'rather': 'ADV',
#  'than': 'ADP',
#  'people': 'NOUN',
#  'Inside': 'ADV',
#  'pieces': 'NOUN',
#  'glazed': 'VERB',
#  'three': 'NUM',
#  'coats': 'NOUN',
#  'Creek-Turn': 'NOUN',
#  'bottle': 'NOUN',
#  'green': 'ADJ',
#  'antique': 'NOUN',
#  'glaze': 'NOUN',
#  'But': 'CONJ',
#  'our': 'DET',
#  'health': 'NOUN',
#  'more': 'ADV',
#  'precious': 'ADJ',
#  'all': 'PRT',
#  'money': 'NOUN',
#  'modern': 'ADJ',
#  'witch': 'NOUN',
#  'doctors': 'NOUN',
#  'fake': 'ADJ',
#  'therapeutic': 'ADJ',
#  'gadgets': 'NOUN',
#  'gambling': 'VERB',
#  'away': 'ADV',
#  'Over': 'ADP',
#  '4': 'NUM',
#  'million': 'NUM',
#  'shares': 'NOUN',
#  'sold': 'VERB',
#  'highest': 'ADJ',
#  'since': 'ADP',
#  'early': 'ADJ',
#  'June': 'NOUN',
#  'He': 'PRON',
#  'did': 'VERB',
#  'say': 'VERB',
#  'she': 'PRON',
#  'could': 'VERB',
#  'get': 'VERB',
#  'her': 'DET',
#  'beef': 'NOUN',
#  'vegetables': 'NOUN',
#  'cans': 'NOUN',
#  'summer': 'NOUN',
#  'Washington': 'NOUN',
#  'Feb.': 'NOUN',
#  '9': 'NUM',
#  'supplier': 'NOUN',
#  'delivers': 'VERB',
#  'at': 'ADP',
#  'his': 'DET',
#  'convenience': 'NOUN',
#  'transport': 'NOUN',
#  'loads': 'NOUN',
#  'maintain': 'VERB',
#  'two-to-three': 'NUM',
#  'weeks': 'NOUN',
#  'reserve': 'NOUN',
#  'supply': 'NOUN',
#  'against': 'ADP',
#  'weather': 'NOUN',
#  'contingencies': 'NOUN',
#  'On': 'ADP',
#  'way': 'NOUN',
#  'airport': 'NOUN',
#  'Paris': 'NOUN',
#  'you': 'PRON',
#  'bet': 'VERB',
#  'Lucy': 'NOUN',
#  'said': 'VERB',
#  'herself': 'PRON',
#  'when': 'ADV',
#  'Gloriana': 'NOUN',
#  'rides': 'NOUN',
#  'them': 'PRON',
#  'also': 'ADV',
#  'take': 'VERB',
#  'girls': 'NOUN',
#  'usually': 'ADV',
#  'ride': 'VERB',
#  'little': 'ADJ',
#  'car': 'NOUN',
#  "isn't": 'VERB',
#  'big': 'ADJ',
#  'carrots': 'NOUN',
#  'sometimes': 'ADV',
#  "don't": 'VERB',
#  'make': 'VERB',
#  'through': 'ADP',
#  'winter': 'NOUN',
#  'Fearful': 'ADJ',
#  'inviting': 'VERB',
#  'military': 'ADJ',
#  'showdown': 'NOUN',
#  'West': 'NOUN',
#  'win': 'VERB',
#  'Communists': 'NOUN',
#  'seek': 'VERB',
#  'undermine': 'VERB',
#  'Western': 'ADJ',
#  'power': 'NOUN',
#  'where': 'ADV',
#  'nuclear': 'ADJ',
#  'might': 'VERB',
#  'irrelevant': 'ADJ',
#  'backwoods': 'NOUN',
#  'guerrilla': 'NOUN',
#  'skirmishes': 'NOUN',
#  'mob': 'NOUN',
#  'uprisings': 'NOUN',
#  'streets': 'NOUN',
#  'parliaments': 'NOUN',
#  'clandestine': 'ADJ',
#  'meetings': 'NOUN',
#  'undercover': 'ADJ',
#  'conspirators': 'NOUN',
#  'Nations': 'NOUN',
#  'propaganda': 'NOUN',
#  'front': 'NOUN',
#  'diplomatic': 'ADJ',
#  'conferences': 'NOUN',
#  'preferably': 'ADV',
#  'level': 'NOUN',
#  'Today': 'NOUN',
#  'thousand': 'NUM',
#  'industries': 'NOUN',
#  'distribute': 'VERB',
#  'me': 'PRON',
#  'employees': 'NOUN',
#  'loss': 'NOUN',
#  'growth': 'NOUN',
#  'sawtimber': 'NOUN',
#  'because': 'ADP',
#  'damage': 'NOUN',
#  'destructive': 'ADJ',
#  'agencies': 'NOUN',
#  'States': 'NOUN',
#  '1952': 'NUM',
#  'estimated': 'VERB',
#  '44': 'NUM',
#  'billion': 'NUM',
#  'board': 'NOUN',
#  'feet': 'NOUN',
#  'Pretty': 'ADV',
#  'among': 'ADP',
#  'blonde': 'ADJ',
#  'hair': 'NOUN',
#  'pert': 'ADJ',
#  'faces': 'NOUN',
#  'Their': 'DET',
#  'study': 'NOUN',
#  'showed': 'VERB',
#  'possible': 'ADJ',
#  'transfer': 'NOUN',
#  '3': 'NUM',
#  'lb': 'NOUN',
#  'oxygen': 'NOUN',
#  '/': 'ADP',
#  'hr.': 'NOUN',
#  'hp.': 'NOUN',
#  'Haney': 'NOUN',
#  'scowled': 'VERB',
#  'As': 'ADP',
#  'seen': 'VERB',
#  'B.': 'NOUN',
#  'family': 'NOUN',
#  'there': 'PRT',
#  'an': 'DET',
#  'attempt': 'NOUN',
#  'help': 'VERB',
#  'client': 'NOUN',
#  'develop': 'VERB',
#  'conscious': 'ADJ',
#  'awareness': 'NOUN',
#  'problem': 'NOUN',
#  'especially': 'ADV',
#  'absence': 'NOUN',
#  'formal': 'ADJ',
#  'request': 'NOUN',
#  'assistance': 'NOUN',
#  'crawled': 'VERB',
#  'into': 'ADP',
#  'bed': 'NOUN',
#  'switched': 'VERB',
#  'off': 'PRT',
#  'light': 'NOUN',
#  'Buckley': 'NOUN',
#  'seems': 'VERB',
#  'assumed': 'VERB',
#  'would': 'VERB',
#  'given': 'VERB',
#  'right': 'ADJ',
#  'pick': 'VERB',
#  "Gerosa's": 'NOUN',
#  'successor': 'NOUN',
#  'This': 'DET',
#  'manifestly': 'ADV',
#  'provide': 'VERB',
#  '$5000': 'NOUN',
#  'each': 'DET',
#  'surviving': 'VERB',
#  'five': 'NUM',
#  'children': 'NOUN',
#  'What': 'DET',
#  'seem': 'VERB',
#  'realize': 'VERB',
#  "aren't": 'VERB',
#  'tied': 'VERB',
#  'up': 'PRT',
#  'thing': 'NOUN',
#  '90%': 'NOUN',
#  'transportation': 'NOUN',
#  'know': 'VERB',
#  'now': 'ADV',
#  'why': 'ADV',
#  'Japanese': 'ADJ',
#  'friends': 'NOUN',
#  'surprised': 'VERB',
#  'walked': 'VERB',
#  'bathroom': 'NOUN',
#  'let': 'VERB',
#  'eyelids': 'NOUN',
#  'droop': 'VERB',
#  'breathed': 'VERB',
#  'heavily': 'ADV',
#  'feigning': 'VERB',
#  'sleep': 'NOUN',
#  'meantime': 'NOUN',
#  'beer-runner': 'NOUN',
#  'unhappy': 'ADJ',
#  'solution': 'NOUN',
#  'telephoned': 'VERB',
#  'Torrio': 'NOUN',
#  'returned': 'VERB',
#  "O'Banion": 'NOUN',
#  'message': 'NOUN',
#  ':': '.',
#  'Say': 'VERB',
#  'Dionie': 'NOUN',
#  'just': 'ADV',
#  'been': 'VERB',
#  'talking': 'VERB',
#  'Johnny': 'NOUN',
#  'cops': 'NOUN',
#  'hundred': 'NUM',
#  'hit': 'VERB',
#  'him': 'PRON',
#  'ass': 'NOUN',
#  'once': 'ADV',
#  'obligation': 'NOUN',
#  'pertains': 'VERB',
#  'only': 'ADV',
#  'countries': 'NOUN',
#  'honestly': 'ADV',
#  'seeking': 'VERB',
#  'become': 'VERB',
#  'responsible': 'ADJ',
#  'members': 'NOUN',
#  'stable': 'ADJ',
#  'forward-moving': 'ADJ',
#  'community': 'NOUN',
#  "I've": 'PRT',
#  'got': 'VERB',
#  'cold': 'ADJ',
#  'advantage': 'NOUN',
#  'having': 'VERB',
#  'firm': 'NOUN',
#  'Tri-State': 'ADJ',
#  'headed': 'VERB',
#  'lawyer': 'NOUN',
#  'Day': 'NOUN',
#  'day': 'NOUN',
#  'week': 'NOUN',
#  'month': 'NOUN',
#  'betrayal': 'NOUN',
#  'gnawed': 'VERB',
#  "Andrei's": 'NOUN',
#  'heart': 'NOUN',
#  'B': 'NOUN',
#  'need': 'VERB',
#  'plan': 'NOUN',
#  'investment': 'NOUN',
#  'programs': 'NOUN',
#  'His': 'DET',
#  'small': 'ADJ',
#  'mean': 'VERB',
#  'eyes': 'NOUN',
#  'regarded': 'VERB',
#  'Marty': 'NOUN',
#  'steadily': 'ADV',
#  'unblinkingly': 'ADV',
#  'Just': 'ADV',
#  'evocations': 'NOUN',
#  'place': 'NOUN',
#  'passionate': 'ADJ',
#  'encounter': 'NOUN',
#  'between': 'ADP',
#  'man': 'NOUN',
#  'natural': 'ADJ',
#  'today': 'NOUN',
#  'lost': 'VERB',
#  'Both': 'DET',
#  'those': 'DET',
#  'dynamic': 'ADJ',
#  'run-ups': 'NOUN',
#  'price': 'NOUN',
#  'market': 'NOUN',
#  'recent': 'ADJ',
#  'both': 'DET',
#  'selling': 'VERB',
#  'higher': 'ADJ',
#  'price-earnings': 'NOUN',
#  'yield': 'NOUN',
#  'bases': 'NOUN',
#  'Morton': 'NOUN',
#  'coming': 'VERB',
#  'everyone': 'NOUN',
#  'knew': 'VERB',
#  'anything': 'NOUN',
#  'expected': 'VERB',
#  'fast': 'ADV',
#  'run-up': 'NOUN',
#  'Dr.': 'NOUN',
#  'Karlis': 'NOUN',
#  'Osis': 'NOUN',
#  'Director': 'NOUN',
#  'Research': 'NOUN',
#  'Parapsychology': 'NOUN',
#  'Foundation': 'NOUN',
#  'described': 'VERB',
#  'basis': 'NOUN',
#  'experiment': 'NOUN',
#  'tomorrow': 'NOUN',
#  'article': 'NOUN',
#  'New': 'ADJ',
#  'Survival': 'NOUN',
#  'After': 'ADP',
#  'Death': 'NOUN',
#  'Spring': 'NOUN',
#  '1958': 'NUM',
#  'else': 'ADV',
#  'rattle': 'NOUN',
#  'gunfire': 'NOUN',
#  'sides': 'NOUN',
#  'discussion': 'NOUN',
#  'optimal': 'ADJ',
#  'policy': 'NOUN',
#  'outcome': 'NOUN',
#  'stage': 'NOUN',
#  'known': 'VERB',
#  'before': 'ADP',
#  'passing': 'VERB',
#  'next': 'ADJ',
#  'very': 'ADV',
#  'much': 'ADJ',
#  'difficult': 'ADJ',
#  'matter': 'NOUN',
#  'At': 'ADP',
#  'beginning': 'NOUN',
#  'school': 'NOUN',
#  'students': 'NOUN',
#  'eat': 'VERB',
#  'cereal': 'NOUN',
#  'within': 'ADP',
#  'short': 'ADJ',
#  'eating': 'VERB',
#  'voraciously': 'ADV',
#  'picnic': 'NOUN',
#  'bag': 'NOUN',
#  'grill': 'NOUN',
#  'cooler': 'ADJ',
#  'soft': 'ADJ',
#  'drinks': 'NOUN',
#  'beer': 'NOUN',
#  'frozen': 'VERB',
#  'foods': 'NOUN',
#  'Sunday': 'NOUN',
#  'evening': 'NOUN',
#  'program': 'NOUN',
#  'provides': 'VERB',
#  'theological': 'ADJ',
#  'lectures': 'NOUN',
#  'music': 'NOUN',
#  'drama': 'NOUN',
#  'films': 'NOUN',
#  'related': 'VERB',
#  'issues': 'NOUN',
#  'Judeo-Christian': 'ADJ',
#  'tradition': 'NOUN',
#  "Williams's": 'NOUN',
#  'well': 'ADV',
#  'included': 'VERB',
#  'felt': 'VERB',
#  'They': 'PRON',
#  'unspoken': 'ADJ',
#  'support': 'NOUN',
#  'President-elect': 'NOUN',
#  'Kennedy': 'NOUN',
#  'whose': 'DET',
#  'own': 'ADJ',
#  'legislative': 'ADJ',
#  'menaced': 'VERB',
#  'Rules': 'NOUN',
#  'Committee': 'NOUN',
#  'bottleneck': 'NOUN',
#  'scope': 'NOUN',
#  'elaborate': 'ADJ',
#  'any': 'DET',
#  'great': 'ADJ',
#  'detail': 'NOUN',
#  'upon': 'ADP',
#  'special': 'ADJ',
#  'districts': 'NOUN',
#  'Rhode': 'NOUN',
#  'Island': 'NOUN',
#  'To': 'PRT',
#  'prepare': 'VERB',
#  'latter': 'ADJ',
#  'silver': 'NOUN',
#  'chloride': 'NOUN',
#  'precipitated': 'VERB',
#  'containing': 'VERB',
#  'Af': 'NOUN',
#  'obtained': 'VERB',
#  'Oak': 'NOUN',
#  'Ridge': 'NOUN',
#  'National': 'ADJ',
#  'Laboratory': 'NOUN',
#  'Church': 'NOUN',
#  'loses': 'VERB',
#  'pace': 'NOUN',
#  'purpose': 'NOUN',
#  'conference': 'NOUN',
#  'certain': 'ADJ',
#  'low-wage': 'NOUN',
#  'control': 'NOUN',
#  'textile': 'NOUN',
#  'exports': 'NOUN',
#  'dumping': 'NOUN',
#  'specific': 'ADJ',
#  'products': 'NOUN',
#  'high-wage': 'NOUN',
#  'textile-producing': 'ADJ',
#  'Because': 'ADP',
#  'wealth': 'NOUN',
#  'experience': 'NOUN',
#  'Organization': 'NOUN',
#  'European': 'ADJ',
#  'Economic': 'ADJ',
#  'Cooperation': 'NOUN',
#  'initial': 'ADJ',
#  'studies': 'NOUN',
#  'needed': 'VERB',
#  'face': 'NOUN',
#  'employs': 'VERB',
#  'deductive': 'ADJ',
#  'techniques': 'NOUN',
#  'alien': 'ADJ',
#  'official': 'ADJ',
#  'police': 'NOUN',
#  'routine': 'NOUN',
#  'fullest': 'ADJ',
#  'cooperation': 'NOUN',
#  'Atomic': 'ADJ',
#  'Energy': 'NOUN',
#  'Commission': 'NOUN',
#  'Department': 'NOUN',
#  'Education': 'NOUN',
#  'Welfare': 'NOUN',
#  'State': 'NOUN',
#  'concerned': 'VERB',
#  'shall': 'VERB',
#  'carried': 'VERB',
#  'out': 'PRT',
#  'interest': 'NOUN',
#  'achieving': 'VERB',
#  'objectives': 'NOUN',
#  'Act': 'NOUN',
#  'East': 'ADJ',
#  'creating': 'VERB',
#  'government': 'NOUN',
#  'doubtless': 'ADV',
#  'pay': 'VERB',
#  'Four': 'NUM',
#  'waitresses': 'NOUN',
#  'murdering': 'VERB',
#  'English': 'ADJ',
#  'counter': 'NOUN',
#  'Yuki': 'NOUN',
#  'Kobayashi': 'NOUN',
#  'happened': 'VERB',
#  'thought': 'VERB',
#  'wondered': 'VERB',
#  'what': 'DET',
#  'kind': 'NOUN',
#  'homesteads': 'NOUN',
#  'such': 'ADJ',
#  'odd': 'ADJ',
#  'pioneers': 'NOUN',
#  'establish': 'VERB',
#  'suburban': 'ADJ',
#  'frontier': 'NOUN',
#  'Swadesh': 'NOUN',
#  'trying': 'VERB',
#  'basic': 'ADJ',
#  'list': 'NOUN',
#  'universal': 'ADJ',
#  'knowledge': 'NOUN',
#  'modifies': 'VERB',
#  'dictates': 'VERB',
#  'diagnosis': 'NOUN',
#  'treatment': 'NOUN',
#  'Forty': 'NUM',
#  'miles': 'NOUN',
#  'farther': 'ADV',
#  'north': 'NOUN',
#  'Mount': 'NOUN',
#  'Moosilauke': 'NOUN',
#  "Dartmouth's": 'NOUN',
#  'mountain': 'NOUN',
#  'refine': 'VERB',
#  'extend': 'VERB',
#  'studying': 'VERB',
#  'individual': 'ADJ',
#  'Artie': 'NOUN',
#  'picked': 'VERB',
#  'snorkle': 'NOUN',
#  'twirling': 'VERB',
#  'forefinger': 'NOUN',
#  'atomic': 'ADJ',
#  'nucleus': 'NOUN',
#  'contains': 'VERB',
#  'positive': 'ADJ',
#  'charge': 'NOUN',
#  'electricity': 'NOUN',
#  'holding': 'VERB',
#  'negatively': 'ADV',
#  'charged': 'VERB',
#  'electrons': 'NOUN',
#  'orbits': 'NOUN',
#  'motorist': 'NOUN',
#  'later': 'ADV',
#  'identified': 'VERB',
#  'Richard': 'NOUN',
#  'Sarkees': 'NOUN',
#  '17': 'NUM',
#  '2433': 'NUM',
#  'McClellan': 'NOUN',
#  'currently': 'ADV',
#  'probation': 'NOUN',
#  'under': 'ADP',
#  'court': 'NOUN',
#  'order': 'NOUN',
#  'drive': 'VERB',
#  'Our': 'DET',
#  'necks': 'NOUN',
#  'stiff': 'ADJ',
#  'gazing': 'VERB',
#  'wonders': 'NOUN',
#  'outer': 'ADJ',
#  'space': 'NOUN',
#  'captured': 'VERB',
#  'imagination': 'NOUN',
#  'American': 'ADJ',
#  'public': 'ADJ',
#  'My': 'DET',
#  "name's": 'PRT',
#  'Carla': 'NOUN',
#  'Caneli': 'NOUN',
#  'Beyond': 'ADP',
#  'stockade': 'NOUN',
#  'rifles': 'NOUN',
#  'began': 'VERB',
#  'explode': 'VERB',
#  'some': 'DET',
#  'guerrillas': 'NOUN',
#  'fired': 'VERB',
#  'shadows': 'NOUN',
#  'imagined': 'VERB',
#  'Apaches': 'NOUN',
#  'deadlock': 'NOUN',
#  'has': 'VERB',
#  'caused': 'VERB',
#  "Russians'": 'NOUN',
#  'demand': 'NOUN',
#  'three-man': 'ADJ',
#  'neutral': 'ADJ',
#  'directorate': 'NOUN',
#  'thus': 'ADV',
#  'veto': 'NOUN',
#  'over': 'ADP',
#  'machinery': 'NOUN',
#  "It's": 'PRT',
#  'added': 'VERB',
#  'There': 'PRT',
#  'Hetty': 'NOUN',
#  'inevitably': 'ADV',
#  'unfavorable': 'ADJ',
#  'marked': 'VERB',
#  'contrast': 'NOUN',
#  'amount': 'NOUN',
#  'information': 'NOUN',
#  'bride': 'NOUN',
#  'groom': 'NOUN',
#  'suggests': 'VERB',
#  'Gore': 'NOUN',
#  'Court': 'NOUN',
#  'embodies': 'VERB',
#  'glories': 'NOUN',
#  'Tudor': 'NOUN',
#  'splendor': 'NOUN',
#  'proposals': 'NOUN',
#  'go': 'VERB',
#  'far': 'ADV',
#  'toward': 'ADP',
#  'economic': 'ADJ',
#  'atmosphere': 'NOUN',
#  'favoring': 'VERB',
#  'turn': 'VERB',
#  'us': 'PRON',
#  'cope': 'VERB',
#  'runaway': 'ADJ',
#  'technology': 'NOUN',
#  'No': 'DET',
#  'One': 'NUM',
#  'Nikita': 'NOUN',
#  "Khrushchev's": 'NOUN',
#  'enthusiastic': 'ADJ',
#  'eulogizers': 'NOUN',
#  "U.S.S.R.'s": 'NOUN',
#  'daily': 'ADV',
#  'Izvestia': 'NOUN',
#  'enterprisingly': 'ADV',
#  'interviewed': 'VERB',
#  'Red-prone': 'ADJ',
#  'Comedian': 'NOUN',
#  'Charlie': 'NOUN',
#  'Chaplin': 'NOUN',
#  'Swiss': 'ADJ',
#  'villa': 'NOUN',
#  'self-exile': 'NOUN',
#  'Even': 'ADV',
#  'wanting': 'VERB',
#  'afraid': 'ADJ',
#  'knowing': 'VERB',
#  'how': 'ADV',
#  'press': 'NOUN',
#  'suit': 'NOUN',
#  'feared': 'VERB',
#  'evil': 'ADJ',
#  'presences': 'NOUN',
#  'metabolism': 'NOUN',
#  'Pasadena': 'NOUN',
#  'listings': 'NOUN',
#  'recently': 'ADV',
#  'unveiled': 'VERB',
#  'moves': 'VERB',
#  'international': 'ADJ',
#  'can': 'VERB',
#  'significant': 'ADJ',
#  'businessmen': 'NOUN',
#  'many': 'ADJ',
#  'lines': 'NOUN',
#  'We': 'PRON',
#  'aim': 'NOUN',
#  "t'": 'PRT',
#  'see-lective': 'ADJ',
#  "y'know": 'PRT',
#  '?': '.',
#  'muttered': 'VERB',
#  'terrible': 'ADJ',
#  'deliberate': 'ADJ',
#  'slowness': 'NOUN',
#  'elevator': 'NOUN',
#  'flew': 'VERB',
#  'making': 'VERB',
#  'adjustments': 'NOUN',
#  'obvious': 'ADJ',
#  'doing': 'VERB',
#  'fruit': 'NOUN',
#  'long': 'ADJ',
#  'Never': 'ADV',
#  "he'd": 'PRT',
#  'told': 'VERB',
#  'Joyce': 'NOUN',
#  'encountered': 'VERB',
#  'situation': 'NOUN',
#  'called': 'VERB',
#  'gun': 'NOUN',
#  'Then': 'ADV',
#  'replied': 'VERB',
#  'coldly': 'ADV',
#  'If': 'ADP',
#  'despise': 'VERB',
#  'directly': 'ADV',
#  'When': 'ADV',
#  'Negroes': 'NOUN',
#  'landed': 'VERB',
#  'Boston': 'NOUN',
#  'course': 'NOUN',
#  'longer': 'ADV',
#  'slaves': 'NOUN',
#  'All': 'PRT',
#  'outside': 'ADP',
#  'bubbles': 'NOUN',
#  'last': 'ADJ',
#  'night': 'NOUN',
#  'sentient': 'ADJ',
#  'being': 'VERB',
#  'came': 'VERB',
#  'alarm': 'NOUN',
#  'web': 'NOUN',
#  'planners': 'NOUN',
#  'Taiwan': 'NOUN',
#  'struck': 'VERB',
#  'realistic': 'ADJ',
#  'men': 'NOUN',
#  'Most': 'ADJ',
#  'U.S.': 'NOUN',
#  'Senate': 'NOUN',
#  'human': 'ADJ',
#  'high': 'ADJ',
#  'hog': 'NOUN',
#  'Jackson': 'NOUN',
#  'political': 'ADJ',
#  'Rusk': 'NOUN',
#  'rid': 'ADJ',
#  'department': 'NOUN',
#  'personnel': 'NOUN',
#  'engaged': 'VERB',
#  ...}

# %%
i = 0
for key, value in mfc_table.items():
    print(key, value)
    i += 1
    if i > 120: break
# Out:
# Whenever ADV
# artists NOUN
# , .
# indeed ADV
# turned VERB
# to PRT
# actual ADJ
# representations NOUN
# or CONJ
# molded VERB
# three-dimensional ADJ
# figures NOUN
# which DET
# were VERB
# rare ADJ
# down PRT
# 800 NUM
# B.C. NOUN
# they PRON
# tended VERB
# reflect VERB
# reality NOUN
# ( .
# see VERB
# Plate NOUN
# 6a NUM
# 9b NUM
# ) .
# ; .
# For ADP
# almost ADV
# two NUM
# months NOUN
# the DET
# defendant NOUN
# and CONJ
# world NOUN
# heard VERB
# from ADP
# individuals NOUN
# escaped VERB
# grave ADJ
# about ADP
# fathers NOUN
# mothers NOUN
# graybeards NOUN
# adolescents NOUN
# babies NOUN
# starved VERB
# beaten VERB
# death NOUN
# strangled VERB
# machine-gunned VERB
# gassed VERB
# burned VERB
# . .
# Clearer ADJ
# meaning NOUN
# Yes ADV
# gentlemen NOUN
# I PRON
# am VERB
# getting VERB
# point NOUN
# my DET
# About ADV
# same ADJ
# time NOUN
# Alleghenies NOUN
# Poconos NOUN
# in ADP
# Pennsylvania NOUN
# are VERB
# magnificent ADJ
# -- .
# Renovo NOUN
# holds VERB
# its DET
# annual ADJ
# Flaming VERB
# Foliage NOUN
# Festival NOUN
# on ADP
# Oct. NOUN
# 14 NUM
# 15 NUM
# There's PRT
# no DET
# doubt NOUN
# this DET
# Tim NOUN
# sneaked VERB
# back ADV
# killed VERB
# Mrs. NOUN
# Buck NOUN
# The DET
# cowboy's NOUN
# humorous ADJ
# name NOUN
# for ADP
# a DET
# cow NOUN
# givin' VERB
# milk NOUN
# was VERB
# `` .
# pitcher NOUN
# '' .
# It PRON
# is VERB
# therefore ADV
# not ADV
# surprising ADJ
# that ADP
# resist VERB
# lure NOUN
# of ADP
# marriage NOUN
# trap NOUN
# domesticity NOUN

# %% [markdown]
# Python `namedtuple` supports a type of container-like dictionary that, like dictionaries, contains keys that are hashed to particular values. But it supports *both* access from key values as well as *iteration*, the functionality that dictionaries lack.
#
# Let's write a class that takes in a table in its constructor and adds `<MISSING>` POS tags if the word is missing from the training set (possible that a word is in the test set but missing from the training set). It also has a `viterbi` method that takes in the table and builds a sequence of states that we will use in our Hidden Markov Model.

# %%
FakeState = namedtuple('FakeState', 'name')

class MFCTagger:
    missing = FakeState(name = '<MISSING>')
    
    def __init__(self, table):
        self.table = defaultdict(lambda: MFCTagger.missing)
        self.table.update({word: FakeState(name=tag) for word, tag in table.items()})
        
    def viterbi(self, seq):
        """This method simplifies predictions by matching the Pomegranate viterbi() interface"""
        return 0., list(enumerate(["<start>"] + [self.table[w] for w in seq] + ["<end>"]))

# %%
mfc_model = MFCTagger(mfc_table)

# %% [markdown]
# So essentially we built a table that associates words with their most frequent POS tag. This is a simplistic **bag of words** (BOW) model. Let's see, given a sentence, if we *guess the hidden states* (POS tags) right!

# %%
def replace_unknown(sequence):
    return [w if w in data.training_set.vocab else 'nan' for w in sequence]

def simplify_decoding(X, model):    
    _, state_path = model.viterbi(replace_unknown(X))
    return [state[1].name for state in state_path[1:-1]]

# %%
for key in data.testing_set.keys[:1]:
    print("Sentence Key: {}\n".format(key))
    print("Sentence: {}\n".format(data.sentences[key].words))
    print("Predicted labels:\n-----------------")
    print(simplify_decoding(data.sentences[key].words, mfc_model))
    print()
    print("Actual labels:\n--------------")
    print(data.sentences[key].tags)
    print("\n")
# Out:
# Sentence Key: b100-28144
#
# Sentence: ('and', 'August', '15', ',', 'November', '15', ',', 'February', '17', ',', 'and', 'May', '15', ',', '(', 'Cranston', ')', '.')
#
# Predicted labels:
# -----------------
# ['CONJ', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'CONJ', 'NOUN', 'NUM', '.', '.', 'NOUN', '.', '.']
#
# Actual labels:
# --------------
# ('CONJ', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'CONJ', 'NOUN', 'NUM', '.', '.', 'NOUN', '.', '.')

# %% [markdown]
# Pretty good! Let's evaluate the accuracy of our most-frequent-tag tagger:

# %%
def accuracy(X, Y, model):
    
    correct = total_predictions = 0
    for observations, actual_tags in zip(X, Y):
        
        # The model.viterbi call in simplify_decoding will return None if the HMM
        # raises an error (for example, if a test sentence contains a word that
        # is out of vocabulary for the training set). Any exception counts the
        # full sentence as an error (which makes this a conservative estimate).
        try:
            most_likely_tags = simplify_decoding(observations, model)
            correct += sum(p == t for p, t in zip(most_likely_tags, actual_tags))
        except:
            pass
        total_predictions += len(observations)
    return correct / total_predictions

# %%
mfc_training_acc = accuracy(data.training_set.X, data.training_set.Y, mfc_model)
print("training accuracy mfc_model: {:.2f}%".format(100 * mfc_training_acc))

mfc_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, mfc_model)
print("testing accuracy mfc_model: {:.2f}%".format(100 * mfc_testing_acc))
# Out:
# training accuracy mfc_model: 95.72%
# testing accuracy mfc_model: 93.01%

# %% [markdown]
# # Hidden Markov Model
#
# Let's build a POS tagger using a Hidden Markov Model.
#
# First, let's see how many POS tags we have in our corpus, using the python `Counter` structure that we used last week to count instances.

# %%
def unigram_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.training_set.stream())]
tag_unigrams = unigram_counts(tags)
len(tag_unigrams)
# Out:
# 12

# %% [markdown]
# We'll *slightly* modify the code above to get our POS bigrams, from *both* training and test subsets, to uncover which POS tags follow which other POS tags. So, instead of a simple list of POS tags, `Counter` will count *neighboring* POS tuples!

# %%
def bigram_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.stream())]
o = [(tags[i],tags[i+1]) for i in range(0,len(tags)-2,2)]
tag_bigrams = bigram_counts(o)
len(tag_bigrams)
# Out:
# 144

# %% [markdown]
# What tags do our sentences *begin* with?

# %%
def starting_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.stream())]
starts_tag = [i[0] for i in data.Y]
tag_starts = starting_counts(starts_tag)
tag_starts
# Out:
# Counter({'NOUN': 8093,
#          'CONJ': 2817,
#          'PRT': 2103,
#          'DET': 12238,
#          'PRON': 9157,
#          'ADP': 7044,
#          'ADJ': 1969,
#          'ADV': 5238,
#          'VERB': 2588,
#          'NUM': 964,
#          '.': 5099,
#          'X': 30})

# %% [markdown]
# What tags do our sentences *end* with?

# %%
def ending_counts(sequences):    
    return Counter(sequences)

end_tag = [i[len(i)-1] for i in data.Y]
tag_ends = ending_counts(end_tag)
tag_ends
# Out:
# Counter({'.': 56149,
#          'ADJ': 31,
#          'ADV': 20,
#          'NOUN': 914,
#          'NUM': 80,
#          'PRON': 5,
#          'ADP': 8,
#          'VERB': 102,
#          'DET': 18,
#          'PRT': 9,
#          'CONJ': 2,
#          'X': 2})

# %% [markdown]
# Not surprising that most end with a period `.`! Ideally, we should end with the previous-to-last tag!

# %%
end_tag = [i[len(i)-2] for i in data.Y]
tag_ends = ending_counts(end_tag)
tag_ends
# Out:
# Counter({'NOUN': 30751,
#          'VERB': 5748,
#          '.': 10002,
#          'NUM': 1409,
#          'PRT': 719,
#          'PRON': 2125,
#          'ADV': 2860,
#          'ADJ': 2947,
#          'CONJ': 54,
#          'ADP': 302,
#          'X': 85,
#          'DET': 338})

# %% [markdown]
# Let's create our Hidden Markov Model and peek into most popular words per POS tag.
#
# `tag_words_count` contains words associated to each POS tag, arranged by frequency so that we can eventually evaluate *emission* probabilities, which are probabilities of observable states (wrods) given hidden states (POS tags).

# %%
hmm_model = HiddenMarkovModel(name="base-hmm-tagger")

tags = [tag for i, (word, tag) in enumerate(data.stream())]
words = [word for i, (word, tag) in enumerate(data.stream())]

tags_count = unigram_counts(tags)
tag_words_count = pair_counts(tags, words)

starting_tag_list = [i[0] for i in data.Y]
#ending_tag_list = [i[-1] if len(i)==1 else i[-2] for i in data.Y]
#ending_tag_list = [i[-1] for i in data.Y]
ending_tag_list = [i[len(i)-2] for i in data.Y]

starting_tag_count = starting_counts(starting_tag_list) #the number of times a tag occured at the start
ending_tag_count = ending_counts(ending_tag_list)       #the number of times a tag occured at the end

tag_words_count
# Out:
# defaultdict(<function __main__.pair_counts.<locals>.<lambda>()>,
#             {'NOUN': defaultdict(int,
#                          {'Mr.': 844,
#                           'Podger': 21,
#                           'use': 352,
#                           'advice': 50,
#                           'difference': 148,
#                           'opinion': 94,
#                           'board': 165,
#                           'instrument': 44,
#                           'elasticity': 5,
#                           'pastes': 1,
#                           'inks': 1,
#                           'paints': 6,
#                           'adhesives': 2,
#                           'plastics': 28,
#                           'bread': 41,
#                           'dough': 13,
#                           'properties': 61,
#                           'length': 115,
#                           'shortness': 1,
#                           'spinnability': 1,
#                           'methods': 138,
#                           'present': 44,
#                           'plans': 96,
#                           'language': 106,
#                           'teacher': 78,
#                           'east': 41,
#                           'mile': 42,
#                           'road': 178,
#                           'effort': 145,
#                           'sweat': 19,
#                           'television': 49,
#                           'Line': 15,
#                           'tour': 39,
#                           'Beach': 28,
#                           'night': 398,
#                           'opportunity': 120,
#                           'measure': 60,
#                           'adversary': 5,
#                           'war': 304,
#                           "Khrushchev's": 14,
#                           'intentions': 22,
#                           'views': 49,
#                           'direction': 132,
#                           'place': 475,
#                           'philosopher': 16,
#                           'Samuel': 34,
#                           "Alexander's": 3,
#                           'debt': 13,
#                           'Wordsworth': 2,
#                           'Meredith': 18,
#                           'example': 287,
#                           'A.': 110,
#                           'N.': 26,
#                           "Whitehead's": 2,
#                           'understanding': 82,
#                           'romantics': 5,
#                           'Shelley': 12,
#                           'network': 30,
#                           'entities': 11,
#                           'manner': 124,
#                           'regard': 53,
#                           'needs': 93,
#                           'society': 192,
#                           'regime': 23,
#                           "corporation's": 5,
#                           'survival': 30,
#                           'responsibility': 116,
#                           'conditions': 179,
#                           'assistance': 85,
#                           'scale': 53,
#                           'definition': 34,
#                           'objectives': 39,
#                           'assessment': 22,
#                           'costs': 160,
#                           'Theresa': 24,
#                           'Anne': 42,
#                           'George': 129,
#                           'degree': 125,
#                           'Af': 994,
#                           'P': 47,
#                           'teen': 2,
#                           'life': 676,
#                           'non-college': 1,
#                           'group': 377,
#                           'sense': 301,
#                           'marginality': 2,
#                           'tempest': 1,
#                           'March': 97,
#                           'Udall': 6,
#                           'bronze': 8,
#                           'statue': 16,
#                           'William': 147,
#                           'Jennings': 3,
#                           'Bryan': 12,
#                           'Gutzon': 1,
#                           'Borglum': 2,
#                           'loan': 41,
#                           'Salem': 19,
#                           'Illinois': 40,
#                           "Bryan's": 2,
#                           'birthplace': 6,
#                           'case': 353,
#                           'elements': 103,
#                           'pencil': 34,
#                           'secant': 12,
#                           'line': 279,
#                           'vertex': 19,
#                           'intersection': 17,
#                           '**zg': 32,
#                           'plane': 111,
#                           'howl': 3,
#                           'coming': 12,
#                           'times': 260,
#                           'veterinarian': 2,
#                           'Kennan': 7,
#                           'account': 90,
#                           'circumstance': 12,
#                           'atmosphere': 79,
#                           'decisions': 52,
#                           'approach': 107,
#                           'integration': 47,
#                           'formation': 37,
#                           'Market': 12,
#                           'Euratom': 1,
#                           'cooperation': 36,
#                           'development': 309,
#                           'energy': 96,
#                           'one': 482,
#                           'prestige': 27,
#                           'management': 88,
#                           'position': 235,
#                           'minds': 56,
#                           'people': 809,
#                           'things': 361,
#                           'holes': 38,
#                           'art': 178,
#                           'movies': 30,
#                           'girl': 211,
#                           'dreams': 24,
#                           'flower': 17,
#                           'elbows': 7,
#                           'body': 269,
#                           'potato': 15,
#                           'tune-belly': 1,
#                           'jury': 63,
#                           'Fulton': 17,
#                           "ordinary's": 1,
#                           'court': 118,
#                           'fire': 160,
#                           'practices': 49,
#                           'appointment': 26,
#                           'appraisers': 1,
#                           'guardians': 4,
#                           'administrators': 5,
#                           'awarding': 1,
#                           'fees': 27,
#                           'compensation': 17,
#                           'precedent': 9,
#                           'time': 1555,
#                           'capture': 4,
#                           'Helion': 18,
#                           'person': 170,
#                           'sketchbook': 2,
#                           "Woolworth's": 1,
#                           'York': 302,
#                           'boat': 69,
#                           'frames': 26,
#                           'contact': 53,
#                           'plywood': 9,
#                           'planking': 8,
#                           'significance': 66,
#                           'volume': 115,
#                           'paragraphs': 14,
#                           'Laguerre': 3,
#                           'Hanover': 66,
#                           'Tar': 10,
#                           'Heel-Lotus': 2,
#                           'radioactivity': 3,
#                           'fallout': 31,
#                           'Cavalry': 10,
#                           'troopers': 5,
#                           'Palace': 23,
#                           'Emperor': 12,
#                           'tonight': 34,
#                           'Earl': 11,
#                           'examples': 47,
#                           'abuse': 13,
#                           'passages': 20,
#                           'Examiner': 8,
#                           'Destroyer': 1,
#                           'Character': 1,
#                           'Richard': 71,
#                           'Steele': 21,
#                           'Swift': 20,
#                           'truth': 124,
#                           'men': 736,
#                           'treatment': 122,
#                           'Robert': 83,
#                           'E.': 85,
#                           'Lee': 34,
#                           'dignity': 34,
#                           'confederacy': 3,
#                           'Heat': 6,
#                           'transfer': 32,
#                           'conduction': 2,
#                           'radiation': 91,
#                           'arc': 40,
#                           'column': 60,
#                           'maps': 13,
#                           'program': 367,
#                           'step': 110,
#                           'division': 66,
#                           'long-range': 40,
#                           'state': 524,
#                           'plan': 166,
#                           'series': 122,
#                           'inch': 39,
#                           'sheets': 26,
#                           'feet': 283,
#                           'Hong': 11,
#                           'Kong': 11,
#                           'India': 58,
#                           'Pakistan': 7,
#                           'exports': 10,
#                           'types': 114,
#                           'textiles': 15,
#                           'Britain': 55,
#                           'years': 942,
#                           'Lancashire': 1,
#                           'Pact': 3,
#                           'day': 623,
#                           'dogs': 66,
#                           'Ireland': 13,
#                           'pigs': 6,
#                           'fans': 19,
#                           'room': 365,
#                           'remnants': 2,
#                           'smoke': 32,
#                           'strata': 2,
#                           'ceiling': 31,
#                           'ship': 76,
#                           'Discovery': 12,
#                           'crew': 36,
#                           'nuclei': 13,
#                           'fibers': 23,
#                           'Figures': 13,
#                           'proliferation': 5,
#                           'structure': 90,
#                           'center': 175,
#                           'periphery': 5,
#                           'fiber': 27,
#                           'presence': 75,
#                           'artery': 46,
#                           'anastomoses': 6,
#                           'Ruysch': 1,
#                           'others': 294,
#                           'information': 258,
#                           'sampling': 10,
#                           'assesment': 1,
#                           'techniques': 98,
#                           'advisers': 12,
#                           'attention': 177,
#                           'uninitiate': 1,
#                           'confusion': 43,
#                           'operator': 49,
#                           'anybody': 39,
#                           'campaign': 75,
#                           'Mitchell': 26,
#                           'image': 117,
#                           'unity': 66,
#                           'candidate': 34,
#                           'Washington': 206,
#                           'kind': 295,
#                           'materialism': 6,
#                           'Artists': 12,
#                           'truck': 54,
#                           'transportation': 39,
#                           'dollars': 97,
#                           'luxuries': 3,
#                           'agency': 48,
#                           'Fiat': 9,
#                           '$1.26': 1,
#                           '$.03': 4,
#                           'kilometer': 8,
#                           'Station': 12,
#                           'Wagon': 3,
#                           '$1.10': 1,
#                           '$.105': 1,
#                           'Premier': 24,
#                           'Khrushchev': 68,
#                           'inauguration': 3,
#                           'meeting': 122,
#                           'President': 257,
#                           'Kennedy': 140,
#                           'problem': 312,
#                           'field': 241,
#                           'work': 576,
#                           'procedures': 61,
#                           'Felix': 30,
#                           'Kopstein': 1,
#                           'snake': 42,
#                           'maturity': 36,
#                           'python': 14,
#                           'exception': 40,
#                           'corner': 113,
#                           'lights': 45,
#                           'motor': 52,
#                           'children': 342,
#                           'section': 132,
#                           'countries': 148,
#                           'farms': 16,
#                           'Du': 59,
#                           'Pont': 35,
#                           'General': 103,
#                           'Motors': 43,
#                           'shares': 41,
#                           'stockholders': 26,
#                           'right': 179,
#                           'eyes': 391,
#                           'bridge': 79,
#                           'type': 195,
#                           'U.S.': 161,
#                           'highway': 32,
#                           'system': 393,
#                           'relic': 6,
#                           'horse': 110,
#                           'buggy': 6,
#                           'days': 377,
#                           'promise': 36,
#                           'lion': 14,
#                           'lamb': 6,
#                           'tense': 5,
#                           'spices': 3,
#                           'flavorings': 1,
#                           'condiments': 2,
#                           'values': 182,
#                           'talents': 28,
#                           'tile': 16,
#                           'dome': 17,
#                           'rug': 13,
#                           'poem': 48,
#                           'miniature': 5,
#                           'institutions': 96,
#                           'city': 259,
#                           'buildings': 76,
#                           'walls': 69,
#                           'lanes': 4,
#                           'plays': 31,
#                           'facets': 9,
#                           'experience': 254,
#                           'religion': 101,
#                           'today': 246,
#                           'tomorrow': 59,
#                           'quality': 112,
#                           'collection': 83,
#                           'monotony': 7,
#                           'pieces': 92,
#                           "gourmet's": 1,
#                           'kitchen': 90,
#                           'breakfast': 51,
#                           'luncheon': 23,
#                           'party': 194,
#                           'rooms': 54,
#                           'everybody': 60,
#                           'mud': 31,
#                           'crank': 1,
#                           'calls': 22,
#                           'McFeeley': 12,
#                           'chance': 127,
#                           'transposition': 1,
#                           'numbers': 120,
#                           'thing': 331,
#                           'mistake': 30,
#                           'explosion': 15,
#                           'island': 32,
#                           'Krakatoa': 1,
#                           'transfers': 10,
#                           'angle': 50,
#                           'Orioles': 11,
#                           'improvement': 37,
#                           'year': 647,
#                           'influence': 113,
#                           'marijuana': 10,
#                           'beatnik': 7,
#                           'self': 34,
#                           'sesame': 4,
#                           'universe': 63,
#                           'book': 176,
#                           'title': 52,
#                           'moment': 246,
#                           'Wheeler': 4,
#                           'Fiske': 5,
#                           'rifle': 59,
#                           'Mike': 91,
#                           'guerrilla': 12,
#                           'boy': 234,
#                           'sir': 33,
#                           'enjoyment': 21,
#                           'liquor': 42,
#                           'ladies': 27,
#                           'Cheyenne': 2,
#                           'claim': 69,
#                           'killing': 12,
#                           'insinuations': 2,
#                           'Hetman': 12,
#                           'Hearst': 48,
#                           'newspaper': 62,
#                           'empire': 9,
#                           'means': 188,
#                           'coups': 2,
#                           'destruction': 37,
#                           'editors': 17,
#                           'course': 464,
#                           'unfrocking': 1,
#                           'publishers': 9,
#                           'mistakes': 15,
#                           'judgment': 58,
#                           'reports': 65,
#                           'Mama': 43,
#                           'Mrs.': 534,
#                           "Coolidge's": 2,
#                           'wish': 23,
#                           'rest': 136,
#                           'orchestra': 40,
#                           'spots': 31,
#                           'recording': 14,
#                           'performance': 122,
#                           'popularity': 17,
#                           'result': 196,
#                           'closing': 5,
#                           'Street': 98,
#                           'burlesque': 1,
#                           'joints': 12,
#                           'neighborhood': 57,
#                           'saloons': 8,
#                           'bit': 93,
#                           'epidermis': 2,
#                           'bedroom': 52,
#                           'forms': 122,
#                           'antibiotic': 1,
#                           'strains': 8,
#                           'examination': 27,
#                           'catalogs': 2,
#                           'schools': 190,
#                           'courses': 58,
#                           'design': 105,
#                           'part': 461,
#                           'membership': 66,
#                           'Association': 86,
#                           'Schools': 5,
#                           'Art': 24,
#                           'spot': 52,
#                           'inspection': 20,
#                           'number': 466,
#                           'recommendations': 21,
#                           'answers': 36,
#                           'clay': 84,
#                           'flesh': 52,
#                           'abdomen': 6,
#                           'torso': 7,
#                           'tablet': 3,
#                           'water': 430,
#                           'jungle': 18,
#                           'pool': 106,
#                           'nose': 59,
#                           'glasses': 29,
#                           'ribbon': 12,
#                           'jockey': 3,
#                           'adult': 23,
#                           'world': 684,
#                           'sources': 82,
#                           'diffusion': 24,
#                           "adolescent's": 3,
#                           'search': 58,
#                           'meaning': 113,
#                           'particular': 5,
#                           'identity': 55,
#                           'crisis': 77,
#                           'carborundum': 1,
#                           'disk': 25,
#                           'atom': 37,
#                           'physics': 19,
#                           'head': 404,
#                           'sides': 99,
#                           'balls': 17,
#                           'size': 136,
#                           'footballs': 1,
#                           'Eden': 9,
#                           'West': 94,
#                           'negotiation': 6,
#                           'East': 44,
#                           'parents': 81,
#                           'police': 134,
#                           'headquarters': 56,
#                           'hour': 145,
#                           'choice': 105,
#                           'fact': 447,
#                           'signs': 64,
#                           'frenzy': 6,
#                           'hunger': 17,
#                           'pain': 87,
#                           'fear': 93,
#                           'leg': 53,
#                           'importance': 108,
#                           'knife': 73,
#                           'material': 170,
#                           'Carboloy': 2,
#                           'Hesiometer': 6,
#                           'support': 123,
#                           'President-elect': 5,
#                           'Rules': 9,
#                           'Committee': 88,
#                           'bottleneck': 2,
#                           'touch': 54,
#                           'Crombie': 11,
#                           'Product': 4,
#                           'research': 133,
#                           'hours': 173,
#                           'independence': 46,
#                           'tribesmen': 2,
#                           "congressman's": 1,
#                           'patriotism': 6,
#                           'Defense': 41,
#                           'Department': 164,
#                           "Ortega's": 1,
#                           'hope': 98,
#                           'psychology': 13,
#                           'flowering': 4,
#                           'novel': 48,
#                           'something': 420,
#                           'home': 525,
#                           '49%': 1,
#                           'subjects': 79,
#                           'reaction': 121,
#                           'normalcy': 4,
#                           'demonstration': 25,
#                           'warmth': 28,
#                           'area': 319,
#                           'tones': 15,
#                           'fabrics': 28,
#                           'Romaniuk': 1,
#                           'Director': 25,
#                           'AIMO': 5,
#                           'Congo': 57,
#                           'rapport': 3,
#                           'Secretariat': 5,
#                           'points': 124,
#                           'Berle': 4,
#                           "Means's": 1,
#                           'study': 200,
#                           'Corporation': 20,
#                           'Property': 3,
#                           'panic': 20,
#                           'Mis-ter': 2,
#                           'McBride': 11,
#                           'Lord': 86,
#                           'hand': 411,
#                           "boss's": 3,
#                           'arm': 91,
#                           'car': 270,
#                           'Chapel': 11,
#                           'services': 127,
#                           'weekend': 27,
#                           'retreat': 11,
#                           'Cape': 17,
#                           'roses': 7,
#                           'door': 312,
#                           'birth': 63,
#                           'word': 261,
#                           'God': 297,
#                           'parts': 109,
#                           'cells': 81,
#                           'wavelengths': 6,
#                           'portions': 11,
#                           'color': 132,
#                           'San': 70,
#                           'Francisco': 41,
#                           'firemen': 5,
#                           'week': 257,
#                           'task': 59,
#                           'toys': 7,
#                           'distribution': 83,
#                           'Austin': 18,
#                           'Gary': 5,
#                           'Hammond': 2,
#                           'Ronnie': 5,
#                           'Davis': 27,
#                           'Oak': 8,
#                           'Cliff': 3,
#                           'Airport': 8,
#                           'Los': 51,
#                           'Angeles': 47,
#                           'Houston': 25,
#                           'Boeing': 3,
#                           'minutes': 193,
#                           'stopovers': 1,
#                           'Phoenix': 9,
#                           'El': 18,
#                           'Paso': 10,
#                           'Antonio': 6,
#                           'friction': 17,
#                           'force': 175,
#                           'chip': 17,
#                           'surfaces': 28,
#                           'face': 319,
#                           'Shayne': 27,
#                           'left-hand': 5,
#                           'lane': 11,
#                           'Boulevard': 9,
#                           'divider': 1,
#                           'shore': 40,
#                           'masts': 2,
#                           'Boys': 11,
#                           'boys': 132,
#                           'Texans': 9,
#                           'controversies': 4,
#                           'confusions': 4,
#                           'mind': 287,
#                           'usage': 14,
#                           'Gentile': 9,
#                           'Jew': 26,
#                           'members': 312,
#                           'bee': 10,
#                           'family': 311,
#                           'idlers': 1,
#                           'parasites': 4,
#                           'expense': 50,
#                           'relatives': 21,
#                           'Georgia': 46,
#                           'State': 263,
#                           'Chamber': 15,
#                           'Commerce': 40,
#                           'danger': 68,
#                           'candidates': 38,
#                           'side': 365,
#                           'situation': 196,
#                           'anything': 265,
#                           'policy': 221,
#                           'Definition': 4,
#                           'thighs': 7,
#                           'championship': 8,
#                           'lifters': 4,
#                           'exploration': 22,
#                           'business': 363,
#                           'joke': 19,
#                           'somebody': 45,
#                           'Spirit': 22,
#                           'Whigs': 6,
#                           "Steele's": 12,
#                           'reference': 66,
#                           'friend': 125,
#                           'Style': 1,
#                           'Friend': 8,
#                           'Body': 7,
#                           'Level': 1,
#                           'piano': 30,
#                           'sonatas': 3,
#                           'chamber': 31,
#                           'music': 194,
#                           'gavottes': 1,
#                           'marches': 1,
#                           'Miami': 22,
#                           'Fla.': 10,
#                           'protein': 21,
#                           'vitamins': 9,
#                           'minerals': 11,
#                           'shrubs': 4,
#                           'value': 199,
#                           'areas': 235,
#                           'brush': 29,
#                           'Palmer': 56,
#                           'strokes': 12,
#                           'Player': 33,
#                           'Communists': 39,
#                           'Germany': 81,
#                           'age': 212,
#                           'dealer': 24,
#                           'stocks': 17,
#                           'equipment': 164,
#                           '25%': 6,
#                           'affects': 1,
#                           'recovery': 26,
#                           "country's": 15,
#                           'farm': 109,
#                           'manufacturers': 40,
#                           'Simpkins': 7,
#                           'Somerset': 3,
#                           'shunts': 5,
#                           'being': 27,
#                           'rats': 3,
#                           'Pilgrims': 5,
#                           'prayers': 13,
#                           'thanks': 27,
#                           'conviction': 50,
#                           'need': 157,
#                           "Lord's": 12,
#                           'protection': 64,
#                           'future': 134,
#                           'peace': 133,
#                           'Morse': 29,
#                           'priests': 16,
#                           'Minerals': 3,
#                           'notch': 6,
#                           'finish': 15,
#                           'steel': 38,
#                           'dog': 70,
#                           'operation': 106,
#                           'platform': 70,
#                           "man's": 115,
#                           'Woods': 1,
#                           'duck': 2,
#                           'blinds': 3,
#                           'beer': 32,
#                           'poker': 5,
#                           'male': 24,
#                           'secretaries': 6,
#                           'climate': 26,
#                           'impressions': 24,
#                           'subject': 121,
#                           'deal': 89,
#                           'moments': 48,
#                           'long-life': 1,
#                           'components': 54,
#                           'housing': 21,
#                           'Pantas': 2,
#                           'club': 69,
#                           'chef': 8,
#                           'level': 195,
#                           'dark': 22,
#                           'light': 251,
#                           'impact': 66,
#                           'labor-management': 7,
#                           'relations': 93,
#                           'past': 98,
#                           'Moulton': 1,
#                           'Wilshire': 2,
#                           'Franklin': 30,
#                           'Moultons': 1,
#                           'S.': 114,
#                           'Windsor': 2,
#                           'Blvd.': 4,
#                           'enterprises': 14,
#                           'Electric': 4,
#                           'prices': 61,
#                           'way': 883,
#                           'competitors': 9,
#                           'wall': 137,
#                           'Cereal': 4,
#                           'grains': 20,
#                           'soybeans': 5,
#                           'peas': 24,
#                           'beans': 9,
#                           'two-thirds': 11,
#                           'three-fourths': 2,
#                           'diet': 20,
#                           'Asia': 44,
#                           'Africa': 45,
#                           'hardship': 9,
#                           'bristles': 3,
#                           'Fitch': 1,
#                           'one-half': 9,
#                           'chisel': 4,
#                           'edge': 76,
#                           'arcs': 8,
#                           'instance': 82,
#                           '90%': 4,
#                           'power': 324,
#                           'anode': 77,
#                           'rise': 53,
#                           'heat': 86,
#                           'fluxes': 4,
#                           'excess': 23,
#                           'authors': 23,
#                           'hell': 71,
#                           'niggers': 3,
#                           'squad': 16,
#                           'places': 91,
#                           'bags': 10,
#                           'seed': 39,
#                           'grain': 27,
#                           'author': 42,
#                           'electronics': 28,
#                           'application': 64,
#                           'possibilities': 42,
#                           'mathematics': 18,
#                           'grammar': 4,
#                           'school': 413,
#                           'arithmetic': 5,
#                           'classes': 76,
#                           'president': 125,
#                           'faculty': 73,
#                           'autonomy': 18,
#                           "university's": 5,
#                           'income': 97,
#                           'top-level': 3,
#                           'peoples': 36,
#                           'population': 136,
#                           'Yesterday': 3,
#                           'Violence': 3,
#                           'Jean': 23,
#                           'Reavey': 1,
#                           'sound': 126,
#                           'concrete': 26,
#                           'air': 218,
#                           'dust': 65,
#                           'debris': 8,
#                           'everyone': 73,
#                           'women': 182,
#                           'floor': 157,
#                           'desks': 4,
#                           'turtlebacks': 1,
#                           'expansion': 45,
#                           'raise': 4,
#                           'taxes': 44,
#                           'growth': 151,
#                           'tax': 186,
#                           'digest': 1,
#                           'planning': 43,
#                           'commissioners': 11,
#                           'Chairman': 19,
#                           'Charles': 96,
#                           'O.': 29,
#                           'Emmerich': 2,
#                           'trust': 25,
#                           'county': 70,
#                           'officials': 56,
#                           'list': 125,
#                           'Blevins': 2,
#                           'Flannagans': 3,
#                           'figure': 147,
#                           'Scripture': 3,
#                           'creatures': 20,
#                           'church': 223,
#                           "God's": 38,
#                           'providence': 3,
#                           'literature': 131,
#                           'education': 175,
#                           'sensibility': 7,
#                           'man': 1148,
#                           'curses': 3,
#                           'spirits': 42,
#                           'daughter': 70,
#                           'talons': 1,
#                           'fingers': 66,
#                           'hair': 147,
#                           'trees': 95,
#                           'moon': 48,
#                           'arms': 115,
#                           'piece': 127,
#                           'cavity': 12,
#                           'mold': 42,
#                           'Penny': 21,
#                           'grass': 52,
#                           'none': 92,
#                           'Mercer': 70,
#                           'Shayol': 4,
#                           'change': 161,
#                           'paper': 152,
#                           'flatness': 7,
#                           'indication': 19,
#                           'sign': 73,
#                           'ages': 37,
#                           'patients': 35,
#                           'Dr.': 192,
#                           'Brodie': 10,
#                           'cake': 13,
#                           'Bill': 65,
#                           'Bailey': 3,
#                           'discussions': 31,
#                           'science': 105,
#                           'studies': 94,
#                           'humanities': 2,
#                           'arts': 42,
#                           "week's": 8,
#                           'honeymoon': 10,
#                           'Acapulco': 1,
#                           'details': 57,
#                           'Victory': 7,
#                           'Sun': 10,
#                           'p': 29,
#                           'intention': 36,
#                           "Faulkner's": 9,
#                           'awareness': 32,
#                           'borders': 10,
#                           'South': 106,
#                           'Southerner': 8,
#                           'outlook': 35,
#                           'newspapers': 37,
#                           'cartoons': 5,
#                           'implications': 22,
#                           'headaches': 6,
#                           "Tilghman's": 4,
#                           'comrade': 4,
#                           'Throat': 11,
#                           'brawl': 1,
#                           "town's": 14,
#                           'funeral': 23,
#                           'parlor': 18,
#                           'burial': 10,
#                           'Moss': 6,
#                           'possum': 2,
#                           'plant': 118,
#                           'chief': 28,
#                           'Chapter': 36,
#                           'Parker': 63,
#                           'minister': 46,
#                           'pale': 1,
#                           'repository': 4,
#                           'liberality': 3,
#                           'champion': 18,
#                           'freedom': 119,
#                           'Steinberg': 15,
#                           'element': 52,
#                           'score': 50,
#                           'effect': 197,
#                           'song': 56,
#                           'Ivan': 4,
#                           'Allen': 20,
#                           'Jr.': 75,
#                           'Sept.': 34,
#                           'primary': 15,
#                           'Mayor': 30,
#                           'Hartsfield': 5,
#                           'reelection': 2,
#                           'Requests': 3,
#                           'agencies': 61,
#                           'assignments': 18,
#                           'cars': 109,
#                           'Hood': 3,
#                           'house': 391,
#                           'Blanche': 24,
#                           'Dunkel': 2,
#                           'Dwight': 12,
#                           'reformatory': 2,
#                           'murder': 68,
#                           'son-in-law': 4,
#                           'Ervin': 2,
#                           'Lang': 1,
#                           'parole': 5,
#                           'hearing': 48,
#                           'yesterday': 80,
#                           'pardon': 4,
#                           'John': 360,
#                           'M.': 62,
#                           'Bookwalter': 1,
#                           'Joseph': 55,
#                           'Carpentier': 1,
#                           'trend': 46,
#                           'bargaining': 16,
#                           'Geneva': 17,
#                           'negotiations': 20,
#                           'Laos': 64,
#                           'Vietnam': 3,
#                           'nations': 117,
#                           'pressure': 183,
#                           'lease': 7,
#                           'option': 5,
#                           'verdict': 15,
#                           'neighbor': 13,
#                           'Hengesbach': 9,
#                           'announcement': 24,
#                           'bond': 43,
#                           'City': 134,
#                           'Solicitor': 3,
#                           'David': 51,
#                           'Berger': 15,
#                           'press': 81,
#                           'conference': 61,
#                           'morning': 208,
#                           'Wagner': 21,
#                           'PTC': 3,
#                           'representatives': 27,
#                           'engineering': 9,
#                           'firm': 59,
#                           'project': 79,
#                           'completion': 36,
#                           'key': 51,
#                           'shoe': 14,
#                           'engine': 47,
#                           'fog': 24,
#                           'refrigerator': 23,
#                           'Knauer': 2,
#                           'owners': 34,
#                           "city's": 20,
#                           'animal': 68,
#                           'care': 85,
#                           'bar': 68,
#                           'spacers': 5,
#                           'frame': 69,
#                           'country': 312,
#                           'folk': 33,
#                           'dances': 19,
#                           'Virginia': 75,
#                           'Reels': 1,
#                           'square': 77,
#                           'trains': 14,
#                           'migration': 5,
#                           'Briton': 1,
#                           'Stirling': 2,
#                           'road-circuit': 1,
#                           ...}),
#              'VERB': defaultdict(int,
#                          {'had': 5101,
#                           'thanked': 6,
#                           'made': 1119,
#                           'seemed': 333,
#                           'be': 6342,
#                           'should': 865,
#                           'go': 604,
#                           'follow': 90,
#                           'is': 10010,
#                           'expected': 186,
#                           'could': 1580,
#                           'used': 610,
#                           'measure': 27,
#                           'printing': 10,
#                           'related': 98,
#                           'termed': 15,
#                           'are': 4333,
#                           'judged': 15,
#                           'become': 359,
#                           'ran': 132,
#                           'turned': 320,
#                           'panting': 8,
#                           'soaked': 6,
#                           'seems': 252,
#                           'would': 2677,
#                           'give': 377,
#                           'take': 573,
#                           'try': 125,
#                           'probe': 5,
#                           'make': 765,
#                           'move': 132,
#                           'faced': 50,
#                           'perpetuating': 4,
#                           'can': 1730,
#                           'controlling': 23,
#                           'forcing': 13,
#                           'representing': 28,
#                           'encourage': 45,
#                           'establishing': 25,
#                           'sustained': 15,
#                           'Could': 21,
#                           'wondered': 58,
#                           'understood': 58,
#                           'was': 9777,
#                           'divides': 6,
#                           'have': 3892,
#                           'tends': 34,
#                           'stirred': 15,
#                           'announced': 88,
#                           'sculpted': 1,
#                           'sent': 143,
#                           'killed': 75,
#                           "didn't": 393,
#                           'fixed': 81,
#                           'joining': 15,
#                           'does': 445,
#                           'lie': 52,
#                           'let': 286,
#                           'saying': 112,
#                           'did': 994,
#                           'takes': 86,
#                           'mitigating': 2,
#                           'recalling': 5,
#                           'mistaken': 17,
#                           'were': 3279,
#                           'taken': 279,
#                           'capped': 2,
#                           'leads': 31,
#                           'conclude': 16,
#                           'believe': 199,
#                           'stuck': 23,
#                           'come': 589,
#                           'born': 109,
#                           'grows': 22,
#                           'held': 259,
#                           'trilled': 1,
#                           'tickled': 2,
#                           'commented': 18,
#                           'has': 2424,
#                           'been': 2470,
#                           'want': 317,
#                           'stir': 7,
#                           'bought': 56,
#                           'do': 1259,
#                           'foregoing': 7,
#                           'suggest': 53,
#                           'looked': 366,
#                           'decays': 1,
#                           'charged': 57,
#                           'guarding': 9,
#                           'said': 1943,
#                           'quotes': 4,
#                           'attributes': 1,
#                           'react': 15,
#                           'represented': 56,
#                           'needed': 187,
#                           'rebelling': 3,
#                           'planning': 72,
#                           'implement': 3,
#                           'prepare': 35,
#                           'covering': 30,
#                           'limiting': 11,
#                           'will': 2105,
#                           'going': 389,
#                           'drawing': 25,
#                           'drifted': 9,
#                           'obtained': 115,
#                           'provisioned': 1,
#                           'called': 396,
#                           'recruited': 4,
#                           'commanded': 15,
#                           'shown': 166,
#                           'showed': 141,
#                           'approximated': 5,
#                           'forming': 21,
#                           'occurring': 21,
#                           'noted': 89,
#                           'gathered': 32,
#                           'sit': 64,
#                           'may': 1290,
#                           'divert': 1,
#                           'cause': 52,
#                           "don't": 387,
#                           'care': 75,
#                           'witnessed': 13,
#                           'project': 12,
#                           'see': 727,
#                           'wish': 86,
#                           'budget': 2,
#                           'saving': 18,
#                           'indulge': 9,
#                           'lists': 6,
#                           'seating': 5,
#                           'froze': 5,
#                           'figure': 19,
#                           'symbolize': 9,
#                           'intimated': 5,
#                           'hoped': 48,
#                           'confronted': 30,
#                           'follows': 76,
#                           'states': 17,
#                           'reaches': 21,
#                           'reached': 169,
#                           'goes': 89,
#                           'cite': 7,
#                           'went': 506,
#                           'parked': 33,
#                           'turning': 57,
#                           'put': 424,
#                           'retain': 11,
#                           'required': 181,
#                           'pass': 63,
#                           'vote': 26,
#                           'surviving': 13,
#                           'serve': 103,
#                           'given': 371,
#                           'told': 411,
#                           'continue': 105,
#                           'rise': 48,
#                           'deal': 45,
#                           'must': 998,
#                           'Called': 5,
#                           'indicate': 80,
#                           'lasting': 12,
#                           'avoids': 3,
#                           'dining': 26,
#                           'sitting': 88,
#                           'standing': 91,
#                           'dressing': 17,
#                           "won't": 103,
#                           'notice': 26,
#                           'passed': 157,
#                           'launched': 20,
#                           'look': 268,
#                           'comes': 133,
#                           'experiences': 5,
#                           'enhanced': 5,
# ...
#                           '2.5': 4,
#                           '7070/7074': 4,
#                           '86': 6,
#                           '56': 6,
#                           'twenty-three': 7,
#                           '51': 4,
#                           '158': 1,
#                           '1,100': 1,
#                           '15.8': 1,
#                           '10,000,000': 2,
#                           '150,000,000': 2,
#                           '14.7': 2,
#                           '29.2': 2,
#                           '562': 1,
#                           '1958-60': 1,
#                           '1.8': 3,
#                           '1832': 7,
#                           '1,257,700': 1,
#                           '1200': 1,
#                           '-.50': 1,
#                           '-.10': 1,
#                           '7-6': 2,
#                           '32,589': 1,
#                           'Eight': 11,
#                           '72': 10,
#                           '1981': 1,
#                           '1821': 5,
#                           '165': 2,
#                           '6-6': 1,
#                           'seventy': 4,
#                           'hundred-odd': 2,
#                           '100-200': 1,
#                           '9e': 1,
#                           '2.26': 1,
#                           '1-0': 1,
#                           'Thirty-three': 1,
#                           '139': 1,
#                           '2,800,000': 1,
#                           '447': 2,
#                           '469': 1,
#                           '22-29': 1,
#                           '25-30': 1,
#                           'sixteen': 18,
#                           '1,700': 2,
#                           'ninety-eight': 1,
#                           'septillion': 1,
#                           '10.2': 1,
#                           '3.03': 2,
#                           '450': 3,
#                           '66': 2,
#                           '1,512': 1,
#                           '1,065': 1,
#                           '7:00': 2,
#                           'fifty-three': 1,
#                           '6-2/3': 1,
#                           '0.7': 1,
#                           '172': 1,
#                           '2:00.2': 1,
#                           '2:04.2': 2,
#                           '2:03': 1,
#                           '2:02.3': 2,
#                           '16-22': 1,
#                           '15-': 1,
#                           '46,000': 1,
#                           '2.6': 4,
#                           '2.7': 1,
#                           '2,800': 1,
#                           '1,524': 1,
#                           'seven-': 1,
#                           '543': 1,
#                           '1810': 5,
#                           'Fifty': 5,
#                           '2:33': 3,
#                           '96': 5,
#                           '285': 1,
#                           '312': 1,
#                           '392': 2,
#                           '1964': 3,
#                           "'51": 1,
#                           '3.0': 1,
#                           '-.5': 1,
#                           '391': 1,
#                           '1453': 2,
#                           '$50': 1,
#                           '4,000': 3,
#                           'eight-by-ten': 1,
#                           'eighty-nine': 1,
#                           '1310': 1,
#                           '1745': 1,
#                           '1764': 1,
#                           '1782': 2,
#                           "'58": 3,
#                           '762': 1,
#                           '442': 1,
#                           '390': 1,
#                           '2-and-2': 1,
#                           '1592': 2,
#                           'fifty-four': 1,
#                           '520': 1,
#                           '694': 1,
#                           '2.55': 1,
#                           '2.58': 1,
#                           '035': 1,
#                           '40,000': 9,
#                           '800': 13,
#                           '247': 2,
#                           '83': 3,
#                           'Fifty-seven': 1,
#                           '265': 1,
#                           '64-13': 1,
#                           '1776': 5,
#                           'quadrillion': 1,
#                           '9-6': 1,
#                           '7-9': 1,
#                           '3211': 2,
#                           '185': 1,
#                           '10.6': 1,
#                           '1597/8': 1,
#                           '5847': 1,
#                           '6124': 1,
#                           '12:50': 1,
#                           '7,484,268': 1,
#                           '9,910,741': 1,
#                           '12-to-one': 1,
#                           '1950-1953': 1,
#                           '2688': 1,
#                           '823': 1,
#                           '9a': 1,
#                           '57': 10,
#                           '7-1': 6,
#                           '381': 4,
#                           '2.0': 2,
#                           '200,000': 4,
#                           'thirty-nine': 2,
#                           '7:50': 1,
#                           '1540': 1,
#                           '1882': 3,
#                           '63,000,000': 1,
#                           '7,500': 1,
#                           '2:40': 2,
#                           '20-to-1': 2,
#                           '116': 1,
#                           '400,000': 2,
#                           '300,000': 6,
#                           '360,000': 1,
#                           '270,000': 1,
#                           '1630': 1,
#                           '170': 2,
#                           '105': 2,
#                           '430,000': 1,
#                           '7074': 1,
#                           '4.21': 1,
#                           '2.16': 1,
#                           '1-1/2': 4,
#                           '132,000': 1,
#                           '923,076': 1,
#                           '4:00': 2,
#                           '1811': 1,
#                           '7-3': 2,
#                           '1609': 3,
#                           '2/3': 1,
#                           '1938-1939': 1,
#                           '1,509': 1,
#                           '2:30-:34.3': 2,
#                           '250,000': 4,
#                           '511': 1,
#                           '1644': 1,
#                           '0.001': 2,
#                           '4,122,354': 1,
#                           '1818': 4,
#                           '1911-1912': 1,
#                           '1631': 1,
#                           '1311': 1,
#                           '451': 1,
#                           '1783': 3,
#                           '18-1/2': 1,
#                           '495': 1,
#                           '55,000': 1,
#                           '637': 1,
#                           'thirteen': 9,
#                           '7:25': 1,
#                           '4-0': 2,
#                           '1881-85': 1,
#                           '1901': 4,
#                           '1863': 3,
#                           '94': 2,
#                           '1-a': 4,
#                           '1,488': 1,
#                           '7-2': 3,
#                           '1939': 6,
#                           'fifty-one': 1,
#                           '0.2': 4,
#                           '0.4': 4,
#                           '1733': 1,
#                           '1.24': 2,
#                           '3-5': 1,
#                           '1751': 1,
#                           '1899': 3,
#                           '13,200': 1,
#                           '117': 1,
#                           '79,400': 1,
#                           '1904': 3,
#                           '144': 1,
#                           '570': 1,
#                           '44': 3,
#                           '36-A': 1,
#                           '1597': 1,
#                           '0.005': 1,
#                           '0.039': 1,
#                           '7/2': 2,
#                           '1897': 3,
#                           'octillion': 3,
#                           '8-b-2': 1,
#                           '2,300': 1,
#                           '4.5': 2,
#                           '1787': 2,
#                           '710': 1,
#                           '3.8': 1,
#                           '13.9': 1,
#                           '05': 3,
#                           '5.3': 1,
#                           '1492': 1,
#                           '1598/9': 1,
#                           'forty-seven': 3,
#                           '1579': 2,
#                           'Ninety': 1,
#                           '153': 2,
#                           '1970': 3,
#                           '1700': 3,
#                           '635': 1,
#                           '6.6': 1,
#                           '278': 1,
#                           '31730': 1,
#                           '1693': 1,
#                           '646': 1,
#                           '11-18': 1,
#                           '1,212,000': 1,
#                           '5-': 1,
#                           '1-701': 1,
#                           '168': 3,
#                           '381(c)(6)': 2,
#                           '140,000': 1,
#                           'two-to-three': 1,
#                           '126,000': 1,
#                           '1875': 4,
#                           '7-5': 1,
#                           '1307': 1,
#                           "'50": 3,
#                           "'53": 1,
#                           'Forty-six': 2,
#                           '1184': 1,
#                           '643': 1,
#                           '541': 1,
#                           '31978': 1,
#                           '14-1': 2,
#                           '2:25': 2,
#                           '6-12': 1,
#                           '1582': 3,
#                           '120': 6,
#                           '4.8': 1,
#                           '135': 3,
#                           '3.9': 1,
#                           '4.7': 1,
#                           '2.512': 2,
#                           '1858': 2,
#                           '1665.32': 1,
#                           '1667.36': 1,
#                           '0.10': 1,
#                           '443': 1,
#                           '106': 2,
#                           '2/4': 1,
#                           '4/4': 1,
#                           'Forty': 4,
#                           '3-0': 1,
#                           '1558': 1,
#                           '1,419,833': 1,
#                           '1,541,991': 1,
#                           '122,158': 1,
#                           '33-1/2': 1,
#                           '116,000': 1,
#                           '3.3': 2,
#                           '381(c)': 2,
#                           '3-1/2': 3,
#                           '1728': 1,
#                           '1,900': 1,
#                           '1637': 1,
#                           'twenty-two': 6,
#                           '1963-1972': 1,
#                           '1a': 1,
#                           '10:45': 1,
#                           '357': 1,
#                           '1830': 1,
#                           '12,500': 1,
#                           '1,119': 1,
#                           '402': 1,
#                           '22-1/2': 1,
#                           '2:67': 1,
#                           '63': 5,
#                           '394': 1,
#                           '7,827': 1,
#                           '5-to-2': 1,
#                           '151': 1,
#                           '5-1/2': 1,
#                           '1774': 1,
#                           '128': 3,
#                           '198': 1,
#                           '1859-1929': 1,
#                           '211': 2,
#                           '1895': 6,
#                           '1.10.1': 1,
#                           '50-50': 1,
#                           '78-79': 1,
#                           '87-1/2': 1,
#                           '1947-49': 1,
#                           '1,600': 2,
#                           '2-5': 2,
#                           '2:31.3-:35.3': 1,
#                           '19-1/2': 1,
#                           '6-1/2': 2,
#                           '64-66': 1,
#                           '343': 1,
#                           '169': 2,
#                           '22,000': 2,
#                           '44,000': 1,
#                           'thirty-eight': 1,
#                           '836-901': 1,
#                           '1876': 4,
#                           '1865': 6,
#                           '186': 2,
#                           '2:00.3': 1,
#                           '2:05.1': 1,
#                           '121,000': 1,
#                           '11:00': 2,
#                           '12:00': 1,
#                           '1898': 4,
#                           '1792': 3,
#                           '1:00': 2,
#                           '195': 2,
#                           '7-4': 2,
#                           'ten-fifty-five': 1,
#                           '1.10.8': 1,
#                           '540-K': 1,
#                           'ninety-six': 2,
#                           'seven-thirty': 1,
#                           '200-odd': 1,
#                           '828': 1,
#                           '354': 2,
#                           'Twenty-six': 1,
#                           '59,780': 1,
#                           '750': 4,
#                           '19-12': 1,
#                           '1632': 4,
#                           '1639': 1,
#                           '1565': 2,
#                           '512': 2,
#                           '156': 3,
#                           '1814': 2,
#                           '346': 2,
#                           '5-6': 1,
#                           '2:01.3': 1,
#                           '2:02': 1,
#                           '2:06.3': 1,
#                           '2:02.2': 1,
#                           '22,807': 1,
#                           '37,081': 1,
#                           'five-seventeen': 1,
#                           'eighty-one': 1,
#                           '1934': 6,
#                           '1640': 1,
#                           '1747': 1,
#                           '1878': 1,
#                           '1957-1958': 1,
#                           '1290': 1,
#                           '1655': 1,
#                           '1596/7': 1,
#                           '1633': 1,
#                           '1598': 2,
#                           '6-7': 1,
#                           '88': 1,
#                           '1746': 1,
#                           '1748': 1,
#                           '1967': 2,
#                           '650': 1,
#                           '63-64': 1,
#                           '1923-27': 1,
#                           '1972': 1,
#                           '4-7/8': 1,
#                           '1986': 3,
#                           '1991': 1,
#                           '37,470': 1,
#                           '6-5': 1,
#                           'forty-nine': 3,
#                           '213': 2,
#                           '060': 1,
#                           '5-3': 1,
#                           '5.6': 2,
#                           '6.2': 1,
#                           '1806': 1,
#                           '256': 3,
#                           '1024': 1,
#                           '6.4': 2,
#                           '9,748,000': 1,
#                           '2,887,671': 1,
#                           'Twelve': 3,
#                           '4.6': 1,
#                           '573': 1,
#                           '1847': 2,
#                           '2:26': 2,
#                           '1.25': 1,
#                           "'31": 1,
#                           '2.44': 1,
#                           '1769': 1,
#                           'seventy-eight': 1,
#                           ':35.3': 1,
#                           '381(c)(4)': 1,
#                           '5-5': 2,
#                           '5:30': 1,
#                           '27,000': 2,
#                           '4:05': 1,
#                           '13-1/2': 1,
#                           '9329': 1,
#                           ...})})

# %%
ending_tag_list
# Out:
# ['NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'VERB',
#  '.',
#  'VERB',
#  'NOUN',
#  '.',
#  '.',
#  '.',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'PRT',
#  'PRON',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  '.',
#  'PRON',
#  'ADV',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  '.',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'ADJ',
#  'ADJ',
#  'NUM',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'PRON',
#  'ADV',
#  'NOUN',
#  'ADV',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'PRON',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  '.',
#  '.',
#  'NUM',
#  '.',
#  'VERB',
#  '.',
#  'VERB',
#  '.',
#  '.',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'ADV',
#  'NOUN',
#  '.',
#  'NOUN',
#  '.',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'CONJ',
#  'ADJ',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'PRON',
#  'ADV',
#  'NOUN',
#  'ADP',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'ADV',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  '.',
#  '.',
#  '.',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'VERB',
#  'PRON',
#  'NOUN',
#  'NOUN',
#  'ADP',
#  'NOUN',
#  '.',
#  'PRON',
#  'NOUN',
#  'PRON',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  '.',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  '.',
#  'NOUN',
#  'NOUN',
#  'ADP',
#  '.',
#  'ADV',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  '.',
#  'NOUN',
#  '.',
#  'NOUN',
#  'PRT',
#  'PRON',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  '.',
#  'ADJ',
#  'NOUN',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  '.',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'ADP',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'VERB',
#  'ADV',
#  'ADV',
#  'VERB',
#  'NUM',
#  'PRON',
#  '.',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  '.',
#  'NOUN',
#  'X',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  '.',
#  'NOUN',
#  'NOUN',
#  'PRON',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'PRON',
#  '.',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'ADV',
#  '.',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'ADV',
#  'ADV',
#  'PRON',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  '.',
#  '.',
#  'PRON',
#  'NOUN',
#  'NOUN',
#  'PRON',
#  'NOUN',
#  '.',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'PRON',
#  'VERB',
#  'NUM',
#  'NOUN',
#  '.',
#  'NOUN',
#  'ADJ',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  '.',
#  'VERB',
#  'PRT',
#  'VERB',
#  'DET',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  '.',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'PRT',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'VERB',
#  'NOUN',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'ADV',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  '.',
#  'NOUN',
#  'NOUN',
#  'ADV',
#  'PRON',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  '.',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'ADV',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  '.',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  'PRON',
#  'VERB',
#  '.',
#  'ADJ',
#  'PRON',
#  'VERB',
#  'NOUN',
#  'NUM',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'NUM',
#  'NOUN',
#  '.',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'VERB',
#  'ADJ',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'PRON',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'ADJ',
#  'VERB',
#  '.',
#  'NOUN',
#  '.',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'PRON',
#  'NOUN',
#  'VERB',
#  '.',
#  'NOUN',
#  'NOUN',
#  '.',
#  'ADV',
#  'VERB',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  '.',
#  '.',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  '.',
#  'VERB',
#  'NOUN',
#  'NUM',
#  'VERB',
#  '.',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'PRON',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NUM',
#  'NOUN',
#  '.',
#  'PRON',
#  'VERB',
#  'VERB',
#  '.',
#  'NOUN',
#  'ADV',
#  '.',
#  'VERB',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  '.',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'VERB',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'ADV',
#  '.',
#  'NOUN',
#  'VERB',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  '.',
#  'NOUN',
#  'PRON',
#  '.',
#  'VERB',
#  '.',
#  'NOUN',
#  'PRON',
#  'PRON',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'ADV',
#  'NOUN',
#  'VERB',
#  '.',
#  'VERB',
#  'NOUN',
#  '.',
#  'NOUN',
#  '.',
#  'ADJ',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'ADJ',
#  'ADV',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  '.',
#  'NOUN',
#  'VERB',
#  'ADV',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'PRON',
#  'NOUN',
#  '.',
#  'ADV',
#  'NOUN',
#  '.',
#  'NOUN',
#  '.',
#  'ADV',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NUM',
#  '.',
#  'PRON',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'PRT',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'ADV',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'ADV',
#  '.',
#  'ADV',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  '.',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  '.',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'PRON',
#  'NOUN',
#  '.',
#  '.',
#  'VERB',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'ADJ',
#  '.',
#  'NOUN',
#  'NOUN',
#  'PRON',
#  'NOUN',
#  'NOUN',
#  'ADV',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  '.',
#  'ADJ',
#  'NOUN',
#  'ADV',
#  '.',
#  'NOUN',
#  '.',
#  'ADV',
#  'NOUN',
#  'PRT',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'ADV',
#  'NOUN',
#  'NUM',
#  'NOUN',
#  'PRON',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'PRT',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  '.',
#  '.',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'PRON',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'ADV',
#  'NOUN',
#  'ADV',
#  'ADJ',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  '.',
#  '.',
#  'NOUN',
#  'ADJ',
#  '.',
#  '.',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  '.',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  '.',
#  '.',
#  '.',
#  '.',
#  'PRON',
#  'NOUN',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NUM',
#  '.',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'VERB',
#  '.',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'NUM',
#  '.',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'PRON',
#  '.',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NUM',
#  'NOUN',
#  'PRT',
#  'NOUN',
#  'ADV',
#  'NOUN',
#  'ADJ',
#  'ADJ',
#  'VERB',
#  'NOUN',
#  '.',
#  'ADV',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  '.',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'VERB',
#  '.',
#  'VERB',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'PRT',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'ADV',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  '.',
#  'VERB',
#  '.',
#  '.',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'PRON',
#  'NOUN',
#  'ADJ',
#  'ADV',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'PRON',
#  'ADV',
#  'NOUN',
#  'VERB',
#  '.',
#  'NOUN',
#  'ADV',
#  '.',
#  'NOUN',
#  '.',
#  '.',
#  '.',
#  'ADJ',
#  'NOUN',
#  '.',
#  'NOUN',
#  'VERB',
#  '.',
#  'ADJ',
#  'NOUN',
#  '.',
#  'VERB',
#  '.',
#  'DET',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'NOUN',
#  '.',
#  'NOUN',
#  'VERB',
#  '.',
#  'NOUN',
#  'PRON',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'ADV',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  '.',
#  '.',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  '.',
#  '.',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'PRON',
#  ...]

# %%
starting_tag_count
# Out:
# Counter({'NOUN': 8093,
#          'CONJ': 2817,
#          'PRT': 2103,
#          'DET': 12238,
#          'PRON': 9157,
#          'ADP': 7044,
#          'ADJ': 1969,
#          'ADV': 5238,
#          'VERB': 2588,
#          'NUM': 964,
#          '.': 5099,
#          'X': 30})

# %% [markdown]
# Let's convert word frequencies by POS tag to probabilities by dividing by the total number of words per POS tag, yielding the `distribution` of words.
#
# We'll define HMM emission probabilities using that `distribution`.

# %%
to_pass_states = []
for tag, words_dict in tag_words_count.items():
    total = float(sum(words_dict.values()))
    distribution = {word: count/total for word, count in words_dict.items()}
    tag_emissions = DiscreteDistribution(distribution)
#     print(distribution)
    tag_state = State(tag_emissions, name=tag)
    to_pass_states.append(tag_state)

# %%
# distribution

# %% [markdown]
# `to_pass_states` yields the probability distribution of words per POS tag:

# %%
# to_pass_states

# %% [markdown]
# Let's add states to our model:

# %%
hmm_model.add_states()

# %% [markdown]
# The start probability for each tag is how many times it is a sentence-starting POS tag divided by its total count. We build the starting transitions for our HMM model:

# %%
start_prob={}

for tag in tags:
    start_prob[tag] = starting_tag_count[tag] / tags_count[tag]

for tag_state in to_pass_states :
    hmm_model.add_transition(hmm_model.start, tag_state, start_prob[tag_state.name])

# %% [markdown]
# The end probability for each tag is how many times it is a sentence-ending POS tag divided by its total count. We build the ending transitions for our HMM model:

# %%
end_prob={}

for tag in tags:
    end_prob[tag] = ending_tag_count[tag]/tags_count[tag]
    
for tag_state in to_pass_states :
    hmm_model.add_transition(tag_state, hmm_model.end, end_prob[tag_state.name])

# %% [markdown]
# We now add the transition probabilities for our model, which uses our POS bigrams to enumerate what the probabilities are for transiting from one POS tag to another.

# %%
transition_prob_pair={}

for key in tag_bigrams.keys():
    transition_prob_pair[key] = tag_bigrams.get(key)/tags_count[key[0]]
    
for tag_state in to_pass_states:
    for next_tag_state in to_pass_states:
#         if (tag_state.name,next_tag_state.name) in tag_bigrams.keys():
        hmm_model.add_transition(tag_state, next_tag_state, transition_prob_pair[(tag_state.name, next_tag_state.name)])

# %% [markdown]
# We *bake* our model:

# %%
hmm_model.bake()

# %% [markdown]
# We can now evaluate the accuracy of our HMM model and compare it to our BOW model:

# %%
hmm_training_acc = accuracy(data.training_set.X, data.training_set.Y, hmm_model)
print("training accuracy basic hmm model: {:.2f}%".format(100 * hmm_training_acc))

hmm_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, hmm_model)
print("testing accuracy basic hmm model: {:.2f}%".format(100 * hmm_testing_acc))
# Out:
# training accuracy basic hmm model: 97.48%
# testing accuracy basic hmm model: 95.96%

# %% [markdown]
# Here's a decoding example:

# %%
for key in data.testing_set.keys[:1]:
    print("Sentence Key: {}\n".format(key))
    print("Sentence: {}\n".format(data.sentences[key].words))
    print("Predicted labels:\n-----------------")
    print(simplify_decoding(data.sentences[key].words, hmm_model))
    print()
    print("Actual labels:\n--------------")
    print(data.sentences[key].tags)
    print("\n")
# Out:
# Sentence Key: b100-28144
#
# Sentence: ('and', 'August', '15', ',', 'November', '15', ',', 'February', '17', ',', 'and', 'May', '15', ',', '(', 'Cranston', ')', '.')
#
# Predicted labels:
# -----------------
# ['CONJ', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'CONJ', 'NOUN', 'NUM', '.', '.', 'NOUN', '.', '.']
#
# Actual labels:
# --------------
# ('CONJ', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'CONJ', 'NOUN', 'NUM', '.', '.', 'NOUN', '.', '.')

# %% [markdown]
# A 96% accuracy for our HMM model compared to a 93% accuracy for our BOW model is a ***huge*** improvement as it brings language understanding error to below 4%, and 5% error is considered a *gold standard* for NLP. Speech-to-text frameworks like Alexa and Siri only started betting popular when they crossed the 5% threshold.
#
# # References
#
# - Hands on Markov models with python, by Ankur Ankan and Abinash Panda, [on amazon](https://www.amazon.com/Hands-Markov-Models-Python-probabilistic/dp/1788625447/ref=sr_1_2?keywords=hands+on+markov+models+with+python&qid=1581280984&sr=8-2)</div>
#
# - [Universal Dependency Parsing from Scratch](https://nlp.stanford.edu/pubs/qi2018universal.pdf)
#
# - [Statistical Machine Translation](https://en.wikipedia.org/wiki/Statistical_machine_translation)
#
# - [Language Models](https://en.wikipedia.org/wiki/Language_model).
#
# # Homework
#
# Use the methodology in this notebook to build a statistical language translator, *from your language to english*. So, from Hindi or Chinese to English. Teams of **3** students. You *have* to use a Hidden Markov Model and `pomegranate` as your HMM library, to ensure all student teams start from the same baseline. Start from a Most Frequent Word (BOW) translation baseline, then move on to a Hidden Markov Model to improve translation. How much can you improve it by? The translation engine with the best accuracy, per language, will be presented in class.
